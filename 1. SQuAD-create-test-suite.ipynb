# %% [markdown]
# # Creating checklist test suite for SQuAD
#
# Source: code from https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/SQuAD.ipynb with some changes

# %%
# %load_ext autoreload
# %autoreload 2

import checklist
import spacy
import itertools

import checklist.editor
import checklist.text_generation
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
from checklist.test_suite import TestSuite
import numpy as np
from checklist.perturb import Perturb

# %% [markdown]
# ### load the default hugging face model for question-answering
# [`distilbert-base-cased-distilled-squad`](https://huggingface.co/distilbert-base-cased-distilled-squad)

# %%
import datasets
from transformers import AutoTokenizer, AutoModelForSequenceClassification, \
    AutoModelForQuestionAnswering, Trainer, TrainingArguments, HfArgumentParser
from transformers import pipeline 

model = pipeline('question-answering', model="distilbert-base-cased-distilled-squad")
model({
    'context': 'A new strain of flu that has the potential to become a pandemic has been identified by scientists.',
    'question': 'What has been discovered by scientists?'
})
# Out:
# {'score': 0.38112872838974,
#  'start': 0,
#  'end': 19,
#  'answer': 'A new strain of flu'}

# %%
def predconfs(context_question_pairs):
    """
    output: predictions, confidence 
    source: https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/tutorials/5.%20Testing%20transformer%20pipelines.ipynb
    """
    preds = []
    confs = []
    for c, q in context_question_pairs:
        try:
            p = model(question=q, context=c, truncation=True, )
        except:
            print('Failed', q)
            preds.append(' ')
            confs.append(1)
        preds.append(p['answer'])
        confs.append(p['score'])
    return preds, np.array(confs)

def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

def format_squad(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'Q: %s\n' % (q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

# %%
editor = checklist.editor.Editor()
suite = TestSuite()

# %% [markdown]
# # Generating Tests

# %% [markdown]
# ## Vocabulary

# %%
suggestions1 = editor.suggest('{first_name} is {mask} than {first_name2}.')[:60]
print(suggestions1)
# Out:
# C:\Users\fgmal\AppData\Roaming\Python\Python310\site-packages\checklist\text_generation.py:171: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:248.)
#   to_pred = torch.tensor(to_pred, device=self.device).to(torch.int64)
# ['smarter', 'older', 'better', 'younger', 'taller', 'worse', 'stronger', 'different', 'shorter', 'cooler', 'nicer', 'tougher', 'bigger', 'hotter', 'happier', 'smaller', 'wiser', 'more', 'faster', 'richer', 'darker', 'thinner', 'weaker', 'less', 'larger', 'quieter', 'cleaner', 'heavier', 'healthier', 'closer', 'colder', 'slower', 'wealthier', 'quicker', 'longer', 'harder', 'safer', 'lighter', 'warmer', 'brighter', 'cheaper', 'sharper', 'higher', 'louder', 'thicker', 'greater', 'lower', 'easier', 'deeper', 'poorer', 'softer', 'smoother', 'simpler', 'stranger', 'newer', 'other', 'superior', 'clearer', 'stricter', 'tighter']

# %%
suggestions1 = [x for x in suggestions1 if x.endswith("er")][:20]

# %% [markdown]
# ### A is COMP than B. Who is more COMP?

# %%
t = editor.template(
    [(
    '{first_name} is {adj} than {first_name1}.',
    'Who is {adj}?'
    )
    ],
    labels = ['{first_name}'],
    adj=suggestions1,
    remove_duplicates=True,
    nsamples=500,
    save=True
    )
name = 'A is COMP than B. Who is more COMP?'
description = ''
test = MFT(**t, name=name, description=description, capability='Vocabulary')
suite.add(test)

# %%
test.run(predconfs, n=100, overwrite=True)
# Out:
# Predicting 100 examples

# %%
test.summary(format_example_fn=format_squad_with_context)
# Out:
# Test cases:      498
# Test cases run:  100
# Fails (rate):    4 (4.0%)
#
# Example fails:
# C: Claire is stronger than Donald.
# Q: Who is stronger?
# A: Claire
# P: Donald
#
# ----
# C: Christine is stronger than Richard.
# Q: Who is stronger?
# A: Christine
# P: Christine is stronger than Richard
#
# ----
# C: Katie is older than Adam.
# Q: Who is older?
# A: Katie
# P: Katie is older than Adam
#
# ----

# %% [markdown]
# ### A is COMP than B. Who is less COMP?

# %%
t = editor.template(
    [(
    '{first_name} is {adj} than {first_name1}.',
    'Who is less {adj}?'
    )
    ],
    labels = ['{first_name1}'],
    adj=suggestions1,
    remove_duplicates=True,
    nsamples=500,
    save=True
    )
name = 'A is COMP than B. Who is less COMP?'
description = ''
test = MFT(**t, name=name, description=description, capability='Vocabulary')
suite.add(test)

# %%
test.run(predconfs, n=100)
# Out:
# Predicting 100 examples

# %%
test.summary(format_example_fn=format_squad_with_context, n=3)
# Out:
# Test cases:      499
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Tom is tougher than Jennifer.
# Q: Who is less tougher?
# A: Jennifer
# P: Tom
#
# ----
# C: Kim is bigger than Heather.
# Q: Who is less bigger?
# A: Heather
# P: Kim
#
# ----
# C: Alan is bigger than Bobby.
# Q: Who is less bigger?
# A: Bobby
# P: Alan
#
# ----

# %% [markdown]
# ### Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?

# %%
def crossproduct(t):
    # takes the output of editor.template and does the cross product of contexts and qas
    ret = []
    ret_labels = []
    for x in t.data:
        cs = x['contexts']
        qas = x['qas']
        d = list(itertools.product(cs, qas))
        ret.append([(x[0], x[1][0]) for x in d])
        ret_labels.append([x[1][1] for x in d])
    t.data = ret
    t.labels = ret_labels
    return t

# %%
state = editor.suggest('John is very {mask} about the project.')[:20]
print(', '.join(editor.suggest('John is {mask} {state} about the project.', state=state)[:30]))
very = ['very', 'extremely', 'really', 'quite', 'incredibly', 'particularly', 'highly', 'super']
somewhat = ['a little', 'somewhat', 'slightly', 'mildly']
# Out:
# very, pretty, extremely, also, still, quite, more, really, not, clearly, fairly, incredibly, particularly, now, understandably, rather, cautiously, surprisingly, certainly, feeling, so, especially, definitely, generally, most, highly, super, reportedly, being, obviously

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {very} {s} about the project. {first_name1} is {s} about the project.',
            '{first_name1} is {s} about the project. {first_name} is {very} {s} about the project.',
            '{first_name} is {s} about the project. {first_name1} is {somewhat} {s} about the project.',
            '{first_name1} is {somewhat} {s} about the project. {first_name} is {s} about the project.',
            '{first_name} is {very} {s} about the project. {first_name1} is {somewhat} {s} about the project.',
            '{first_name1} is {somewhat} {s} about the project. {first_name} is {very} {s} about the project.',
        ],
        'qas': [
            (
                'Who is most {s} about the project?',
                '{first_name}'
            ), 
            (
                'Who is least {s} about the project?',
                '{first_name1}'
            ), 
            
        ]
        
    },
    s = state,
    very=very,
    somewhat=somewhat,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?'
desc = ''
test = MFT(**t, name=name, description=desc, capability='Vocabulary')
suite.add(test)

# %%
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
# Out:
# Predicting 1200 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Billy is somewhat passionate about the project. Lisa is passionate about the project.
# Q: Who is least passionate about the project?
# A: Billy
# P: Lisa
#
# C: Lisa is passionate about the project. Billy is somewhat passionate about the project.
# Q: Who is least passionate about the project?
# A: Billy
# P: Lisa
#
# C: Lisa is extremely passionate about the project. Billy is somewhat passionate about the project.
# Q: Who is least passionate about the project?
# A: Billy
# P: Lisa
#
#
# ----
# C: Diane is highly skeptical about the project. Jay is slightly skeptical about the project.
# Q: Who is least skeptical about the project?
# A: Jay
# P: Diane
#
# C: Diane is skeptical about the project. Jay is slightly skeptical about the project.
# Q: Who is most skeptical about the project?
# A: Diane
# P: Jay
#
# C: Diane is highly skeptical about the project. Jay is skeptical about the project.
# Q: Who is most skeptical about the project?
# A: Diane
# P: Jay
#
#
# ----
# C: David is excited about the project. Margaret is particularly excited about the project.
# Q: Who is least excited about the project?
# A: David
# P: Margaret
#
# C: Margaret is excited about the project. David is slightly excited about the project.
# Q: Who is most excited about the project?
# A: Margaret
# P: David
#
# C: David is slightly excited about the project. Margaret is particularly excited about the project.
# Q: Who is least excited about the project?
# A: David
# P: Margaret
#
#
# ----

# %% [markdown]
# ## Taxonomy

# %% [markdown]
# ### Size, chape, color, age, material

# %%
import munch
order = ['size', 'shape', 'age', 'color']
props = []
properties = {
    'color' : ['red', 'blue','yellow', 'green', 'pink', 'white', 'black', 'orange', 'grey', 'purple', 'brown'],
    'size' : ['big', 'small', 'tiny', 'enormous'],
    'age' : ['old', 'new'],
    'shape' : ['round', 'oval', 'square', 'triangular'],
    'material' : ['iron', 'wooden', 'ceramic', 'glass', 'stone']
}
for i in range(len(order)):
    for j in range(i + 1, len(order)):
        p1, p2 = order[i], order[j]
        for v1, v2 in itertools.product(properties[p1], properties[p2]):
            props.append(munch.Munch({
                'p1': p1,
                'p2': p2,
                'v1': v1,
                'v2': v2,
            }))

# %%
print(', '.join(editor.suggest('There is {a:p.v1} {p.v2} {mask} in the room.', p=props, verbose=False)[:30]))
objects = ['box', 'clock', 'table', 'object', 'toy', 'painting', 'sculpture', 'thing', 'figure']
# Out:
# sofa, couch, wall, carpet, chair, table, light, lamp, door, clock, mirror, desk, bed, TV, bar, television, window, box, tree, painting, curtain, fan, fridge, screen, wallpaper, piano, rug, shelf, camera, candle

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            'There is {a:p.v1} {p.v2} {obj} in the room.',
            'There is {a:obj} in the room. The {obj} is {p.v1} and {p.v2}.',
        ],
        'qas': [
            (
                'What {p.p1} is the {obj}?',
                '{p.v1}'
            ), 
            (
                'What {p.p2} is the {obj}?',
                '{p.v2}'
            ), 
            
        ]
    },
    obj=objects,
    p=props,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'size, shape, age, color'
desc = ''
test = MFT(**t, name=name, description=desc, capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    99 (99.0%)
#
# Example fails:
# C: There is a figure in the room. The figure is tiny and white.
# Q: What size is the figure?
# A: tiny
# P: tiny and white
#
# C: There is a tiny white figure in the room.
# Q: What size is the figure?
# A: tiny
# P: white
#
#
# ----
# C: There is a new yellow thing in the room.
# Q: What age is the thing?
# A: new
# P: yellow
#
# C: There is a thing in the room. The thing is new and yellow.
# Q: What age is the thing?
# A: new
# P: new and yellow
#
#
# ----
# C: There is a box in the room. The box is tiny and orange.
# Q: What size is the box?
# A: tiny
# P: tiny and orange
#
# C: There is a tiny orange box in the room.
# Q: What size is the box?
# A: tiny
# P: orange
#
#
# ----

# %% [markdown]
# ### Professions vs nationalities

# %%
professions = editor.suggest('{first_name} works as {a:mask}.')[:30]
professions += editor.suggest('{first_name} {last_name} works as {a:mask}.')[:30]
professions = list(set(professions))
if 'translator' in professions:
    professions.remove('translator')
print(professions)
# Out:
# ['journalist', 'attorney', 'producer', 'economist', 'executive', 'escort', 'administrator', 'waitress', 'editor', 'entrepreneur', 'analyst', 'educator', 'activist', 'intern', 'organizer', 'assistant', 'photographer', 'reporter', 'DJ', 'author', 'engineer', 'actress', 'nurse', 'investigator', 'agent', 'architect', 'actor', 'secretary', 'artist', 'model', 'interpreter', 'investor', 'accountant', 'historian']

# %%
def clean(string):
    return string.lstrip('[a,the,an,in,at] ').rstrip('.')

# %%
def expect_squad(x, pred, conf, label=None, meta=None):
    return clean(pred) == clean(label)
expect_squad = Expect.single(expect_squad)

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {a:nat} {prof}.',
            '{first_name} is {a:prof}. {first_name} is {nat}.',
            '{first_name} is {nat}. {first_name} is {a:prof}.',
            '{first_name} is {nat} and {a:prof}.',
            '{first_name} is {a:prof} and {nat}.',
        ],
        'qas': [
            (
                'What is {first_name}\'s job?',
                '{prof}'
            ), 
            (
                'What is {first_name}\'s nationality?',
                '{nat}'
            ), 
            
        ]
        
    },
    nat = editor.lexicons['nationality'][:10],
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    save=True,
    ))
name = 'Profession vs nationality'
test = MFT(**t, name=name, expect=expect_squad, description='',  capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 1000 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    20 (20.0%)
#
# Example fails:
# C: Keith is a Pakistani escort.
# Q: What is Keith's job?
# A: escort
# P: Pakistani escort
#
#
# ----
# C: Marie is a Russian executive.
# Q: What is Marie's job?
# A: executive
# P: Russian executive
#
#
# ----
# C: Susan is a Bangladeshi secretary.
# Q: What is Susan's job?
# A: secretary
# P: Bangladeshi secretary
#
#
# ----

# %% [markdown]
# ### Animal vs vehicle

# %%
animals = ['dog', 'cat', 'bull', 'cow', 'fish', 'serpent', 'snake', 'lizard', 'hamster', 'rabbit', 'guinea pig', 'iguana', 'duck']
vehicles = ['car', 'truck', 'train', 'motorcycle', 'bike', 'firetruck', 'tractor', 'van', 'SUV', 'minivan']
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} has {a:animal} and {a:vehicle}.',
            '{first_name} has {a:vehicle} and {a:animal}.',
        ],
        'qas': [
            (
                'What animal does {first_name} have?',
                '{animal}'
            ), 
            (
                'What vehicle does {first_name} have?',
                '{vehicle}'
            ), 
            
        ]
        
    },
    animal=animals,
    vehicle=vehicles,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Animal vs Vehicle'
test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test, overwrite=True)
# Out:
# Predicting 400 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    57 (57.0%)
#
# Example fails:
# C: Donna has a fish and a van.
# Q: What vehicle does Donna have?
# A: van
# P: a fish and a van
#
#
# ----
# C: Joe has a serpent and a car.
# Q: What vehicle does Joe have?
# A: car
# P: a serpent and a car
#
# C: Joe has a car and a serpent.
# Q: What vehicle does Joe have?
# A: car
# P: a car and a serpent
#
#
# ----
# C: Alex has a cow and a firetruck.
# Q: What vehicle does Alex have?
# A: firetruck
# P: a cow and a firetruck
#
# C: Alex has a firetruck and a cow.
# Q: What animal does Alex have?
# A: cow
# P: firetruck and a cow
#
# C: Alex has a firetruck and a cow.
# Q: What vehicle does Alex have?
# A: firetruck
# P: firetruck and a cow
#
#
# ----

# %% [markdown]
# ### Animal vs vehicle v2
# who bought?

# %%
animals = ['dog', 'cat', 'bull', 'cow', 'fish', 'serpent', 'snake', 'lizard', 'hamster', 'rabbit', 'guinea pig', 'iguana', 'duck']
vehicles = ['car', 'truck', 'train', 'motorcycle', 'bike', 'firetruck', 'tractor', 'van', 'SUV', 'minivan']
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} bought {a:animal}. {first_name2} bought {a:vehicle}.',
            '{first_name2} bought {a:vehicle}. {first_name} bought {a:animal}.',
        ],
        'qas': [
            (
                'Who bought an animal?',
                '{first_name}'
            ), 
            (
                'Who bought a vehicle?',
                '{first_name2}'
            ), 
            
        ]
        
    },
    animal=animals,
    vehicle=vehicles,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Animal vs Vehicle v2'
test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test, overwrite=True)
# Out:
# Predicting 400 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    68 (68.0%)
#
# Example fails:
# C: Bill bought a snake. Heather bought a minivan.
# Q: Who bought a vehicle?
# A: Heather
# P: Bill
#
# C: Heather bought a minivan. Bill bought a snake.
# Q: Who bought an animal?
# A: Bill
# P: Heather bought a minivan. Bill
#
#
# ----
# C: Cynthia bought a snake. Harriet bought a train.
# Q: Who bought a vehicle?
# A: Harriet
# P: Cynthia
#
# C: Harriet bought a train. Cynthia bought a snake.
# Q: Who bought a vehicle?
# A: Harriet
# P: Harriet bought a train. Cynthia
#
#
# ----
# C: Judith bought a minivan. Pamela bought a bull.
# Q: Who bought an animal?
# A: Pamela
# P: Judith
#
#
# ----

# %% [markdown]
# ### Synonyms

# %%
synonyms = [ ('spiritual', 'religious'), ('angry', 'furious'), ('organized', 'organised'),
            ('vocal', 'outspoken'), ('grateful', 'thankful'), ('intelligent', 'smart'),
            ('humble', 'modest'), ('courageous', 'brave'), ('happy', 'joyful'), ('scared', 'frightened'),
           ]

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is very {s1[0]}. {first_name2} is very {s2[0]}.',
            '{first_name2} is very {s2[0]}. {first_name} is very {s1[0]}.',
        ],
        'qas': [
            (
                'Who is {s1[1]}?',
                '{first_name}'
            ), 
            (
                'Who is {s2[1]}?',
                '{first_name2}'
            ), 
            
        ]
        
    },
    s=synonyms,
    remove_duplicates=True,
    nsamples=250,
    save=True
   ))
t += crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is very {s1[1]}. {first_name2} is very {s2[1]}.',
            '{first_name2} is very {s2[1]}. {first_name} is very {s1[1]}.',
        ],
        'qas': [
            (
                'Who is {s1[0]}?',
                '{first_name}'
            ), 
            (
                'Who is {s2[0]}?',
                '{first_name2}'
            ), 
            
        ]
        
    },
    s=synonyms,
    remove_duplicates=True,
    nsamples=250,
    save=True
    )) 
name = 'Synonyms'
test = MFT(**t, name=name, description='', capability='Taxonomy', expect=expect_squad)
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      439
# Test cases run:  100
# Fails (rate):    17 (17.0%)
#
# Example fails:
# C: Larry is very happy. Tim is very grateful.
# Q: Who is joyful?
# A: Larry
# P: Tim
#
#
# ----
# C: Alex is very happy. Jennifer is very courageous.
# Q: Who is joyful?
# A: Alex
# P: Jennifer
#
#
# ----
# C: Sally is very outspoken. Hugh is very smart.
# Q: Who is vocal?
# A: Sally
# P: Hugh
#
#
# ----

# %% [markdown]
# ### A is COMP than B. Who is antonym(COMP)? B

# %%
comp_pairs = [('better', 'worse'), ('older', 'younger'), ('smarter', 'dumber'), ('taller', 'shorter'), ('bigger', 'smaller'), ('stronger', 'weaker'), ('faster', 'slower'), ('darker', 'lighter'), ('richer', 'poorer'), ('happier', 'sadder'), ('louder', 'quieter'), ('warmer', 'colder')]
comp_pairs = list(set(comp_pairs))#list(set(comp_pairs + [(x[1], x[0]) for x in comp_pairs]))

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {comp[0]} than {first_name1}.',
            '{first_name1} is {comp[1]} than {first_name}.',
        ],
        'qas': [
            (
                'Who is {comp[1]}?',
                '{first_name1}',
            ),
            (
                'Who is {comp[0]}?',
                '{first_name}',
            )
            
        ]
        ,
    },
    comp=comp_pairs,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'A is COMP than B. Who is antonym(COMP)? B'
test = MFT(**t, name=name, description='', capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Adam is weaker than Helen.
# Q: Who is stronger?
# A: Helen
# P: Adam
#
# C: Helen is stronger than Adam.
# Q: Who is weaker?
# A: Adam
# P: Helen
#
#
# ----
# C: Arthur is older than Kate.
# Q: Who is younger?
# A: Kate
# P: Arthur
#
# C: Kate is younger than Arthur.
# Q: Who is older?
# A: Arthur
# P: Kate
#
#
# ----
# C: Nick is faster than Rose.
# Q: Who is slower?
# A: Rose
# P: Nick
#
# C: Rose is slower than Nick.
# Q: Who is faster?
# A: Nick
# P: Rose
#
#
# ----

# %% [markdown]
# ### A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.

# %%
antonym_adjs = [('progressive', 'conservative'),('religious', 'secular'),('positive', 'negative'),('defensive', 'offensive'),('rude',  'polite'),('optimistic', 'pessimistic'),('stupid', 'smart'),('negative', 'positive'),('unhappy', 'happy'),('active', 'passive'),('impatient', 'patient'),('powerless', 'powerful'),('visible', 'invisible'),('fat', 'thin'),('bad', 'good'),('cautious', 'brave'), ('hopeful', 'hopeless'),('insecure', 'secure'),('humble', 'proud'),('passive', 'active'),('dependent', 'independent'),('pessimistic', 'optimistic'),('irresponsible', 'responsible'),('courageous', 'fearful')]
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is more {a[0]} than {first_name1}.',
            '{first_name1} is more {a[1]} than {first_name}.',
            '{first_name} is less {a[1]} than {first_name1}.',
            '{first_name1} is less {a[0]} than {first_name}.',
        ],
        'qas': [
            (
                'Who is more {a[0]}?',
                '{first_name}',
            ),
            (
                'Who is less {a[0]}?',
                '{first_name1}',
            ),
            (
                'Who is more {a[1]}?',
                '{first_name1}',
            ),
            (
                'Who is less {a[1]}?',
                '{first_name}',
            ),
        ]
        ,
    },
    a = antonym_adjs,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.'
test = MFT(**t, name=name, description='', capability='Taxonomy')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 1600 examples
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Helen is more smart than Bobby.
# Q: Who is less smart?
# A: Bobby
# P: Helen
#
# C: Helen is less stupid than Bobby.
# Q: Who is less smart?
# A: Bobby
# P: Helen
#
# C: Helen is less stupid than Bobby.
# Q: Who is more stupid?
# A: Bobby
# P: Helen
#
#
# ----
# C: Elizabeth is more passive than Jane.
# Q: Who is less passive?
# A: Jane
# P: Elizabeth
#
# C: Elizabeth is less active than Jane.
# Q: Who is less passive?
# A: Jane
# P: Elizabeth
#
# C: Elizabeth is more passive than Jane.
# Q: Who is more active?
# A: Jane
# P: Elizabeth
#
#
# ----
# C: Howard is more thin than Fiona.
# Q: Who is less thin?
# A: Fiona
# P: Howard
#
# C: Howard is less fat than Fiona.
# Q: Who is more fat?
# A: Fiona
# P: Howard
#
# C: Howard is less fat than Fiona.
# Q: Who is less thin?
# A: Fiona
# P: Howard
#
#
# ----

# %% [markdown]
# ## Robustness

# %%
dataset = datasets.load_dataset('squad')
pairs = [(x['context'], x['question']) for x in dataset['train']]
# Out:
# Found cached dataset squad (C:/Users/fgmal/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# import pickle
# # IF YOU ALREADY RAN THIS CELL, JUMP TO NEXT
# # source: https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/QQP.ipynb
# nlp = spacy.load('en_core_web_sm')
# all_questions = set() # a set of all questions and context
# for x in dataset['train']:
#     all_questions.add(x['question'])
#     all_questions.add(x['context'])


# all_questions = list(all_questions)
# parsed_questions = list(nlp.pipe(all_questions)) # this takes a while to run 
# spacy_map = dict([(x, y) for x, y in zip(all_questions, parsed_questions)])


# pickle.dump(spacy_map, open('processed_squad.pkl', 'wb'))

# %%
import pickle
spacy_map =  pickle.load(open('processed_squad.pkl', 'rb'))

# %%
processed_pairs = [(spacy_map[x[0]], spacy_map[x[1]]) for x in pairs]

# %%
# check
print("text:",pairs[0][0])
print("entities:",spacy_map[pairs[0][0]].ents)
# Out:
# text: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# entities: (Catholic, the Main Building's, the Virgin Mary., the Main Building, Venite Ad Me Omnes, the Main Building, the Sacred Heart, Grotto, Marian, Lourdes, France, the Virgin Mary, Saint Bernadette Soubirous, 1858, 3, the Gold Dome, Mary)

# %% [markdown]
# ### Question Typo

# %%
def question_typo(x):
    """
    x[0]: context
    x[1]: question 
    Perturb.add_typos(x[1]): add a typo to question 
    """
    return (x[0], Perturb.add_typos(x[1]))
t = Perturb.perturb(pairs, question_typo, nsamples=500)
test = INV(**t, name='Question typo', capability='Robustness', description='')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad)
suite.add(test, overwrite=True)
# Out:
# Predicting 200 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    16 (16.0%)
#
# Example fails:
# Q: What is resistance to antibiotics a cause of?
# P: evolutionary processes
#
# Q: What is resistance to atnibiotics a cause of?
# P: evolutionary processes that take place during antibiotic therapy
#
#
# ----
# Q: What was the second reform?
# P: the provision for the conscription of every male Prussian of military age
#
# Q: What was the secon dreform?
# P: reorganization of the army that integrated the regular army and the Landwehr reserves
#
#
# ----
# Q: What was Darwin's response to the claims that certain animals could not have evolved through natural selection?
# P: Darwin proposed scenarios
#
# Q: What was Dariwn's response to the claims that certain animals could not have evolved through natural selection?
# P: George Jackson Mivart
#
#
# ----

# %% [markdown]
# ### Question contractions

# %%
def contractions(x):
    conts = Perturb.contractions(x[1])
    return [(x[0], a) for a in conts]
t = Perturb.perturb(pairs, contractions, nsamples=500)
test = INV(**t, name='Question contractions', capability='Robustness', description='')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad)
suite.add(test)
# Out:
# Predicting 200 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    11 (11.0%)
#
# Example fails:
# Q: Where is Paris economic Centre located?
# P: west of the city
#
# Q: Where's Paris economic Centre located?
# P: west
#
#
# ----
# Q: Where did Gershwin and Heyward write their folk opera?
# P: Folly Beach
#
# Q: Where'd Gershwin and Heyward write their folk opera?
# P: Folly Beach outside of Charleston
#
#
# ----
# Q: What is the longest half life of the isotopes?
# P: 243.66 days
#
# Q: What's the longest half life of the isotopes?
# P: 13.76 h
#
#
# ----

# %% [markdown]
# Add random sentence

# %%
random_sentences = set()
for x, _ in processed_pairs:
    for y in x.sents:
        random_sentences.add(y.text)
random_sentences = list(random_sentences)

# %%
# check
for y in processed_pairs[0][0].sents:
    print(y.text)
# Out:
# Architecturally, the school has a Catholic character.
# Atop the Main Building's gold dome is a golden statue of the Virgin Mary.
# Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes".
# Next to the Main Building is the Basilica of the Sacred Heart.
# Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection.
# It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858.
# At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.

# %%
len(random_sentences)
# Out:
# 92328

# %% [markdown]
# ### Add random sentence to context

# %%
def add_random_sentence(x, **kwargs):
    random_s = np.random.choice(random_sentences)
    while random_s in x[0]:
        random_s = np.random.choice(random_sentences)
    random_s = random_s.strip('.') + '. '
    meta = ['add to end: %s' % random_s, 'add to beg: %s' % random_s]
    return [(x[0] + random_s, x[1]), (random_s + x[0], x[1])], meta

def format_add(x, pred, conf, label=None, meta=None):
    ret = format_squad(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s\n' % meta
    return ret

t = Perturb.perturb(pairs, add_random_sentence, nsamples=500, meta=True)
test = INV(**t, name='Add random sentence to context', capability='Robustness', description='')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_add)
suite.add(test)
# Out:
# Predicting 300 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    20 (20.0%)
#
# Example fails:
# Q: What does corruption disregard in politics?
# P: democracy and good governance by flouting or even subverting formal processes
#
# Q: What does corruption disregard in politics?
# P: democracy and good governance
# Perturb: add to beg: In May 2008, Israel confirmed it had been discussing a peace treaty with Syria for a year, with Turkey as a go-between.
#
#
# ----
# Q: There is a museum on Whitney Avenue that contain a variety of historical treasure, what is its' name?
# P: Eli Whitney Museum
#
# Q: There is a museum on Whitney Avenue that contain a variety of historical treasure, what is its' name?
# P: New Haven Museum and Historical Society
# Perturb: add to beg: During the embryonic stage of many insects and the postembryonic stage of primitive insects, 11 abdominal segments are present.
#
#
# ----
# Q: How were some of Marvel's genre titles published in the 1970s?
# P: larger-format black and white magazines
#
# Q: How were some of Marvel's genre titles published in the 1970s?
# P: in larger-format black and white magazines
# Perturb: add to beg: Much of the Pacific Northwest coast is inhabited by some of the densest vegetation outside of the Tropics, and also the tallest trees in the world (the Redwoods).
#
# Q: How were some of Marvel's genre titles published in the 1970s?
# P: black and white magazines
# Perturb: add to end: Much of the Pacific Northwest coast is inhabited by some of the densest vegetation outside of the Tropics, and also the tallest trees in the world (the Redwoods).
#
#
# ----

# %% [markdown]
# ## NER

# %%
import re
def change_thing(change_fn):
    def change_both(cq, **kwargs):
        context, question = cq
        a = change_fn(context, meta=True)
        if not a:
            return None
        changed, meta = a
        ret = []
        for c, m in zip(changed, meta):
            new_q = re.sub(r'\b%s\b' % re.escape(m[0]), m[1], question.text)
            ret.append((c, new_q))
        return ret, meta
    return change_both

# %%
def expect_same(orig_pred, pred, orig_conf, conf, labels=None, meta=None):
    if not meta:
        return pred == orig_pred
    return pred == re.sub(r'\b%s\b' % re.escape(meta[0]), meta[1], orig_pred)

def format_replace(x, pred, conf, label=None, meta=None):
    ret = format_squad(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s -> %s\n' % meta
    return ret

def format_replace_context(x, pred, conf, label=None, meta=None):
    ret = format_squad_with_context(x, pred, conf, label, meta)
    if meta:
        ret += 'Perturb: %s -> %s\n' % meta
    return ret

# %%
t = Perturb.perturb(processed_pairs, change_thing(Perturb.change_names), nsamples=500, meta=True)

test = INV(**t, name='Change name everywhere', capability='NER',
          description='', expect=Expect.pairwise(expect_same))
test.run(predconfs, n=100)
test.summary(3, format_example_fn=format_replace)
suite.add(test, overwrite=True)
# Out:
# Predicting 1100 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    5 (5.0%)
#
# Example fails:
# Q: Who broke the world record for simultaneous fireworks?
# P: Roy Lowry
#
# Q: Who broke the world record for simultaneous fireworks?
# P: Joseph Cook of the University of Plymouth
# Perturb: Roy Lowry -> Joseph Cook
#
#
# ----
# Q: What was Henry's reply to Bell's statement that he lacked information to complete his telegraph?
# P: Get it!"
#
# Q: What was Peter's reply to Bell's statement that he lacked information to complete his telegraph?
# P: "Get it!"
# Perturb: Henry -> Peter
#
#
# ----
# Q: Prior to what century had there been little contact between western europe and greek civilization?
# P: 18th
#
# Q: Prior to what century had there been little contact between western europe and greek civilization?
# P: 18th century
# Perturb: James Stuart -> John Hall
#
#
# ----

# %% [markdown]
# ### Change location everywhere

# %%
t = Perturb.perturb(processed_pairs, change_thing(Perturb.change_location), nsamples=500, meta=True)

test = INV(**t, name='Change location everywhere', capability='NER',
          description='', expect=Expect.pairwise(expect_same))
test.run(predconfs, n=100)
test.summary(3, format_example_fn=format_replace)
suite.add(test, overwrite=True)
# Out:
# Predicting 1100 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    10 (10.0%)
#
# Example fails:
# Q: Which was the last amateur team to compete for the Canadian football championship?
# P: The Ontario Rugby Football Union
#
# Q: Which was the last amateur team to compete for the Canadian football championship?
# P: Ontario Rugby Football Union
# Perturb: Canada -> Ukraine
#
# Q: Which was the last amateur team to compete for the Canadian football championship?
# P: Ontario Rugby Football Union
# Perturb: Canada -> Thailand
#
#
# ----
# Q: Demotic speaking Greek refugees were placed where?
# P: Greek Isles and cities
#
# Q: Demotic speaking Greek refugees were placed where?
# P: the Greek Isles and cities
# Perturb: Greece -> Nepal
#
# Q: Demotic speaking Greek refugees were placed where?
# P: the Greek Isles and cities
# Perturb: Turkey -> Italy
#
#
# ----
# Q: After Estonia achieved independence what was made their state language?
# P: Estonian
#
# Q: After Mexico achieved independence what was made their state language?
# P: Estonian language
# Perturb: Estonia -> Mexico
#
# Q: After Mexico achieved independence what was made their state language?
# P: Estonian language
# Perturb: Estonia -> Mexico
#
#
# ----

# %% [markdown]
# ## Temporal

# %% [markdown]
# ### There was a change in profession

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            'Both {first_name} and {first_name2} were {prof1}s, but there was a change in {first_name}, who is now {a:prof2}.',
            'Both {first_name2} and {first_name} were {prof1}s, but there was a change in {first_name}, who is now {a:prof2}.',
        ],
        'qas': [
            (
                'Who is {a:prof2}?',
                '{first_name}'
            ), 
        ]
        
    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'There was a change in profession'
test = MFT(**t, expect=expect_squad, capability='Temporal', name=name, description='' )
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 200 examples
# Test cases:      485
# Test cases run:  100
# Fails (rate):    0 (0.0%)

# %% [markdown]
# ### Understanding before / after -> first / last.

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} became a {prof} before {first_name2} did.',
            '{first_name2} became a {prof} after {first_name} did.',
        ],
        'qas': [
            (
                'Who became a {prof} first?',
                '{first_name}'
            ), 
            (
                'Who became a {prof} last?',
                '{first_name2}'
            ), 
        ]
        
    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Understanding before / after -> first / last.'
test = MFT(**t, expect=expect_squad, capability='Temporal', name=name, description='' )
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      495
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Victoria became a editor before Pamela did.
# Q: Who became a editor first?
# A: Victoria
# P: Pamela
#
# C: Pamela became a editor after Victoria did.
# Q: Who became a editor first?
# A: Victoria
# P: Pamela
#
#
# ----
# C: Ian became a actress before Stephanie did.
# Q: Who became a actress last?
# A: Stephanie
# P: Ian
#
# C: Stephanie became a actress after Ian did.
# Q: Who became a actress first?
# A: Ian
# P: Stephanie
#
#
# ----
# C: Philip became a attorney before Jonathan did.
# Q: Who became a attorney last?
# A: Jonathan
# P: Philip
#
# C: Jonathan became a attorney after Philip did.
# Q: Who became a attorney last?
# A: Jonathan
# P: Philip
#
#
# ----

# %% [markdown]
# ## Negation

# %% [markdown]
# ### Negation in context, may or may not be in question

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is not {a:prof}. {first_name2} is.',
            '{first_name2} is {a:prof}. {first_name} is not.',
        ],
        'qas': [
            (
                'Who is {a:prof}?',
                '{first_name2}'
            ), 
            (
                'Who is not {a:prof}?',
                '{first_name}'
            ), 
        ]
        
    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Negation in context, may or may not be in question'
test = MFT(**t, expect=expect_squad, capability='Negation', name=name, description='' )
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      497
# Test cases run:  100
# Fails (rate):    92 (92.0%)
#
# Example fails:
# C: Amy is not an interpreter. Jean is.
# Q: Who is an interpreter?
# A: Jean
# P: Amy
#
#
# ----
# C: Martha is not a photographer. Jay is.
# Q: Who is a photographer?
# A: Jay
# P: Martha
#
#
# ----
# C: Sam is not an agent. Tom is.
# Q: Who is an agent?
# A: Tom
# P: Sam
#
#
# ----

# %% [markdown]
# ### Negation in question only.
# Not in context:

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} is {a:prof}. {first_name2} is {a:prof2}.',
            '{first_name2} is {a:prof2}. {first_name} is {a:prof}.',
        ],
        'qas': [
            (
                'Who is {a:prof}?',
                '{first_name}'
            ), 
            (
                'Who is not {a:prof}?',
                '{first_name2}'
            ), 
            (
                'Who is {a:prof2}?',
                '{first_name2}'
            ), 
            (
                'Who is not {a:prof2}?',
                '{first_name}'
            ), 
        ]
        
    },
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Negation in question only.'
test = MFT(**t, expect=expect_squad, capability='Negation', name=name, description='' )
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 800 examples
# Test cases:      486
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Lucy is an investigator. Edward is an escort.
# Q: Who is not an investigator?
# A: Edward
# P: Lucy
#
# C: Lucy is an investigator. Edward is an escort.
# Q: Who is not an escort?
# A: Lucy
# P: Edward
#
# C: Edward is an escort. Lucy is an investigator.
# Q: Who is not an investigator?
# A: Edward
# P: Lucy
#
#
# ----
# C: Thomas is an agent. Steven is a journalist.
# Q: Who is not an agent?
# A: Steven
# P: Thomas
#
# C: Thomas is an agent. Steven is a journalist.
# Q: Who is not a journalist?
# A: Thomas
# P: Steven
#
# C: Steven is a journalist. Thomas is an agent.
# Q: Who is not an agent?
# A: Steven
# P: Thomas
#
#
# ----
# C: Melissa is an interpreter. Catherine is a waitress.
# Q: Who is not an interpreter?
# A: Catherine
# P: Melissa
#
# C: Melissa is an interpreter. Catherine is a waitress.
# Q: Who is not a waitress?
# A: Melissa
# P: Catherine
#
# C: Catherine is a waitress. Melissa is an interpreter.
# Q: Who is not an interpreter?
# A: Catherine
# P: Melissa
#
#
# ----

# %% [markdown]
# ## Fairness spinoff

# %% [markdown]
# ### M/F failure rates should be similar for different professions

# %%
import collections
fewer_profs = ['doctor', 'nurse', 'secretary', 'CEO']
t = editor.template(
    [
        ('{male} is not {a:prof}, {female} is.', 'Who is {a:prof}?', '{female}', 'woman', '{prof}'),
        ('{female} is not {a:prof}, {male} is.', 'Who is {a:prof}?', '{male}', 'man', '{prof}'),
    ],
#     prof=professions + ['doctor'],
    prof=fewer_profs,
    remove_duplicates=True,
    nsamples=1000,
    unroll=True,
    save=True,
    )
data = [(d[0], d[1]) for d in t.data]
labels = [d[2] for d in t.data]
meta = [(d[3], d[4]) for d in t.data]

test = MFT(data, expect=expect_squad, labels=labels, meta=meta, templates=t.templates,
          name='M/F failure rates should be similar for different professions', capability='Fairness',
          description='Using negation in context.')
test.run(predconfs, n=100)

def print_fair(test):
    c = collections.Counter(test.meta)
    fail = collections.Counter([tuple(x) for x in np.array(test.meta)[test.fail_idxs()]])
    profs = set()
    for sex, prof in fail:
        profs.add(prof)
    prof_fail = {}
    get_fail = lambda f:fail[f] / c[f]
    for prof in profs:
        fail_m = get_fail(('man', prof))
        fail_f = get_fail(('woman', prof))
        prof_fail[prof] = (fail_m, fail_f)
    print('%-13s fail_men fail_women (count)' % 'profession')
    for prof, vs in sorted(prof_fail.items(), key=lambda x:max(x[1][0], x[1][1]), reverse=True):
        fail_m, fail_f = vs
        print('%-13s   %.1f      %.1f     (%d)' % (prof, 100 * fail_m, 100 * fail_f, c[('man', prof)]))
print_fair(test)
suite.add(test)
# Out:
# Predicting 100 examples
# profession    fail_men fail_women (count)
# doctor          5.2      5.6     (232)
# CEO             5.1      4.8     (294)
# secretary       3.0      4.2     (236)
# nurse           4.2      4.2     (238)

# %%
test.summary(format_example_fn=format_squad_with_context)
# Out:
# Test cases:      2000
# Test cases run:  100
# Fails (rate):    84 (84.0%)
#
# Example fails:
# C: Emma is not a CEO, Alfred is.
# Q: Who is a CEO?
# A: Alfred
# P: Emma
#
# ----
# C: John is not a nurse, Kate is.
# Q: Who is a nurse?
# A: Kate
# P: John
#
# ----
# C: Lisa is not a CEO, Benjamin is.
# Q: Who is a CEO?
# A: Benjamin
# P: Lisa
#
# ----

# %% [markdown]
# ## Coref

# %% [markdown]
# ### Basic coref, he / she

# %%
if 'actress' in professions:
    professions.remove('actress')

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{male} and {female} are friends. He is {a:prof1}, and she is {a:prof2}.',
            '{female} and {male} are friends. He is {a:prof1}, and she is {a:prof2}.',
            '{male} and {female} are friends. She is {a:prof2}, and he is {a:prof1}.',
            '{female} and {male} are friends. She is {a:prof2}, and he is {a:prof1}.',
        ],
        'qas': [
            (
                'Who is {a:prof1}?',
                '{male}'
            ), 
            (
                'Who is {a:prof2}?',
                '{female}'
            ), 
        ]
        
    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Basic coref, he / she'
test = MFT(**t, expect=expect_squad, name=name, description='', capability='Coref')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 800 examples
# Test cases:      488
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Kenneth and Betty are friends. He is an attorney, and she is an entrepreneur.
# Q: Who is an attorney?
# A: Kenneth
# P: Kenneth and Betty
#
# C: Kenneth and Betty are friends. He is an attorney, and she is an entrepreneur.
# Q: Who is an entrepreneur?
# A: Betty
# P: Kenneth and Betty
#
# C: Betty and Kenneth are friends. He is an attorney, and she is an entrepreneur.
# Q: Who is an attorney?
# A: Kenneth
# P: Betty and Kenneth
#
#
# ----
# C: Joseph and Nancy are friends. He is an editor, and she is an investigator.
# Q: Who is an editor?
# A: Joseph
# P: Joseph and Nancy
#
# C: Joseph and Nancy are friends. He is an editor, and she is an investigator.
# Q: Who is an investigator?
# A: Nancy
# P: Joseph and Nancy
#
# C: Nancy and Joseph are friends. He is an editor, and she is an investigator.
# Q: Who is an editor?
# A: Joseph
# P: Nancy and Joseph
#
#
# ----
# C: Lawrence and Amy are friends. He is an attorney, and she is an architect.
# Q: Who is an architect?
# A: Amy
# P: Lawrence
#
# C: Amy and Lawrence are friends. He is an attorney, and she is an architect.
# Q: Who is an attorney?
# A: Lawrence
# P: Amy and Lawrence
#
# C: Amy and Lawrence are friends. He is an attorney, and she is an architect.
# Q: Who is an architect?
# A: Amy
# P: Amy and Lawrence
#
#
# ----

# %% [markdown]
# ### Basic coref, his / her

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{male} and {female} are friends. His mom is {a:prof}.',
            '{female} and {male} are friends. His mom is {a:prof}.',
        ],
        'qas': [
            (
                'Whose mom is {a:prof}?',
                '{male}'
            ), 
        ]
        
    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=250,
    ))
t += crossproduct(editor.template(
    {
        'contexts': [
            '{male} and {female} are friends. Her mom is {a:prof}.',
            '{female} and {male} are friends. Her mom is {a:prof}.',
        ],
        'qas': [
            (
                'Whose mom is {a:prof}?',
                '{female}'
            ), 
        ]
        
    },
    save=True,
    prof=professions,
    remove_duplicates=True,
    nsamples=250,
    ))

name = 'Basic coref, his / her'
test = MFT(**t, expect=expect_squad, name=name, description='', capability='Coref')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 200 examples
# Test cases:      500
# Test cases run:  100
# Fails (rate):    94 (94.0%)
#
# Example fails:
# C: Lawrence and Evelyn are friends. Her mom is an educator.
# Q: Whose mom is an educator?
# A: Evelyn
# P: Lawrence and Evelyn
#
# C: Evelyn and Lawrence are friends. Her mom is an educator.
# Q: Whose mom is an educator?
# A: Evelyn
# P: Evelyn and Lawrence
#
#
# ----
# C: James and Grace are friends. Her mom is a model.
# Q: Whose mom is a model?
# A: Grace
# P: James and Grace
#
# C: Grace and James are friends. Her mom is a model.
# Q: Whose mom is a model?
# A: Grace
# P: Grace and James
#
#
# ----
# C: Arthur and Michelle are friends. His mom is an actor.
# Q: Whose mom is an actor?
# A: Arthur
# P: Arthur and Michelle
#
# C: Michelle and Arthur are friends. His mom is an actor.
# Q: Whose mom is an actor?
# A: Arthur
# P: Michelle and Arthur
#
#
# ----

# %% [markdown]
# ### Former / latter

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} and {first_name2} are friends. The former is {a:prof1}.',
            '{first_name2} and {first_name} are friends. The latter is {a:prof1}.',
            '{first_name} and {first_name2} are friends. The former is {a:prof1} and the latter is {a:prof2}.',
            '{first_name2} and {first_name} are friends. The former is {a:prof2} and the latter is {a:prof1}.',
        ],
        'qas': [
            (
                'Who is {a:prof1}?',
                '{first_name}'
            ), 
        ]
        
    },
    prof=professions,
    remove_duplicates=True,
    nsamples=500,
    save=True
    ))
name = 'Former / Latter'
test = MFT(**t, expect=expect_squad, name=name, description='', capability='Coref')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      485
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Catherine and Jim are friends. The former is an organizer.
# Q: Who is an organizer?
# A: Catherine
# P: Catherine and Jim
#
# C: Jim and Catherine are friends. The latter is an organizer.
# Q: Who is an organizer?
# A: Catherine
# P: Jim and Catherine
#
# C: Catherine and Jim are friends. The former is an organizer and the latter is an interpreter.
# Q: Who is an organizer?
# A: Catherine
# P: Catherine and Jim
#
#
# ----
# C: Alison and Frank are friends. The former is a model.
# Q: Who is a model?
# A: Alison
# P: Alison and Frank
#
# C: Frank and Alison are friends. The latter is a model.
# Q: Who is a model?
# A: Alison
# P: Frank and Alison
#
# C: Alison and Frank are friends. The former is a model and the latter is a nurse.
# Q: Who is a model?
# A: Alison
# P: Alison and Frank
#
#
# ----
# C: Jay and Keith are friends. The former is a producer.
# Q: Who is a producer?
# A: Jay
# P: Jay and Keith
#
# C: Keith and Jay are friends. The latter is a producer.
# Q: Who is a producer?
# A: Jay
# P: Keith and Jay
#
# C: Jay and Keith are friends. The former is a producer and the latter is an economist.
# Q: Who is a producer?
# A: Jay
# P: Jay and Keith
#
#
# ----

# %% [markdown]
# ## SRL
# Semantic Role Labelling

# %% [markdown]
# ### Agent / object distinction

# %%
import pattern
import pattern.en
pverb = ['love', 'hate', 'like', 'remember', 'recognize', 'trust', 'deserve', 'understand', 'blame', 'dislike', 'prefer', 'follow', 'notice', 'hurt', 'bother', 'support', 'believe', 'accept', 'attack']
a = pattern.en.tenses('loves')[0]
b = pattern.en.tenses('stolen')[0]
pverb = [(pattern.en.conjugate(v, *a), pattern.en.conjugate(v, *b)) for v in pverb]

t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} {v[0]} {first_name2}.',
            '{first_name2} is {v[1]} by {first_name}.',
        ],
        'qas': [
            (
                'Who {v[0]}?',
                '{first_name}'
            ), 
            (
                'Who is {v[1]}?',
                '{first_name2}'
            ), 
        ]
        
    },
    v=pverb,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Agent / object distinction'
test = MFT(**t, expect=expect_squad, name=name, description='', capability='SRL')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 400 examples
# Test cases:      499
# Test cases run:  100
# Fails (rate):    72 (72.0%)
#
# Example fails:
# C: Jonathan hurts Ann.
# Q: Who hurts?
# A: Jonathan
# P: Ann
#
# C: Ann is hurt by Jonathan.
# Q: Who hurts?
# A: Jonathan
# P: Ann
#
#
# ----
# C: David is preferred by Sally.
# Q: Who prefers?
# A: Sally
# P: David is preferred by Sally
#
#
# ----
# C: Caroline hates Nancy.
# Q: Who is hated?
# A: Nancy
# P: Caroline hates Nancy
#
# C: Nancy is hated by Caroline.
# Q: Who hates?
# A: Caroline
# P: Nancy is hated by Caroline
#
#
# ----

# %%
pattern.en.tenses('loves')[0]
# Out:
# ('present', 3, 'singular', 'indicative', 'imperfective')

# %% [markdown]
# ### Agent / object distinction with 3 agents

# %%
t = crossproduct(editor.template(
    {
        'contexts': [
            '{first_name} {v[0]} {first_name2}. {first_name2} {v[0]} {first_name3}.',
            '{first_name} {v[0]} {first_name2}. {first_name3} is {v[1]} by {first_name2}.',
            '{first_name2} is {v[1]} by {first_name}. {first_name2} {v[0]} {first_name3}.',
            '{first_name2} is {v[1]} by {first_name}. {first_name3} is {v[1]} by {first_name2}.',
        ],
        'qas': [
            (
                'Who {v[0]} {first_name2}?',
                '{first_name}'
            ), 
            (
                'Who {v[0]} {first_name3}?',
                '{first_name2}'
            ), 
            (
                'Who is {v[1]} by {first_name}?',
                '{first_name2}'
            ), 
            (
                'Who is {v[1]} by {first_name2}?',
                '{first_name3}'
            ), 
        ]
        
    },
    save=True,
    v=pverb,
    remove_duplicates=True,
    nsamples=500,
    ))
name = 'Agent / object distinction with 3 agents'
test = MFT(**t, expect=expect_squad, name=name, description='', capability='SRL')
test.run(predconfs, n=100)
test.summary(n=3, format_example_fn=format_squad_with_context)
suite.add(test)
# Out:
# Predicting 1600 examples
# Test cases:      495
# Test cases run:  100
# Fails (rate):    98 (98.0%)
#
# Example fails:
# C: Alan blames Jimmy. Jimmy blames Kevin.
# Q: Who is blamed by Alan?
# A: Jimmy
# P: Kevin
#
# C: Alan blames Jimmy. Kevin is blamed by Jimmy.
# Q: Who blames Kevin?
# A: Jimmy
# P: Alan
#
# C: Alan blames Jimmy. Kevin is blamed by Jimmy.
# Q: Who is blamed by Alan?
# A: Jimmy
# P: Kevin
#
#
# ----
# C: Edward prefers Rebecca. Rebecca prefers Judy.
# Q: Who prefers Judy?
# A: Rebecca
# P: Edward
#
# C: Edward prefers Rebecca. Judy is preferred by Rebecca.
# Q: Who prefers Judy?
# A: Rebecca
# P: Edward
#
# C: Edward prefers Rebecca. Judy is preferred by Rebecca.
# Q: Who is preferred by Edward?
# A: Rebecca
# P: Judy
#
#
# ----
# C: Julia follows Nicole. Nicole follows Marie.
# Q: Who follows Marie?
# A: Nicole
# P: Julia
#
# C: Julia follows Nicole. Nicole follows Marie.
# Q: Who is followed by Nicole?
# A: Marie
# P: Julia
#
# C: Julia follows Nicole. Marie is followed by Nicole.
# Q: Who follows Marie?
# A: Nicole
# P: Julia
#
#
# ----

# %%
path = 'squad_suite2.pkl'
suite.save(path)

# %%
suite.summary(n=3, format_example_fn=format_squad_with_context)
# Out:
# Vocabulary
#
# A is COMP than B. Who is more COMP?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    1 (1.0%)
#
# Example fails:
# C: Alison is faster than Sue.
# Q: Who is faster?
# A: Alison
# P: Alison is faster than Sue
#
# ----
#
#
# A is COMP than B. Who is less COMP?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    98 (98.0%)
#
# Example fails:
# C: Marilyn is happier than Ed.
# Q: Who is less happier?
# A: Ed
# P: Marilyn
#
# ----
# C: Susan is happier than Matt.
# Q: Who is less happier?
# A: Matt
# P: Susan
#
# ----
# C: Ed is thinner than Ann.
# Q: Who is less thinner?
# A: Ann
# P: Ed
#
# ----
#
#
# Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Evelyn is incredibly open about the project. Kathy is open about the project.
# Q: Who is most open about the project?
# A: Evelyn
# P: Kathy
#
# C: Evelyn is incredibly open about the project. Kathy is a little open about the project.
# Q: Who is most open about the project?
# A: Evelyn
# P: Kathy
#
# C: Evelyn is open about the project. Kathy is a little open about the project.
# Q: Who is most open about the project?
# A: Evelyn
# P: Kathy
#
#
# ----
# C: Ron is hopeful about the project. Steven is mildly hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Steven
# P: Ron
#
# C: Steven is hopeful about the project. Ron is super hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Steven
# P: Ron
#
# C: Ron is super hopeful about the project. Steven is mildly hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Steven
# P: Ron
#
#
# ----
# C: Carolyn is excited about the project. Katie is somewhat excited about the project.
# Q: Who is most excited about the project?
# A: Carolyn
# P: Katie
#
# C: Katie is somewhat excited about the project. Carolyn is excited about the project.
# Q: Who is least excited about the project?
# A: Katie
# P: Carolyn
#
# C: Katie is excited about the project. Carolyn is very excited about the project.
# Q: Who is least excited about the project?
# A: Katie
# P: Carolyn
#
#
# ----
#
#
#
#
# Taxonomy
#
# size, shape, age, color
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: There is a new green sculpture in the room.
# Q: What age is the sculpture?
# A: new
# P: green
#
# C: There is a sculpture in the room. The sculpture is new and green.
# Q: What age is the sculpture?
# A: new
# P: The sculpture is new and green
#
#
# ----
# C: There is a thing in the room. The thing is square and grey.
# Q: What shape is the thing?
# A: square
# P: square and grey
#
# C: There is a square grey thing in the room.
# Q: What shape is the thing?
# A: square
# P: square grey
#
# C: There is a square grey thing in the room.
# Q: What color is the thing?
# A: grey
# P: square grey
#
#
# ----
# C: There is an object in the room. The object is oval and yellow.
# Q: What shape is the object?
# A: oval
# P: oval and yellow
#
# C: There is an oval yellow object in the room.
# Q: What shape is the object?
# A: oval
# P: oval yellow
#
#
# ----
#
#
# Profession vs nationality
# Test cases:      500
# Test cases run:  100
# Fails (rate):    17 (17.0%)
#
# Example fails:
# C: Victoria is a Pakistani model.
# Q: What is Victoria's job?
# A: model
# P: Pakistani model
#
#
# ----
# C: Mike is a Chinese secretary.
# Q: What is Mike's job?
# A: secretary
# P: Chinese secretary
#
#
# ----
# C: Evelyn is a Japanese assistant.
# Q: What is Evelyn's job?
# A: assistant
# P: Japanese assistant
#
#
# ----
#
#
# Animal vs Vehicle
# Test cases:      500
# Test cases run:  100
# Fails (rate):    53 (53.0%)
#
# Example fails:
# C: Christopher has an iguana and a tractor.
# Q: What vehicle does Christopher have?
# A: tractor
# P: iguana and a tractor
#
#
# ----
# C: Jack has a dog and a train.
# Q: What vehicle does Jack have?
# A: train
# P: a dog and a train
#
#
# ----
# C: William has an iguana and a tractor.
# Q: What vehicle does William have?
# A: tractor
# P: iguana and a tractor
#
#
# ----
#
#
# Animal vs Vehicle v2
# Test cases:      498
# Test cases run:  100
# Fails (rate):    59 (59.0%)
#
# Example fails:
# C: Jennifer bought a tractor. Tom bought a guinea pig.
# Q: Who bought an animal?
# A: Tom
# P: Jennifer
#
#
# ----
# C: Kenneth bought a firetruck. Bobby bought a guinea pig.
# Q: Who bought an animal?
# A: Bobby
# P: Kenneth
#
#
# ----
# C: Mary bought a motorcycle. Don bought a serpent.
# Q: Who bought an animal?
# A: Don
# P: Mary bought a motorcycle. Don
#
#
# ----
#
#
# Synonyms
# Test cases:      449
# Test cases run:  100
# Fails (rate):    16 (16.0%)
#
# Example fails:
# C: Charles is very grateful. Greg is very happy.
# Q: Who is joyful?
# A: Greg
# P: Charles
#
# C: Greg is very happy. Charles is very grateful.
# Q: Who is joyful?
# A: Greg
# P: Charles
#
#
# ----
# C: Anna is very happy. Howard is very humble.
# Q: Who is joyful?
# A: Anna
# P: Howard
#
#
# ----
# C: Ben is very outspoken. Bruce is very thankful.
# Q: Who is vocal?
# A: Ben
# P: Bruce
#
# C: Bruce is very thankful. Ben is very outspoken.
# Q: Who is vocal?
# A: Ben
# P: Bruce
#
#
# ----
#
#
# A is COMP than B. Who is antonym(COMP)? B
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Christopher is smarter than Jim.
# Q: Who is dumber?
# A: Jim
# P: Christopher
#
# C: Jim is dumber than Christopher.
# Q: Who is dumber?
# A: Jim
# P: Christopher
#
#
# ----
# C: Kathleen is smarter than Ed.
# Q: Who is dumber?
# A: Ed
# P: Kathleen
#
# C: Ed is dumber than Kathleen.
# Q: Who is smarter?
# A: Kathleen
# P: Ed
#
#
# ----
# C: Jack is smaller than Jimmy.
# Q: Who is bigger?
# A: Jimmy
# P: Jack
#
# C: Jimmy is bigger than Jack.
# Q: Who is smaller?
# A: Jack
# P: Jimmy
#
#
# ----
#
#
# A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Bob is more active than Jay.
# Q: Who is more passive?
# A: Jay
# P: Bob
#
# C: Jay is more passive than Bob.
# Q: Who is less passive?
# A: Bob
# P: Jay
#
# C: Bob is more active than Jay.
# Q: Who is less active?
# A: Jay
# P: Bob
#
#
# ----
# C: Scott is less irresponsible than Samuel.
# Q: Who is more irresponsible?
# A: Samuel
# P: Scott
#
# C: Scott is less irresponsible than Samuel.
# Q: Who is less responsible?
# A: Samuel
# P: Scott
#
# C: Scott is more responsible than Samuel.
# Q: Who is less responsible?
# A: Samuel
# P: Scott
#
#
# ----
# C: Linda is more offensive than Charles.
# Q: Who is less offensive?
# A: Charles
# P: Linda
#
# C: Linda is more offensive than Charles.
# Q: Who is more defensive?
# A: Charles
# P: Linda
#
# C: Charles is more defensive than Linda.
# Q: Who is more offensive?
# A: Linda
# P: Charles
#
#
# ----
#
#
#
#
# Robustness
#
# Question typo
# Test cases:      500
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
# Example fails:
# C: The Taragaon Museum presents the modern history of the Kathmandu Valley. It seeks to document 50 years of research and cultural heritage conservation of the Kathmandu Valley, documenting what artists photographers architects anthropologists from abroad had contributed in the second half of the 20th century. The actual structure of the Museum showcases restoration and rehabilitation efforts to preserve the built heritage of Kathmandu. It was designed by Carl Pruscha (master-planner of the Kathmandy Valley ) in 1970 and constructed in 1971. Restoration works began in 2010 to rehabilitate the Taragaon hostel into the Taragaon Museum. The design uses local brick along with modern architectural design elements, as well as the use of circle, triangles and squares. The Museum is within a short walk from the Boudhnath stupa, which itself can be seen from the Museum tower.
# Q: What was the Taragaon Museum prior to being a museum?
# P: hostel
#
# C: The Taragaon Museum presents the modern history of the Kathmandu Valley. It seeks to document 50 years of research and cultural heritage conservation of the Kathmandu Valley, documenting what artists photographers architects anthropologists from abroad had contributed in the second half of the 20th century. The actual structure of the Museum showcases restoration and rehabilitation efforts to preserve the built heritage of Kathmandu. It was designed by Carl Pruscha (master-planner of the Kathmandy Valley ) in 1970 and constructed in 1971. Restoration works began in 2010 to rehabilitate the Taragaon hostel into the Taragaon Museum. The design uses local brick along with modern architectural design elements, as well as the use of circle, triangles and squares. The Museum is within a short walk from the Boudhnath stupa, which itself can be seen from the Museum tower.
# Q: What was the Taragaon Muesum prior to being a museum?
# P: Taragaon hostel
#
#
# ----
# C: The Communist Party of China, founded in 1920, adopted the red flag and hammer and sickle emblem of the Soviet Union, which became the national symbols when the Party took power in China in 1949. Under Party leader Mao Zedong, the Party anthem became "The East Is Red", and Mao Zedong himself was sometimes referred to as a "red sun". During the Cultural Revolution in China, Party ideology was enforced by the Red Guards, and the sayings of Mao Zedong were published as a small red book in hundreds of millions of copies. Today the Communist Party of China claims to be the largest political party in the world, with eighty million members.
# Q: In terms of the Communist Party of China, what is "The East is Red?"
# P: Party anthem
#
# C: The Communist Party of China, founded in 1920, adopted the red flag and hammer and sickle emblem of the Soviet Union, which became the national symbols when the Party took power in China in 1949. Under Party leader Mao Zedong, the Party anthem became "The East Is Red", and Mao Zedong himself was sometimes referred to as a "red sun". During the Cultural Revolution in China, Party ideology was enforced by the Red Guards, and the sayings of Mao Zedong were published as a small red book in hundreds of millions of copies. Today the Communist Party of China claims to be the largest political party in the world, with eighty million members.
# Q: In terms of the Communist Party o fChina, what is "The East is Red?"
# P: the Party anthem
#
#
# ----
# C: Windows 8 introduces a new style of application, Windows Store apps. According to Microsoft developer Jensen Harris, these apps are to be optimized for touchscreen environments and are more specialized than current desktop applications. Apps can run either in a full-screen mode, or be snapped to the side of a screen. Apps can provide toast notifications on screen or animate their tiles on the Start screen with dynamic content. Apps can use "contracts"; a collection of hooks to provide common functionality that can integrate with other apps, including search and sharing. Apps can also provide integration with other services; for example, the People app can connect to a variety of different social networks and services (such as Facebook, Skype, and People service), while the Photos app can aggregate photos from services such as Facebook and Flickr.
# Q: What apps can one expect the People app to match with?
# P: Facebook, Skype, and People service
#
# C: Windows 8 introduces a new style of application, Windows Store apps. According to Microsoft developer Jensen Harris, these apps are to be optimized for touchscreen environments and are more specialized than current desktop applications. Apps can run either in a full-screen mode, or be snapped to the side of a screen. Apps can provide toast notifications on screen or animate their tiles on the Start screen with dynamic content. Apps can use "contracts"; a collection of hooks to provide common functionality that can integrate with other apps, including search and sharing. Apps can also provide integration with other services; for example, the People app can connect to a variety of different social networks and services (such as Facebook, Skype, and People service), while the Photos app can aggregate photos from services such as Facebook and Flickr.
# Q: What apps can one expect the Peopel app to match with?
# P: Photos app can aggregate photos from services such as Facebook and Flickr
#
#
# ----
#
#
# Question contractions
# Test cases:      500
# Test cases run:  100
# Fails (rate):    10 (10.0%)
#
# Example fails:
# C: In many countries, national and regional poultry shows are held where enthusiasts exhibit their birds which are judged on certain phenotypical breed traits as specified by their respective breed standards. The idea of poultry exhibition may have originated after cockfighting was made illegal, as a way of maintaining a competitive element in poultry husbandry. Breed standards were drawn up for egg-laying, meat-type, and purely ornamental birds, aiming for uniformity. Sometimes, poultry shows are part of general livestock shows, and sometimes they are separate events such as the annual "National Championship Show" in the United Kingdom organised by the Poultry Club of Great Britain.
# Q: In such competitions what are the chickens juged on? What attibutes are considered viable?
# P: certain phenotypical breed traits
#
# C: In many countries, national and regional poultry shows are held where enthusiasts exhibit their birds which are judged on certain phenotypical breed traits as specified by their respective breed standards. The idea of poultry exhibition may have originated after cockfighting was made illegal, as a way of maintaining a competitive element in poultry husbandry. Breed standards were drawn up for egg-laying, meat-type, and purely ornamental birds, aiming for uniformity. Sometimes, poultry shows are part of general livestock shows, and sometimes they are separate events such as the annual "National Championship Show" in the United Kingdom organised by the Poultry Club of Great Britain.
# Q: In such competitions what're the chickens juged on? What attibutes are considered viable?
# P: certain phenotypical breed traits as specified by their respective breed standards
#
#
# ----
# C: Plants depend on certain edaphic (soil) and climatic factors in their environment but can modify these factors too. For example, they can change their environment's albedo, increase runoff interception, stabilize mineral soils and develop their organic content, and affect local temperature. Plants compete with other organisms in their ecosystem for resources. They interact with their neighbours at a variety of spatial scales in groups, populations and communities that collectively constitute vegetation. Regions with characteristic vegetation types and dominant plants as well as similar abiotic and biotic factors, climate, and geography make up biomes like tundra or tropical rainforest.
# Q: What are groupings of similar plants?
# P: biomes
#
# C: Plants depend on certain edaphic (soil) and climatic factors in their environment but can modify these factors too. For example, they can change their environment's albedo, increase runoff interception, stabilize mineral soils and develop their organic content, and affect local temperature. Plants compete with other organisms in their ecosystem for resources. They interact with their neighbours at a variety of spatial scales in groups, populations and communities that collectively constitute vegetation. Regions with characteristic vegetation types and dominant plants as well as similar abiotic and biotic factors, climate, and geography make up biomes like tundra or tropical rainforest.
# Q: What're groupings of similar plants?
# P: biomes like tundra or tropical rainforest
#
#
# ----
# C: The Arabian oryx, a species of large antelope, once inhabited much of the desert areas of the Middle East. However, the species' striking appearance made it (along with the closely related scimitar-horned oryx and addax) a popular quarry for sport hunters, especially foreign executives of oil companies working in the region.[citation needed] The use of automobiles and high-powered rifles destroyed their only advantage: speed, and they became extinct in the wild exclusively due to sport hunting in 1972. The scimitar-horned oryx followed suit, while the addax became critically endangered. However, the Arabian oryx has now made a comeback and been upgraded from “extinct in the wild” to “vulnerable” due to conservation efforts like captive breeding
# Q: What is a species of large antelope?
# P: Arabian oryx
#
# C: The Arabian oryx, a species of large antelope, once inhabited much of the desert areas of the Middle East. However, the species' striking appearance made it (along with the closely related scimitar-horned oryx and addax) a popular quarry for sport hunters, especially foreign executives of oil companies working in the region.[citation needed] The use of automobiles and high-powered rifles destroyed their only advantage: speed, and they became extinct in the wild exclusively due to sport hunting in 1972. The scimitar-horned oryx followed suit, while the addax became critically endangered. However, the Arabian oryx has now made a comeback and been upgraded from “extinct in the wild” to “vulnerable” due to conservation efforts like captive breeding
# Q: What's a species of large antelope?
# P: The Arabian oryx
#
#
# ----
#
#
# Add random sentence to context
# Test cases:      500
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
# Example fails:
# C: Since playing Pong while filming Jaws in 1974, Spielberg has been an avid video gamer. Spielberg played many of LucasArts adventure games, including the first Monkey Island games. He owns a Wii, a PlayStation 3, a PSP, and Xbox 360, and enjoys playing first-person shooters such as the Medal of Honor series and Call of Duty 4: Modern Warfare. He has also criticized the use of cut scenes in games, calling them intrusive, and feels making story flow naturally into the gameplay is a challenge for future game developers.
# Q: What game consoles does Spielberg own?
# P: a Wii, a PlayStation 3, a PSP, and Xbox 360
#
# C: Tibet continued as a Central Asian empire until the mid-9th century, when a civil war over succession led to the collapse of imperial Tibet. Since playing Pong while filming Jaws in 1974, Spielberg has been an avid video gamer. Spielberg played many of LucasArts adventure games, including the first Monkey Island games. He owns a Wii, a PlayStation 3, a PSP, and Xbox 360, and enjoys playing first-person shooters such as the Medal of Honor series and Call of Duty 4: Modern Warfare. He has also criticized the use of cut scenes in games, calling them intrusive, and feels making story flow naturally into the gameplay is a challenge for future game developers.
# Q: What game consoles does Spielberg own?
# P: Wii, a PlayStation 3, a PSP, and Xbox 360
#
#
# ----
# C: The abdomen is the largest tagma of the insect, which typically consists of 11–12 segments and is less strongly sclerotized than the head or thorax. Each segment of the abdomen is represented by a sclerotized tergum and sternum. Terga are separated from each other and from the adjacent sterna or pleura by membranes. Spiracles are located in the pleural area. Variation of this ground plan includes the fusion of terga or terga and sterna to form continuous dorsal or ventral shields or a conical tube. Some insects bear a sclerite in the pleural area called a laterotergite. Ventral sclerites are sometimes called laterosternites. During the embryonic stage of many insects and the postembryonic stage of primitive insects, 11 abdominal segments are present. In modern insects there is a tendency toward reduction in the number of the abdominal segments, but the primitive number of 11 is maintained during embryogenesis. Variation in abdominal segment number is considerable. If the Apterygota are considered to be indicative of the ground plan for pterygotes, confusion reigns: adult Protura have 12 segments, Collembola have 6. The orthopteran family Acrididae has 11 segments, and a fossil specimen of Zoraptera has a 10-segmented abdomen.
# Q: What is the largest tagma of an insect?
# P: abdomen
#
# C: Railroads sold their land at cheap rates to immigrants in expectation they would generate traffic as soon as farms were established. The abdomen is the largest tagma of the insect, which typically consists of 11–12 segments and is less strongly sclerotized than the head or thorax. Each segment of the abdomen is represented by a sclerotized tergum and sternum. Terga are separated from each other and from the adjacent sterna or pleura by membranes. Spiracles are located in the pleural area. Variation of this ground plan includes the fusion of terga or terga and sterna to form continuous dorsal or ventral shields or a conical tube. Some insects bear a sclerite in the pleural area called a laterotergite. Ventral sclerites are sometimes called laterosternites. During the embryonic stage of many insects and the postembryonic stage of primitive insects, 11 abdominal segments are present. In modern insects there is a tendency toward reduction in the number of the abdominal segments, but the primitive number of 11 is maintained during embryogenesis. Variation in abdominal segment number is considerable. If the Apterygota are considered to be indicative of the ground plan for pterygotes, confusion reigns: adult Protura have 12 segments, Collembola have 6. The orthopteran family Acrididae has 11 segments, and a fossil specimen of Zoraptera has a 10-segmented abdomen.
# Q: What is the largest tagma of an insect?
# P: The abdomen
#
# C: The abdomen is the largest tagma of the insect, which typically consists of 11–12 segments and is less strongly sclerotized than the head or thorax. Each segment of the abdomen is represented by a sclerotized tergum and sternum. Terga are separated from each other and from the adjacent sterna or pleura by membranes. Spiracles are located in the pleural area. Variation of this ground plan includes the fusion of terga or terga and sterna to form continuous dorsal or ventral shields or a conical tube. Some insects bear a sclerite in the pleural area called a laterotergite. Ventral sclerites are sometimes called laterosternites. During the embryonic stage of many insects and the postembryonic stage of primitive insects, 11 abdominal segments are present. In modern insects there is a tendency toward reduction in the number of the abdominal segments, but the primitive number of 11 is maintained during embryogenesis. Variation in abdominal segment number is considerable. If the Apterygota are considered to be indicative of the ground plan for pterygotes, confusion reigns: adult Protura have 12 segments, Collembola have 6. The orthopteran family Acrididae has 11 segments, and a fossil specimen of Zoraptera has a 10-segmented abdomen.Railroads sold their land at cheap rates to immigrants in expectation they would generate traffic as soon as farms were established.
# Q: What is the largest tagma of an insect?
# P: The abdomen
#
#
# ----
# C: During the 1960s, the ceremony of assenting by commission was discontinued and is now only employed once a year, at the end of the annual parliamentary session. In 1960, the Gentleman Usher of the Black Rod arrived to summon the House of Commons during a heated debate and several members protested against the disruption by refusing to attend the ceremony. The debacle was repeated in 1965; this time, when the Speaker left the chair to go to the House of Lords, some members continued to make speeches. As a result, the Royal Assent Act 1967 was passed, creating an additional form for the granting of royal assent. As the attorney-general explained, "there has been a good deal of resentment not only at the loss of Parliamentary time that has been involved but at the breaking of the thread of a possibly eloquent speech and the disruption of a debate that may be caused." The granting of assent by the monarch in person, or by commission, is still possible, but this third form is used on a day-to-day basis.
# Q: When does assention by commission occur today?
# P: once a year, at the end of the annual parliamentary session
#
# C: Franz von Juraschek was a leading economist in Austria-Hungary and a close friend of Eugen Böhm von Bawerk, one of the founders of the Austrian School of Economics. During the 1960s, the ceremony of assenting by commission was discontinued and is now only employed once a year, at the end of the annual parliamentary session. In 1960, the Gentleman Usher of the Black Rod arrived to summon the House of Commons during a heated debate and several members protested against the disruption by refusing to attend the ceremony. The debacle was repeated in 1965; this time, when the Speaker left the chair to go to the House of Lords, some members continued to make speeches. As a result, the Royal Assent Act 1967 was passed, creating an additional form for the granting of royal assent. As the attorney-general explained, "there has been a good deal of resentment not only at the loss of Parliamentary time that has been involved but at the breaking of the thread of a possibly eloquent speech and the disruption of a debate that may be caused." The granting of assent by the monarch in person, or by commission, is still possible, but this third form is used on a day-to-day basis.
# Q: When does assention by commission occur today?
# P: once a year
#
#
# ----
#
#
#
#
# NER
#
# Change name everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    2 (2.0%)
#
# Example fails:
# C: Following the fall of Wu and the turmoil of the Wu Hu uprising against the Jin dynasty (265–420), most of elite Chinese families had collaborated with the non-Chinese rulers and military conquerors in the north. Some may have lost social privilege, and took refugee in areas south to Yangtze River. Some of the Chinese refugees from north China might have resided in areas near Hangzhou. For example, the clan of Zhuge Liang (181–234), a chancellor of the state of Shu Han from Central Plain in north China during the Three Kingdoms period, gathered together at the suburb of Hangzhou, forming an exclusive, closed village Zhuge Village (Zhege Cun), consisting of villagers all with family name "Zhuge". The village has intentionally isolated itself from the surrounding communities for centuries to this day, and only recently came to be known in public. It suggests that a small number of powerful, elite Chinese refugees from the Central Plain might have taken refugee in south of the Yangtze River. However, considering the mountainous geography and relative lack of agrarian lands in Zhejiang, most of these refugees might have resided in some areas in south China beyond Zhejiang, where fertile agrarian lands and metropolitan resources were available, mainly north Jiangsu, west Fujian, Jiangxi, Hunan, Anhui,and provinces where less cohesive, organized regional governments had been in place. Metropolitan areas of Sichuan was another hub for refugees, given that the state of Shu had long been founded and ruled by political and military elites from the Central Plain and north China. Some refugees from the north China might have found residence in south China depending on their social status and military power in the north. The rump Jin state or the Southern Dynasties vied against some elite Chinese from the Central Plain and south of the Yangtze River.
# Q: Where did the clan of Zhuge Liang gather together?
# P: the suburb of Hangzhou
#
# C: Following the fall of Wu and the turmoil of the Wu Hu uprising against the Aaron dynasty (265–420), most of elite Chinese families had collaborated with the non-Chinese rulers and military conquerors in the north. Some may have lost social privilege, and took refugee in areas south to Yangtze River. Some of the Chinese refugees from north China might have resided in areas near Hangzhou. For example, the clan of Zhuge Liang (181–234), a chancellor of the state of Shu Han from Central Plain in north China during the Three Kingdoms period, gathered together at the suburb of Hangzhou, forming an exclusive, closed village Zhuge Village (Zhege Cun), consisting of villagers all with family name "Zhuge". The village has intentionally isolated itself from the surrounding communities for centuries to this day, and only recently came to be known in public. It suggests that a small number of powerful, elite Chinese refugees from the Central Plain might have taken refugee in south of the Yangtze River. However, considering the mountainous geography and relative lack of agrarian lands in Zhejiang, most of these refugees might have resided in some areas in south China beyond Zhejiang, where fertile agrarian lands and metropolitan resources were available, mainly north Jiangsu, west Fujian, Jiangxi, Hunan, Anhui,and provinces where less cohesive, organized regional governments had been in place. Metropolitan areas of Sichuan was another hub for refugees, given that the state of Shu had long been founded and ruled by political and military elites from the Central Plain and north China. Some refugees from the north China might have found residence in south China depending on their social status and military power in the north. The rump Aaron state or the Southern Dynasties vied against some elite Chinese from the Central Plain and south of the Yangtze River.
# Q: Where did the clan of Zhuge Liang gather together?
# P: Hangzhou
#
# C: Following the fall of Wu and the turmoil of the Wu Hu uprising against the Liam dynasty (265–420), most of elite Chinese families had collaborated with the non-Chinese rulers and military conquerors in the north. Some may have lost social privilege, and took refugee in areas south to Yangtze River. Some of the Chinese refugees from north China might have resided in areas near Hangzhou. For example, the clan of Zhuge Liang (181–234), a chancellor of the state of Shu Han from Central Plain in north China during the Three Kingdoms period, gathered together at the suburb of Hangzhou, forming an exclusive, closed village Zhuge Village (Zhege Cun), consisting of villagers all with family name "Zhuge". The village has intentionally isolated itself from the surrounding communities for centuries to this day, and only recently came to be known in public. It suggests that a small number of powerful, elite Chinese refugees from the Central Plain might have taken refugee in south of the Yangtze River. However, considering the mountainous geography and relative lack of agrarian lands in Zhejiang, most of these refugees might have resided in some areas in south China beyond Zhejiang, where fertile agrarian lands and metropolitan resources were available, mainly north Jiangsu, west Fujian, Jiangxi, Hunan, Anhui,and provinces where less cohesive, organized regional governments had been in place. Metropolitan areas of Sichuan was another hub for refugees, given that the state of Shu had long been founded and ruled by political and military elites from the Central Plain and north China. Some refugees from the north China might have found residence in south China depending on their social status and military power in the north. The rump Liam state or the Southern Dynasties vied against some elite Chinese from the Central Plain and south of the Yangtze River.
# Q: Where did the clan of Zhuge Liang gather together?
# P: Hangzhou
#
#
# ----
# C: The thermionic triode, a vacuum tube invented in 1907, enabled amplified radio technology and long-distance telephony. The triode, however, was a fragile device that consumed a lot of power. Physicist Julius Edgar Lilienfeld filed a patent for a field-effect transistor (FET) in Canada in 1925, which was intended to be a solid-state replacement for the triode. Lilienfeld also filed identical patents in the United States in 1926 and 1928. However, Lilienfeld did not publish any research articles about his devices nor did his patents cite any specific examples of a working prototype. Because the production of high-quality semiconductor materials was still decades away, Lilienfeld's solid-state amplifier ideas would not have found practical use in the 1920s and 1930s, even if such a device had been built. In 1934, German inventor Oskar Heil patented a similar device.
# Q: Where did Lilienfeld file his patent?
# P: Canada
#
# C: The thermionic triode, a vacuum tube invented in 1907, enabled amplified radio technology and long-distance telephony. The triode, however, was a fragile device that consumed a lot of power. Physicist Christopher Thompson filed a patent for a field-effect transistor (FET) in Canada in 1925, which was intended to be a solid-state replacement for the triode. Lilienfeld also filed identical patents in the United States in 1926 and 1928. However, Lilienfeld did not publish any research articles about his devices nor did his patents cite any specific examples of a working prototype. Because the production of high-quality semiconductor materials was still decades away, Lilienfeld's solid-state amplifier ideas would not have found practical use in the 1920s and 1930s, even if such a device had been built. In 1934, German inventor Oskar Heil patented a similar device.
# Q: Where did Lilienfeld file his patent?
# P: United States
#
# C: The thermionic triode, a vacuum tube invented in 1907, enabled amplified radio technology and long-distance telephony. The triode, however, was a fragile device that consumed a lot of power. Physicist David Bell filed a patent for a field-effect transistor (FET) in Canada in 1925, which was intended to be a solid-state replacement for the triode. Lilienfeld also filed identical patents in the United States in 1926 and 1928. However, Lilienfeld did not publish any research articles about his devices nor did his patents cite any specific examples of a working prototype. Because the production of high-quality semiconductor materials was still decades away, Lilienfeld's solid-state amplifier ideas would not have found practical use in the 1920s and 1930s, even if such a device had been built. In 1934, German inventor Oskar Heil patented a similar device.
# Q: Where did Lilienfeld file his patent?
# P: United States
#
#
# ----
#
#
# Change location everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    6 (6.0%)
#
# Example fails:
# C: The origins of al-Qaeda can be traced to the Soviet war in Afghanistan (December 1979 – February 1989). The United States, United Kingdom, Saudi Arabia, Pakistan, and the People's Republic of China supported the Islamist Afghan mujahadeen guerillas against the military forces of the Soviet Union and the Democratic Republic of Afghanistan. A small number of "Afghan Arab" volunteers joined the fight against the Soviets, including Osama bin Laden, but there is no evidence they received any external assistance. In May 1996 the group World Islamic Front for Jihad Against Jews and Crusaders (WIFJAJC), sponsored by bin Laden (and later re-formed as al-Qaeda), started forming a large base of operations in Afghanistan, where the Islamist extremist regime of the Taliban had seized power earlier in the year. In February 1998, Osama bin Laden signed a fatwā, as head of al-Qaeda, declaring war on the West and Israel, later in May of that same year al-Qaeda released a video declaring war on the U.S. and the West.
# Q: When did the Soviets leave Afghanistan?
# P: February 1989
#
# C: The origins of al-Qaeda can be traced to the Soviet war in Uzbekistan (December 1979 – February 1989). The United States, United Kingdom, Saudi Arabia, Pakistan, and the People's Republic of China supported the Islamist Afghan mujahadeen guerillas against the military forces of the Soviet Union and the Democratic Republic of Uzbekistan. A small number of "Afghan Arab" volunteers joined the fight against the Soviets, including Osama bin Laden, but there is no evidence they received any external assistance. In May 1996 the group World Islamic Front for Jihad Against Jews and Crusaders (WIFJAJC), sponsored by bin Laden (and later re-formed as al-Qaeda), started forming a large base of operations in Uzbekistan, where the Islamist extremist regime of the Taliban had seized power earlier in the year. In February 1998, Osama bin Laden signed a fatwā, as head of al-Qaeda, declaring war on the West and Israel, later in May of that same year al-Qaeda released a video declaring war on the U.S. and the West.
# Q: When did the Soviets leave Uzbekistan?
# P: December 1979 – February 1989
#
#
# ----
# C: From its origins in the fur trade, the Hudson's Bay Company is the oldest corporation in North America and was the largest department store operator in Canada until the mid-1980s, with locations across the country. It also previously owned Zellers, another major Canadian department store which ceased to exist in March 2013 after selling its lease holdings to Target Canada. Other department stores in Canada are: Canadian Tire, Sears Canada, Ogilvy, Les Ailes de la Mode, Giant Tiger, Co-op, Costco and Holt Renfrew. Grocery giant Superstores carry many non-grocery items akin to a department store. Woolco had 160 stores in Canada when operations ceased (Walmart bought out Woolco in 1994). Today low-price Walmart is by far the most dominant department store retailer in Canada with outlets throughout the country. Historically, department stores were a significant component in Canadian economic life, and chain stores such as Eaton's, Charles Ogilvy Limited, Freiman's, Spencer's, Simpsons, Morgan's, and Woodward's were staples in their respective communities. Department stores in Canada are similar in design and style to department stores in the United States.
# Q: Currently, what department store is most popular in Canada?
# P: Walmart
#
# C: From its origins in the fur trade, the Hudson's Bay Company is the oldest corporation in North America and was the largest department store operator in Russian Federation until the mid-1980s, with locations across the country. It also previously owned Zellers, another major Canadian department store which ceased to exist in March 2013 after selling its lease holdings to Target Russian Federation. Other department stores in Russian Federation are: Canadian Tire, Sears Russian Federation, Ogilvy, Les Ailes de la Mode, Giant Tiger, Co-op, Costco and Holt Renfrew. Grocery giant Superstores carry many non-grocery items akin to a department store. Woolco had 160 stores in Russian Federation when operations ceased (Walmart bought out Woolco in 1994). Today low-price Walmart is by far the most dominant department store retailer in Russian Federation with outlets throughout the country. Historically, department stores were a significant component in Canadian economic life, and chain stores such as Eaton's, Charles Ogilvy Limited, Freiman's, Spencer's, Simpsons, Morgan's, and Woodward's were staples in their respective communities. Department stores in Russian Federation are similar in design and style to department stores in the United States.
# Q: Currently, what department store is most popular in Russian Federation?
# P: low-price Walmart
#
# C: From its origins in the fur trade, the Hudson's Bay Company is the oldest corporation in North America and was the largest department store operator in Saudi Arabia until the mid-1980s, with locations across the country. It also previously owned Zellers, another major Canadian department store which ceased to exist in March 2013 after selling its lease holdings to Target Saudi Arabia. Other department stores in Saudi Arabia are: Canadian Tire, Sears Saudi Arabia, Ogilvy, Les Ailes de la Mode, Giant Tiger, Co-op, Costco and Holt Renfrew. Grocery giant Superstores carry many non-grocery items akin to a department store. Woolco had 160 stores in Saudi Arabia when operations ceased (Walmart bought out Woolco in 1994). Today low-price Walmart is by far the most dominant department store retailer in Saudi Arabia with outlets throughout the country. Historically, department stores were a significant component in Canadian economic life, and chain stores such as Eaton's, Charles Ogilvy Limited, Freiman's, Spencer's, Simpsons, Morgan's, and Woodward's were staples in their respective communities. Department stores in Saudi Arabia are similar in design and style to department stores in the United States.
# Q: Currently, what department store is most popular in Saudi Arabia?
# P: low-price Walmart
#
#
# ----
# C: In 1976, Walter Fiers at the University of Ghent (Belgium) was the first to establish the complete nucleotide sequence of a viral RNA-genome (Bacteriophage MS2). The next year Fred Sanger completed the first DNA-genome sequence: Phage Φ-X174, of 5386 base pairs. The first complete genome sequences among all three domains of life were released within a short period during the mid-1990s: The first bacterial genome to be sequenced was that of Haemophilus influenzae, completed by a team at The Institute for Genomic Research in 1995. A few months later, the first eukaryotic genome was completed, with sequences of the 16 chromosomes of budding yeast Saccharomyces cerevisiae published as the result of a European-led effort begun in the mid-1980s. The first genome sequence for an archaeon, Methanococcus jannaschii, was completed in 1996, again by The Institute for Genomic Research.
# Q: What organization first sequenced a bacterial genome?
# P: Institute for Genomic Research
#
# C: In 1976, Walter Fiers at the University of Ghent (Sudan) was the first to establish the complete nucleotide sequence of a viral RNA-genome (Bacteriophage MS2). The next year Fred Sanger completed the first DNA-genome sequence: Phage Φ-X174, of 5386 base pairs. The first complete genome sequences among all three domains of life were released within a short period during the mid-1990s: The first bacterial genome to be sequenced was that of Haemophilus influenzae, completed by a team at The Institute for Genomic Research in 1995. A few months later, the first eukaryotic genome was completed, with sequences of the 16 chromosomes of budding yeast Saccharomyces cerevisiae published as the result of a European-led effort begun in the mid-1980s. The first genome sequence for an archaeon, Methanococcus jannaschii, was completed in 1996, again by The Institute for Genomic Research.
# Q: What organization first sequenced a bacterial genome?
# P: The Institute for Genomic Research
#
# C: In 1976, Walter Fiers at the University of Ghent (Afghanistan) was the first to establish the complete nucleotide sequence of a viral RNA-genome (Bacteriophage MS2). The next year Fred Sanger completed the first DNA-genome sequence: Phage Φ-X174, of 5386 base pairs. The first complete genome sequences among all three domains of life were released within a short period during the mid-1990s: The first bacterial genome to be sequenced was that of Haemophilus influenzae, completed by a team at The Institute for Genomic Research in 1995. A few months later, the first eukaryotic genome was completed, with sequences of the 16 chromosomes of budding yeast Saccharomyces cerevisiae published as the result of a European-led effort begun in the mid-1980s. The first genome sequence for an archaeon, Methanococcus jannaschii, was completed in 1996, again by The Institute for Genomic Research.
# Q: What organization first sequenced a bacterial genome?
# P: The Institute for Genomic Research
#
#
# ----
#
#
#
#
# Fairness
#
# M/F failure rates should be similar for different professions
# Test cases:      2000
# Test cases run:  100
# Fails (rate):    86 (86.0%)
#
# Example fails:
# C: Al is not a nurse, Helen is.
# Q: Who is a nurse?
# A: Helen
# P: Al
#
# ----
# C: Michael is not a secretary, Marilyn is.
# Q: Who is a secretary?
# A: Marilyn
# P: Michael
#
# ----
# C: Frank is not a doctor, Lucy is.
# Q: Who is a doctor?
# A: Lucy
# P: Frank
#
# ----
#
#
#
#
# Temporal
#
# There was a change in profession
# Test cases:      488
# Test cases run:  100
# Fails (rate):    2 (2.0%)
#
# Example fails:
# C: Both Linda and Bobby were models, but there was a change in Bobby, who is now an actress.
# Q: Who is an actress?
# A: Bobby
# P: Linda and Bobby
#
#
# ----
# C: Both Ryan and Jill were analysts, but there was a change in Jill, who is now an author.
# Q: Who is an author?
# A: Jill
# P: Ryan and Jill
#
#
# ----
#
#
# Understanding before / after -> first / last.
# Test cases:      499
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Cynthia became a economist before William did.
# Q: Who became a economist last?
# A: William
# P: Cynthia
#
# C: William became a economist after Cynthia did.
# Q: Who became a economist first?
# A: Cynthia
# P: William
#
#
# ----
# C: Mark became a actress before Victoria did.
# Q: Who became a actress last?
# A: Victoria
# P: Mark
#
# C: Victoria became a actress after Mark did.
# Q: Who became a actress first?
# A: Mark
# P: Victoria
#
#
# ----
# C: Samuel became a DJ before Maria did.
# Q: Who became a DJ first?
# A: Samuel
# P: Maria
#
# C: Samuel became a DJ before Maria did.
# Q: Who became a DJ last?
# A: Maria
# P: Samuel
#
# C: Maria became a DJ after Samuel did.
# Q: Who became a DJ first?
# A: Samuel
# P: Maria
#
#
# ----
#
#
#
#
# Negation
#
# Negation in context, may or may not be in question
# Test cases:      495
# Test cases run:  100
# Fails (rate):    96 (96.0%)
#
# Example fails:
# C: Carol is not a journalist. Jessica is.
# Q: Who is a journalist?
# A: Jessica
# P: Carol
#
#
# ----
# C: Dave is not an engineer. Adam is.
# Q: Who is an engineer?
# A: Adam
# P: Dave
#
#
# ----
# C: Katherine is not an economist. Alison is.
# Q: Who is an economist?
# A: Alison
# P: Katherine
#
#
# ----
#
#
# Negation in question only.
# Test cases:      486
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Anna is a reporter. Larry is an artist.
# Q: Who is not a reporter?
# A: Larry
# P: Anna
#
# C: Anna is a reporter. Larry is an artist.
# Q: Who is not an artist?
# A: Anna
# P: Larry
#
# C: Larry is an artist. Anna is a reporter.
# Q: Who is not a reporter?
# A: Larry
# P: Anna
#
#
# ----
# C: Tom is an administrator. Jeff is a photographer.
# Q: Who is not an administrator?
# A: Jeff
# P: Tom
#
# C: Tom is an administrator. Jeff is a photographer.
# Q: Who is not a photographer?
# A: Tom
# P: Jeff
#
# C: Jeff is a photographer. Tom is an administrator.
# Q: Who is not an administrator?
# A: Jeff
# P: Tom
#
#
# ----
# C: Anne is an executive. Bob is an educator.
# Q: Who is not an executive?
# A: Bob
# P: Anne
#
# C: Anne is an executive. Bob is an educator.
# Q: Who is not an educator?
# A: Anne
# P: Bob
#
# C: Bob is an educator. Anne is an executive.
# Q: Who is not an executive?
# A: Bob
# P: Anne
#
#
# ----
#
#
#
#
# Coref
#
# Basic coref, he / she
# Test cases:      486
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Martin and Kathryn are friends. He is a reporter, and she is an economist.
# Q: Who is a reporter?
# A: Martin
# P: Martin and Kathryn
#
# C: Martin and Kathryn are friends. He is a reporter, and she is an economist.
# Q: Who is an economist?
# A: Kathryn
# P: Martin and Kathryn
#
# C: Kathryn and Martin are friends. He is a reporter, and she is an economist.
# Q: Who is a reporter?
# A: Martin
# P: Kathryn and Martin
#
#
# ----
# C: Alexander and Robin are friends. He is an administrator, and she is an organizer.
# Q: Who is an administrator?
# A: Alexander
# P: Alexander and Robin
#
# C: Alexander and Robin are friends. He is an administrator, and she is an organizer.
# Q: Who is an organizer?
# A: Robin
# P: Alexander and Robin
#
# C: Robin and Alexander are friends. He is an administrator, and she is an organizer.
# Q: Who is an administrator?
# A: Alexander
# P: Robin
#
#
# ----
# C: Ben and Carol are friends. He is an entrepreneur, and she is a DJ.
# Q: Who is an entrepreneur?
# A: Ben
# P: Ben and Carol
#
# C: Ben and Carol are friends. He is an entrepreneur, and she is a DJ.
# Q: Who is a DJ?
# A: Carol
# P: Ben and Carol
#
# C: Carol and Ben are friends. He is an entrepreneur, and she is a DJ.
# Q: Who is an entrepreneur?
# A: Ben
# P: Carol and Ben
#
#
# ----
#
#
# Basic coref, his / her
# Test cases:      500
# Test cases run:  100
# Fails (rate):    97 (97.0%)
#
# Example fails:
# C: Anthony and Patricia are friends. Her mom is an educator.
# Q: Whose mom is an educator?
# A: Patricia
# P: Anthony and Patricia
#
# C: Patricia and Anthony are friends. Her mom is an educator.
# Q: Whose mom is an educator?
# A: Patricia
# P: Patricia and Anthony
#
#
# ----
# C: Dick and Carol are friends. His mom is an escort.
# Q: Whose mom is an escort?
# A: Dick
# P: Dick and Carol
#
# C: Carol and Dick are friends. His mom is an escort.
# Q: Whose mom is an escort?
# A: Dick
# P: Carol and Dick
#
#
# ----
# C: Walter and Florence are friends. Her mom is an attorney.
# Q: Whose mom is an attorney?
# A: Florence
# P: Walter and Florence
#
# C: Florence and Walter are friends. Her mom is an attorney.
# Q: Whose mom is an attorney?
# A: Florence
# P: Florence and Walter
#
#
# ----
#
#
# Former / Latter
# Test cases:      485
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Jerry and Lucy are friends. The former is an analyst.
# Q: Who is an analyst?
# A: Jerry
# P: Jerry and Lucy
#
# C: Lucy and Jerry are friends. The latter is an analyst.
# Q: Who is an analyst?
# A: Jerry
# P: Lucy and Jerry
#
# C: Jerry and Lucy are friends. The former is an analyst and the latter is a reporter.
# Q: Who is an analyst?
# A: Jerry
# P: Jerry and Lucy
#
#
# ----
# C: Paul and Barbara are friends. The former is a journalist.
# Q: Who is a journalist?
# A: Paul
# P: Paul and Barbara
#
# C: Barbara and Paul are friends. The latter is a journalist.
# Q: Who is a journalist?
# A: Paul
# P: Barbara and Paul
#
# C: Paul and Barbara are friends. The former is a journalist and the latter is an intern.
# Q: Who is a journalist?
# A: Paul
# P: Paul and Barbara
#
#
# ----
# C: David and Judy are friends. The former is an executive.
# Q: Who is an executive?
# A: David
# P: David and Judy
#
# C: Judy and David are friends. The latter is an executive.
# Q: Who is an executive?
# A: David
# P: Judy and David
#
# C: David and Judy are friends. The former is an executive and the latter is an assistant.
# Q: Who is an executive?
# A: David
# P: David and Judy
#
#
# ----
#
#
#
#
# SRL
#
# Agent / object distinction
# Test cases:      499
# Test cases run:  100
# Fails (rate):    71 (71.0%)
#
# Example fails:
# C: George attacks John.
# Q: Who is attacked?
# A: John
# P: George attacks John
#
#
# ----
# C: Stephanie loves Jerry.
# Q: Who loves?
# A: Stephanie
# P: Jerry
#
# C: Jerry is loved by Stephanie.
# Q: Who loves?
# A: Stephanie
# P: Jerry
#
#
# ----
# C: Linda supports Suzanne.
# Q: Who is supported?
# A: Suzanne
# P: Linda
#
# C: Suzanne is supported by Linda.
# Q: Who is supported?
# A: Suzanne
# P: Suzanne is supported by Linda
#
#
# ----
#
#
# Agent / object distinction with 3 agents
# Test cases:      492
# Test cases run:  100
# Fails (rate):    98 (98.0%)
#
# Example fails:
# C: Kathy trusts Caroline. Laura is trusted by Caroline.
# Q: Who trusts Laura?
# A: Caroline
# P: Kathy
#
# C: Kathy trusts Caroline. Laura is trusted by Caroline.
# Q: Who is trusted by Kathy?
# A: Caroline
# P: Laura
#
# C: Caroline is trusted by Kathy. Caroline trusts Laura.
# Q: Who trusts Caroline?
# A: Kathy
# P: Laura
#
#
# ----
# C: Claire accepts Anna. Judith is accepted by Anna.
# Q: Who accepts Judith?
# A: Anna
# P: Claire accepts Anna. Judith is accepted by Anna
#
# C: Claire accepts Anna. Judith is accepted by Anna.
# Q: Who is accepted by Claire?
# A: Anna
# P: Judith
#
#
# ----
# C: Sue notices Patricia. Patricia notices Kathleen.
# Q: Who notices Kathleen?
# A: Patricia
# P: Sue
#
# C: Sue notices Patricia. Kathleen is noticed by Patricia.
# Q: Who notices Kathleen?
# A: Patricia
# P: Sue
#
# C: Sue notices Patricia. Kathleen is noticed by Patricia.
# Q: Who is noticed by Sue?
# A: Patricia
# P: Kathleen
#
#
# ----

# %% [markdown]
# # save the generated Q&As in json

# %%
import json

# %%
format_fn = lambda x: json.dumps({'passage': x[0], 'question': x[1]})
suite.to_raw_file('squad.jsonl', format_fn=format_fn)

# %%
format_fn = lambda x: {'passage': x[0], 'question': x[1]}
suite.to_raw_file('squad.json', format_fn=format_fn, file_format='squad')

# %%
test_ranges = {}
current_idx = 0
all_examples = []
for name, t in suite.tests.items():
    examples = t.to_raw_examples()
    suite.test_ranges[name] = (current_idx, current_idx + len(examples))
    current_idx += len(examples)
    all_examples.extend(examples)

# %%
suite.test_ranges
# Out:
# {'A is COMP than B. Who is more COMP?': (0, 498),
#  'A is COMP than B. Who is less COMP?': (498, 997),
#  'Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?': (997,
#   6997),
#  'size, shape, age, color': (6997, 8997),
#  'Profession vs nationality': (8997, 13997),
#  'Animal vs Vehicle': (13997, 15997),
#  'Animal vs Vehicle v2': (15997, 17997),
#  'Synonyms': (17997, 19753),
#  'A is COMP than B. Who is antonym(COMP)? B': (19753, 21745),
#  'A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.': (21745,
#   29713),
#  'Question typo': (29713, 30713),
#  'Question contractions': (30713, 31716),
#  'Add random sentence to context': (31716, 33216),
#  'Change name everywhere': (33216, 38716),
#  'Change location everywhere': (38716, 44216),
#  'There was a change in profession': (44216, 45186),
#  'Understanding before / after -> first / last.': (45186, 47166),
#  'Negation in context, may or may not be in question': (47166, 49154),
#  'M/F failure rates should be similar for different professions': (49154,
#   51154),
#  'Basic coref, he / she': (51154, 55058),
#  'Basic coref, his / her': (55058, 56058),
#  'Former / Latter': (56058, 57998),
#  'Agent / object distinction': (57998, 59994),
#  'Agent / object distinction with 3 agents': (59994, 67914)}

# %%
all_examples
# Out:
# ["('Victoria is stranger than Frank.', 'Who is stranger?')",
#  "('Ashley is stronger than Alan.', 'Who is stronger?')",
#  "('Bobby is nicer than Thomas.', 'Who is nicer?')",
#  "('Benjamin is slower than Simon.', 'Who is slower?')",
#  "('Sally is older than Melissa.', 'Who is older?')",
#  "('Martha is richer than Hugh.', 'Who is richer?')",
#  "('Charlie is nicer than Colin.', 'Who is nicer?')",
#  "('Ron is nicer than Christopher.', 'Who is nicer?')",
#  "('Ken is cooler than Al.', 'Who is cooler?')",
#  "('Jane is smarter than Alice.', 'Who is smarter?')",
#  "('Angela is older than Amanda.', 'Who is older?')",
#  "('Fred is slower than Lucy.', 'Who is slower?')",
#  "('Don is faster than Patricia.', 'Who is faster?')",
#  "('Judith is richer than Jessica.', 'Who is richer?')",
#  "('Samuel is cleaner than Bob.', 'Who is cleaner?')",
#  "('Edith is weaker than Lisa.', 'Who is weaker?')",
#  "('Kathy is smaller than Walter.', 'Who is smaller?')",
#  "('Michael is faster than Rose.', 'Who is faster?')",
#  "('Ed is cooler than Mark.', 'Who is cooler?')",
#  "('Henry is younger than Maria.', 'Who is younger?')",
#  "('Roy is tougher than Johnny.', 'Who is tougher?')",
#  "('Diana is slower than Grace.', 'Who is slower?')",
#  "('Ralph is younger than Kim.', 'Who is younger?')",
#  "('Fred is stronger than Judith.', 'Who is stronger?')",
#  "('Peter is slower than Anthony.', 'Who is slower?')",
#  "('Mike is darker than Tom.', 'Who is darker?')",
#  "('Martin is wiser than Stephen.', 'Who is wiser?')",
#  "('Anna is higher than Judith.', 'Who is higher?')",
#  "('Al is richer than Susan.', 'Who is richer?')",
#  "('Marilyn is cleaner than Janet.', 'Who is cleaner?')",
#  "('Ralph is nicer than Tony.', 'Who is nicer?')",
#  "('Jonathan is stranger than Julia.', 'Who is stranger?')",
#  "('Kenneth is weaker than Paul.', 'Who is weaker?')",
#  "('Judith is older than Evelyn.', 'Who is older?')",
#  "('Melissa is stronger than Fiona.', 'Who is stronger?')",
#  "('Melissa is weaker than Steven.', 'Who is weaker?')",
#  "('Stephanie is taller than Alison.', 'Who is taller?')",
#  "('Colin is cooler than Gary.', 'Who is cooler?')",
#  "('Christopher is faster than Hugh.', 'Who is faster?')",
#  "('Anthony is nicer than Alex.', 'Who is nicer?')",
#  "('Alison is younger than Emma.', 'Who is younger?')",
#  "('Keith is cooler than James.', 'Who is cooler?')",
#  "('Kathleen is stronger than Patricia.', 'Who is stronger?')",
#  "('Jack is shorter than Christopher.', 'Who is shorter?')",
#  "('Sarah is cleaner than Colin.', 'Who is cleaner?')",
#  "('Sarah is tougher than Tom.', 'Who is tougher?')",
#  "('Laura is faster than Katherine.', 'Who is faster?')",
#  "('Daniel is older than Florence.', 'Who is older?')",
#  "('Sarah is taller than Frederick.', 'Who is taller?')",
#  "('Ray is smaller than Kevin.', 'Who is smaller?')",
#  "('Jimmy is weaker than Carl.', 'Who is weaker?')",
#  "('Pamela is weaker than Andrea.', 'Who is weaker?')",
#  "('Elaine is cooler than Frank.', 'Who is cooler?')",
#  "('Jonathan is cleaner than Amanda.', 'Who is cleaner?')",
#  "('Martha is smaller than Keith.', 'Who is smaller?')",
#  "('Jerry is greater than Tom.', 'Who is greater?')",
#  "('Christopher is older than Kenneth.', 'Who is older?')",
#  "('Alison is smarter than Nancy.', 'Who is smarter?')",
#  "('Donald is slower than Betty.', 'Who is slower?')",
#  "('Sharon is richer than Frances.', 'Who is richer?')",
#  "('Ian is younger than Ralph.', 'Who is younger?')",
#  "('Sue is older than Bobby.', 'Who is older?')",
#  "('Gary is richer than Lauren.', 'Who is richer?')",
#  "('Maria is tougher than Colin.', 'Who is tougher?')",
#  "('Cynthia is tougher than Benjamin.', 'Who is tougher?')",
#  "('Judith is taller than Alan.', 'Who is taller?')",
#  "('Mary is wiser than Jay.', 'Who is wiser?')",
#  "('Helen is darker than Elaine.', 'Who is darker?')",
#  "('Ben is cooler than Johnny.', 'Who is cooler?')",
#  "('Tom is richer than Sally.', 'Who is richer?')",
#  "('Kim is faster than Donald.', 'Who is faster?')",
#  "('Simon is darker than Kim.', 'Who is darker?')",
#  "('Alexandra is wiser than John.', 'Who is wiser?')",
#  "('Mary is darker than Carl.', 'Who is darker?')",
#  "('Carolyn is stronger than Jim.', 'Who is stronger?')",
#  "('Lauren is cooler than Paul.', 'Who is cooler?')",
#  "('Ian is cooler than Henry.', 'Who is cooler?')",
#  "('Tom is richer than Robin.', 'Who is richer?')",
#  "('Edward is stronger than Deborah.', 'Who is stronger?')",
#  "('Ian is higher than Thomas.', 'Who is higher?')",
#  "('Amanda is stranger than Johnny.', 'Who is stranger?')",
#  "('Patricia is older than Jessica.', 'Who is older?')",
#  "('Claire is richer than Wendy.', 'Who is richer?')",
#  "('Walter is smaller than Lauren.', 'Who is smaller?')",
#  "('Janet is slower than Bob.', 'Who is slower?')",
#  "('Roy is cooler than Simon.', 'Who is cooler?')",
#  "('Frederick is smaller than Sandra.', 'Who is smaller?')",
#  "('Roy is older than Anthony.', 'Who is older?')",
#  "('Margaret is wiser than Sophie.', 'Who is wiser?')",
#  "('John is smarter than Elaine.', 'Who is smarter?')",
#  "('Kelly is nicer than Christine.', 'Who is nicer?')",
#  "('Matt is stranger than Edwin.', 'Who is stranger?')",
#  "('Eric is cleaner than Ann.', 'Who is cleaner?')",
#  "('Lynn is smarter than Ed.', 'Who is smarter?')",
#  "('Alexander is taller than Jane.', 'Who is taller?')",
#  "('Joseph is wiser than Sharon.', 'Who is wiser?')",
#  "('Ken is cooler than Matthew.', 'Who is cooler?')",
#  "('Sue is taller than Sam.', 'Who is taller?')",
#  "('Donald is smaller than Carl.', 'Who is smaller?')",
#  "('Nancy is older than Roy.', 'Who is older?')",
#  "('Louis is nicer than Robert.', 'Who is nicer?')",
#  "('Anna is stranger than Roger.', 'Who is stranger?')",
#  "('Kim is tougher than Dan.', 'Who is tougher?')",
#  "('Joe is taller than Anthony.', 'Who is taller?')",
#  "('Dorothy is cooler than Samuel.', 'Who is cooler?')",
#  "('Bob is cooler than Brian.', 'Who is cooler?')",
#  "('Anthony is higher than Heather.', 'Who is higher?')",
#  "('Bob is weaker than Kathleen.', 'Who is weaker?')",
#  "('Sue is shorter than Jennifer.', 'Who is shorter?')",
#  "('Mark is slower than Martin.', 'Who is slower?')",
#  "('Catherine is smaller than Helen.', 'Who is smaller?')",
#  "('Fred is higher than Melissa.', 'Who is higher?')",
#  "('Harold is shorter than Bobby.', 'Who is shorter?')",
#  "('Victoria is richer than Bruce.', 'Who is richer?')",
#  "('Bobby is slower than Joseph.', 'Who is slower?')",
#  "('Frances is stranger than Karen.', 'Who is stranger?')",
#  "('Cynthia is smarter than Al.', 'Who is smarter?')",
#  "('Mark is smaller than Lynn.', 'Who is smaller?')",
#  "('Dave is older than Stephanie.', 'Who is older?')",
#  "('Laura is cooler than Eleanor.', 'Who is cooler?')",
#  "('Jason is older than David.', 'Who is older?')",
#  "('Robin is cleaner than William.', 'Who is cleaner?')",
#  "('Emma is slower than Janet.', 'Who is slower?')",
#  "('Patricia is greater than Grace.', 'Who is greater?')",
#  "('Nicole is richer than Jimmy.', 'Who is richer?')",
#  "('Eleanor is darker than Steven.', 'Who is darker?')",
#  "('Heather is tougher than Dorothy.', 'Who is tougher?')",
#  "('Sara is richer than Harold.', 'Who is richer?')",
#  "('Steven is weaker than Ryan.', 'Who is weaker?')",
#  "('Virginia is nicer than Tony.', 'Who is nicer?')",
#  "('Lisa is taller than Charlotte.', 'Who is taller?')",
#  "('Walter is cooler than Jason.', 'Who is cooler?')",
#  "('Rebecca is shorter than Scott.', 'Who is shorter?')",
#  "('Donald is stronger than Dan.', 'Who is stronger?')",
#  "('Daniel is shorter than Sandra.', 'Who is shorter?')",
#  "('Ray is faster than Julia.', 'Who is faster?')",
#  "('Frank is richer than Kathy.', 'Who is richer?')",
#  "('Andrea is slower than David.', 'Who is slower?')",
#  "('Donald is slower than Anna.', 'Who is slower?')",
#  "('Donna is weaker than Keith.', 'Who is weaker?')",
#  "('Joe is richer than Jim.', 'Who is richer?')",
#  "('Katherine is faster than Patrick.', 'Who is faster?')",
#  "('Nancy is greater than Susan.', 'Who is greater?')",
#  "('Paul is richer than Charlotte.', 'Who is richer?')",
#  "('Jack is higher than Gary.', 'Who is higher?')",
#  "('Sam is smaller than Marilyn.', 'Who is smaller?')",
#  "('Matt is richer than Carol.', 'Who is richer?')",
#  "('Jerry is younger than Laura.', 'Who is younger?')",
#  "('Jimmy is taller than Kathy.', 'Who is taller?')",
#  "('Susan is greater than Stephanie.', 'Who is greater?')",
#  "('Adam is greater than Roger.', 'Who is greater?')",
#  "('Don is older than Emma.', 'Who is older?')",
#  "('Sharon is darker than Laura.', 'Who is darker?')",
#  "('Frederick is younger than Jeff.', 'Who is younger?')",
#  "('Sharon is smarter than Amanda.', 'Who is smarter?')",
#  "('Alexandra is taller than Elaine.', 'Who is taller?')",
#  "('Edith is cleaner than Sarah.', 'Who is cleaner?')",
#  "('Simon is higher than Jessica.', 'Who is higher?')",
#  "('Kate is older than Judy.', 'Who is older?')",
#  "('Emily is stranger than Ruth.', 'Who is stranger?')",
#  "('Martha is smaller than Emma.', 'Who is smaller?')",
#  "('Laura is faster than Jack.', 'Who is faster?')",
#  "('Betty is richer than Alex.', 'Who is richer?')",
#  "('Judy is younger than Kathy.', 'Who is younger?')",
#  "('Kathy is older than Alfred.', 'Who is older?')",
#  "('Lucy is faster than Catherine.', 'Who is faster?')",
#  "('Jay is richer than Martin.', 'Who is richer?')",
#  "('Jennifer is stranger than Jill.', 'Who is stranger?')",
#  "('Matthew is weaker than Joe.', 'Who is weaker?')",
#  "('Linda is nicer than Stephanie.', 'Who is nicer?')",
#  "('Patricia is older than Daniel.', 'Who is older?')",
#  "('Kate is wiser than Anna.', 'Who is wiser?')",
#  "('Tom is cleaner than Howard.', 'Who is cleaner?')",
#  "('Hugh is slower than John.', 'Who is slower?')",
#  "('Christine is smaller than Annie.', 'Who is smaller?')",
#  "('Steven is wiser than Annie.', 'Who is wiser?')",
#  "('Ed is weaker than Carol.', 'Who is weaker?')",
#  "('Walter is greater than Ruth.', 'Who is greater?')",
#  "('George is cleaner than Judith.', 'Who is cleaner?')",
#  "('Don is cleaner than Sharon.', 'Who is cleaner?')",
#  "('Richard is darker than Martin.', 'Who is darker?')",
#  "('Frank is cooler than Kenneth.', 'Who is cooler?')",
#  "('Sara is younger than Marilyn.', 'Who is younger?')",
#  "('Alexander is weaker than Dorothy.', 'Who is weaker?')",
#  "('Leslie is greater than Betty.', 'Who is greater?')",
#  "('Louise is cleaner than Lisa.', 'Who is cleaner?')",
#  "('Stephanie is taller than Martha.', 'Who is taller?')",
#  "('Jonathan is stronger than Peter.', 'Who is stronger?')",
#  "('Sophie is stronger than Hugh.', 'Who is stronger?')",
#  "('Rachel is older than George.', 'Who is older?')",
#  "('Angela is cleaner than Andrew.', 'Who is cleaner?')",
#  "('Ryan is younger than Eric.', 'Who is younger?')",
#  "('Kim is cleaner than Patricia.', 'Who is cleaner?')",
#  "('Alexandra is shorter than Larry.', 'Who is shorter?')",
#  "('Eric is tougher than Samuel.', 'Who is tougher?')",
#  "('Anthony is weaker than Nicole.', 'Who is weaker?')",
#  "('Linda is cooler than Roger.', 'Who is cooler?')",
#  "('Roy is shorter than Rebecca.', 'Who is shorter?')",
#  "('Judith is weaker than Jennifer.', 'Who is weaker?')",
#  "('Nicole is slower than Mike.', 'Who is slower?')",
#  "('Laura is older than Sara.', 'Who is older?')",
#  "('Dick is smaller than Amy.', 'Who is smaller?')",
#  "('Michael is smaller than Matthew.', 'Who is smaller?')",
#  "('Jean is taller than Al.', 'Who is taller?')",
#  "('Lynn is taller than Anne.', 'Who is taller?')",
#  "('Rebecca is slower than Joseph.', 'Who is slower?')",
#  "('Carol is stronger than Bob.', 'Who is stronger?')",
#  "('Bill is older than Matthew.', 'Who is older?')",
#  "('Charles is greater than Stephanie.', 'Who is greater?')",
#  "('Suzanne is slower than Henry.', 'Who is slower?')",
#  "('Jonathan is cooler than Philip.', 'Who is cooler?')",
#  "('Henry is younger than Karen.', 'Who is younger?')",
#  "('Samuel is slower than Evelyn.', 'Who is slower?')",
#  "('Heather is tougher than Ken.', 'Who is tougher?')",
#  "('Charles is nicer than Christine.', 'Who is nicer?')",
#  "('Amanda is smaller than Andrea.', 'Who is smaller?')",
#  "('Alice is richer than Joseph.', 'Who is richer?')",
#  "('Diana is tougher than Fiona.', 'Who is tougher?')",
#  "('Judy is tougher than Rachel.', 'Who is tougher?')",
#  "('Angela is higher than Steve.', 'Who is higher?')",
#  "('Amy is higher than Joseph.', 'Who is higher?')",
#  "('Amy is stranger than Virginia.', 'Who is stranger?')",
#  "('Keith is wiser than Marilyn.', 'Who is wiser?')",
#  "('Virginia is nicer than Julie.', 'Who is nicer?')",
#  "('Jack is older than Ryan.', 'Who is older?')",
#  "('Stephen is higher than Dan.', 'Who is higher?')",
#  "('Kevin is cleaner than Walter.', 'Who is cleaner?')",
#  "('Donna is nicer than Charles.', 'Who is nicer?')",
#  "('Jerry is higher than Cynthia.', 'Who is higher?')",
#  "('Roy is cleaner than Don.', 'Who is cleaner?')",
#  "('Paul is weaker than Judith.', 'Who is weaker?')",
#  "('Steve is smaller than Melissa.', 'Who is smaller?')",
#  "('Tom is stronger than Patrick.', 'Who is stronger?')",
#  "('Robin is greater than Joseph.', 'Who is greater?')",
#  "('Andrea is greater than Brian.', 'Who is greater?')",
#  "('Steve is younger than Angela.', 'Who is younger?')",
#  "('Kathleen is higher than Charlotte.', 'Who is higher?')",
#  "('Ann is greater than Harriet.', 'Who is greater?')",
#  "('Alan is weaker than Edith.', 'Who is weaker?')",
#  "('Andrew is cooler than Jack.', 'Who is cooler?')",
#  "('Karen is greater than Leslie.', 'Who is greater?')",
#  "('Sharon is richer than Caroline.', 'Who is richer?')",
#  "('Judith is weaker than Kathleen.', 'Who is weaker?')",
#  "('Mary is stranger than Patricia.', 'Who is stranger?')",
#  "('Kathleen is greater than Harry.', 'Who is greater?')",
#  "('Tom is wiser than Laura.', 'Who is wiser?')",
#  "('Larry is shorter than Simon.', 'Who is shorter?')",
#  "('Tim is wiser than Dan.', 'Who is wiser?')",
#  "('Thomas is wiser than Nick.', 'Who is wiser?')",
#  "('Linda is wiser than Susan.', 'Who is wiser?')",
#  "('Philip is cooler than Janet.', 'Who is cooler?')",
#  "('Heather is cooler than Marie.', 'Who is cooler?')",
#  "('Anne is darker than Caroline.', 'Who is darker?')",
#  "('Kate is wiser than Sara.', 'Who is wiser?')",
#  "('Ed is stranger than Harriet.', 'Who is stranger?')",
#  "('Philip is tougher than Jay.', 'Who is tougher?')",
#  "('Heather is higher than Bobby.', 'Who is higher?')",
#  "('Mary is shorter than Pamela.', 'Who is shorter?')",
#  "('Mark is taller than Dan.', 'Who is taller?')",
#  "('Greg is smarter than Andrea.', 'Who is smarter?')",
#  "('Sarah is darker than Leslie.', 'Who is darker?')",
#  "('Tim is shorter than Howard.', 'Who is shorter?')",
#  "('Jim is nicer than Joseph.', 'Who is nicer?')",
#  "('Jerry is darker than Daniel.', 'Who is darker?')",
#  "('Roy is smarter than Caroline.', 'Who is smarter?')",
#  "('Emily is stranger than Ed.', 'Who is stranger?')",
#  "('Judy is older than Lawrence.', 'Who is older?')",
#  "('Sophie is cooler than Emma.', 'Who is cooler?')",
#  "('Mary is older than Julia.', 'Who is older?')",
#  "('Judith is taller than Katherine.', 'Who is taller?')",
#  "('Jonathan is younger than Sam.', 'Who is younger?')",
#  "('Claire is tougher than Amy.', 'Who is tougher?')",
#  "('Frank is wiser than Jay.', 'Who is wiser?')",
#  "('Samuel is cooler than Ben.', 'Who is cooler?')",
#  "('Donna is tougher than Ruth.', 'Who is tougher?')",
#  "('Marie is cleaner than Jennifer.', 'Who is cleaner?')",
#  "('Kathy is weaker than Suzanne.', 'Who is weaker?')",
#  "('Sharon is higher than Lucy.', 'Who is higher?')",
#  "('Thomas is tougher than Al.', 'Who is tougher?')",
#  "('Ryan is richer than Jennifer.', 'Who is richer?')",
#  "('Ron is stronger than Ryan.', 'Who is stronger?')",
#  "('Jill is taller than Linda.', 'Who is taller?')",
#  "('Jimmy is smaller than Walter.', 'Who is smaller?')",
#  "('Julia is nicer than Matthew.', 'Who is nicer?')",
#  "('Sandra is richer than Carl.', 'Who is richer?')",
#  "('Betty is wiser than Joseph.', 'Who is wiser?')",
#  "('Leslie is stranger than Heather.', 'Who is stranger?')",
#  "('Sue is smaller than Katie.', 'Who is smaller?')",
#  "('Alan is darker than Christine.', 'Who is darker?')",
#  "('Carolyn is nicer than Mary.', 'Who is nicer?')",
#  "('Diana is stronger than Alison.', 'Who is stronger?')",
#  "('Albert is higher than Lawrence.', 'Who is higher?')",
#  "('Anthony is higher than Sharon.', 'Who is higher?')",
#  "('Brian is cleaner than Jane.', 'Who is cleaner?')",
#  "('Alice is smaller than Hugh.', 'Who is smaller?')",
#  "('Kim is younger than Laura.', 'Who is younger?')",
#  "('Harry is nicer than Lynn.', 'Who is nicer?')",
#  "('Gary is slower than Joan.', 'Who is slower?')",
#  "('Robert is taller than William.', 'Who is taller?')",
#  "('Fiona is stronger than Donald.', 'Who is stronger?')",
#  "('Sally is richer than Patrick.', 'Who is richer?')",
#  "('Christopher is greater than Katherine.', 'Who is greater?')",
#  "('Ryan is higher than Carl.', 'Who is higher?')",
#  "('Donna is faster than Carl.', 'Who is faster?')",
#  "('Barbara is taller than Victoria.', 'Who is taller?')",
#  "('Roger is younger than Colin.', 'Who is younger?')",
#  "('Elaine is richer than Amy.', 'Who is richer?')",
#  "('Frederick is nicer than Sarah.', 'Who is nicer?')",
#  "('Sandra is stronger than Dick.', 'Who is stronger?')",
#  "('Fred is stronger than Carolyn.', 'Who is stronger?')",
#  "('Margaret is faster than Caroline.', 'Who is faster?')",
#  "('Florence is stranger than Ryan.', 'Who is stranger?')",
#  "('Bobby is smarter than Christine.', 'Who is smarter?')",
#  "('Joe is tougher than Jay.', 'Who is tougher?')",
#  "('Anna is cleaner than Lucy.', 'Who is cleaner?')",
#  "('Claire is greater than Amy.', 'Who is greater?')",
#  "('Wendy is faster than Gary.', 'Who is faster?')",
#  "('Julie is cooler than Philip.', 'Who is cooler?')",
#  "('Bobby is higher than Frederick.', 'Who is higher?')",
#  "('Eleanor is shorter than Virginia.', 'Who is shorter?')",
#  "('Kenneth is taller than Wendy.', 'Who is taller?')",
#  "('Sandra is taller than Nick.', 'Who is taller?')",
#  "('Catherine is greater than Harry.', 'Who is greater?')",
#  "('Sue is darker than Mary.', 'Who is darker?')",
#  "('Steve is smaller than Christopher.', 'Who is smaller?')",
#  "('Alexandra is faster than Kenneth.', 'Who is faster?')",
#  "('Howard is higher than Bob.', 'Who is higher?')",
#  "('Nick is shorter than Alison.', 'Who is shorter?')",
#  "('Andrea is nicer than Michelle.', 'Who is nicer?')",
#  "('Florence is richer than Steve.', 'Who is richer?')",
#  "('Elaine is faster than Edward.', 'Who is faster?')",
#  "('Charlie is smaller than Christine.', 'Who is smaller?')",
#  "('Eric is darker than Tom.', 'Who is darker?')",
#  "('Robin is tougher than Dan.', 'Who is tougher?')",
#  "('Peter is older than Judith.', 'Who is older?')",
#  "('William is greater than Claire.', 'Who is greater?')",
#  "('Mary is stronger than Matt.', 'Who is stronger?')",
#  "('Eric is darker than Jessica.', 'Who is darker?')",
#  "('Emma is younger than Martin.', 'Who is younger?')",
#  "('Kathy is older than Keith.', 'Who is older?')",
#  "('Tim is greater than Michael.', 'Who is greater?')",
#  "('Jean is slower than Steve.', 'Who is slower?')",
#  "('Bob is tougher than Arthur.', 'Who is tougher?')",
#  "('Chris is older than Richard.', 'Who is older?')",
#  "('John is smarter than Keith.', 'Who is smarter?')",
#  "('Andrew is tougher than Sally.', 'Who is tougher?')",
#  "('Linda is stronger than Sally.', 'Who is stronger?')",
#  "('Elizabeth is stranger than Greg.', 'Who is stranger?')",
#  "('Andrea is shorter than George.', 'Who is shorter?')",
#  "('Emily is tougher than Catherine.', 'Who is tougher?')",
#  "('Louise is stranger than Tony.', 'Who is stranger?')",
#  "('Lynn is stranger than Martha.', 'Who is stranger?')",
#  "('Philip is greater than Amanda.', 'Who is greater?')",
#  "('Judith is cooler than Jessica.', 'Who is cooler?')",
#  "('Joan is higher than Judith.', 'Who is higher?')",
#  "('Leslie is cooler than Bobby.', 'Who is cooler?')",
#  "('Walter is darker than Keith.', 'Who is darker?')",
#  "('Frederick is greater than Margaret.', 'Who is greater?')",
#  "('Ellen is faster than Patrick.', 'Who is faster?')",
#  "('Margaret is faster than Christopher.', 'Who is faster?')",
#  "('Henry is faster than Amy.', 'Who is faster?')",
#  "('Marilyn is higher than Andrew.', 'Who is higher?')",
#  "('Patricia is taller than Paul.', 'Who is taller?')",
#  "('Barbara is older than Fred.', 'Who is older?')",
#  "('Sara is cooler than Al.', 'Who is cooler?')",
#  "('Howard is wiser than Thomas.', 'Who is wiser?')",
#  "('Diana is slower than Gary.', 'Who is slower?')",
#  "('Helen is smarter than Donna.', 'Who is smarter?')",
#  "('Jessica is smaller than Virginia.', 'Who is smaller?')",
#  "('Adam is nicer than Jane.', 'Who is nicer?')",
#  "('Hugh is darker than Elaine.', 'Who is darker?')",
#  "('Roger is shorter than Nicole.', 'Who is shorter?')",
#  "('Tom is slower than Adam.', 'Who is slower?')",
#  "('Jimmy is shorter than Keith.', 'Who is shorter?')",
#  "('Kevin is smaller than Amy.', 'Who is smaller?')",
#  "('Christopher is greater than Billy.', 'Who is greater?')",
#  "('Julie is slower than Jimmy.', 'Who is slower?')",
#  "('Margaret is smaller than Richard.', 'Who is smaller?')",
#  "('Albert is faster than Anthony.', 'Who is faster?')",
#  "('Leslie is higher than Frank.', 'Who is higher?')",
#  "('Patricia is cleaner than Steve.', 'Who is cleaner?')",
#  "('Sarah is wiser than Ed.', 'Who is wiser?')",
#  "('Walter is richer than Philip.', 'Who is richer?')",
#  "('Roy is higher than Leslie.', 'Who is higher?')",
#  "('Ryan is stronger than Patricia.', 'Who is stronger?')",
#  "('Samuel is stranger than Alexander.', 'Who is stranger?')",
#  "('Arthur is stronger than Evelyn.', 'Who is stronger?')",
#  "('Alan is younger than Roy.', 'Who is younger?')",
#  "('Kate is wiser than Jim.', 'Who is wiser?')",
#  "('Harriet is taller than Emma.', 'Who is taller?')",
#  "('Albert is wiser than Margaret.', 'Who is wiser?')",
#  "('Anne is older than Laura.', 'Who is older?')",
#  "('Robin is older than Don.', 'Who is older?')",
#  "('Steve is weaker than Susan.', 'Who is weaker?')",
#  "('Sophie is stronger than Patricia.', 'Who is stronger?')",
#  "('Edwin is smaller than Evelyn.', 'Who is smaller?')",
#  "('Kathleen is wiser than Fred.', 'Who is wiser?')",
#  "('Edward is stranger than Johnny.', 'Who is stranger?')",
#  "('Ann is shorter than Tom.', 'Who is shorter?')",
#  "('Jane is higher than Melissa.', 'Who is higher?')",
#  "('Margaret is older than Arthur.', 'Who is older?')",
#  "('Bruce is darker than Lynn.', 'Who is darker?')",
#  "('Diane is wiser than Sarah.', 'Who is wiser?')",
#  "('Katie is darker than Dick.', 'Who is darker?')",
#  "('Ryan is younger than Tim.', 'Who is younger?')",
#  "('Sarah is wiser than Hugh.', 'Who is wiser?')",
#  "('Jane is weaker than Donald.', 'Who is weaker?')",
#  "('Francis is cleaner than Grace.', 'Who is cleaner?')",
#  "('Rebecca is richer than Colin.', 'Who is richer?')",
#  "('Alan is smarter than Dave.', 'Who is smarter?')",
#  "('Sarah is stronger than Louis.', 'Who is stronger?')",
#  "('Lisa is cooler than Emily.', 'Who is cooler?')",
#  "('Fiona is younger than Claire.', 'Who is younger?')",
#  "('Edward is taller than George.', 'Who is taller?')",
#  "('Ben is taller than Martin.', 'Who is taller?')",
#  "('Emily is smaller than Rachel.', 'Who is smaller?')",
#  "('Amy is greater than Thomas.', 'Who is greater?')",
#  "('Margaret is stranger than Adam.', 'Who is stranger?')",
#  "('Jim is tougher than Bruce.', 'Who is tougher?')",
#  "('Gary is tougher than Rebecca.', 'Who is tougher?')",
#  "('Ashley is higher than Kathryn.', 'Who is higher?')",
#  "('Colin is slower than Jason.', 'Who is slower?')",
#  "('Charlotte is shorter than Nicole.', 'Who is shorter?')",
#  "('Ray is tougher than Larry.', 'Who is tougher?')",
#  "('Jean is faster than Victoria.', 'Who is faster?')",
#  "('Kelly is faster than Don.', 'Who is faster?')",
#  "('Howard is shorter than Elizabeth.', 'Who is shorter?')",
#  "('James is shorter than Emma.', 'Who is shorter?')",
#  "('Emily is cooler than Virginia.', 'Who is cooler?')",
#  "('Melissa is greater than Marilyn.', 'Who is greater?')",
#  "('Lisa is shorter than Marie.', 'Who is shorter?')",
#  "('Christopher is nicer than Jessica.', 'Who is nicer?')",
#  "('Roy is greater than Walter.', 'Who is greater?')",
#  "('Jerry is smarter than Virginia.', 'Who is smarter?')",
#  "('Claire is cleaner than Rebecca.', 'Who is cleaner?')",
#  "('Bobby is richer than Keith.', 'Who is richer?')",
#  "('Sandra is darker than Ann.', 'Who is darker?')",
#  "('Victoria is greater than Ron.', 'Who is greater?')",
#  "('Sue is nicer than Christine.', 'Who is nicer?')",
#  "('Kathleen is younger than Rebecca.', 'Who is younger?')",
#  "('Emily is younger than Anna.', 'Who is younger?')",
#  "('Ian is younger than Sam.', 'Who is younger?')",
#  "('Victoria is smarter than Don.', 'Who is smarter?')",
#  "('Dave is younger than Julia.', 'Who is younger?')",
#  "('Fred is higher than Martin.', 'Who is higher?')",
#  "('Betty is shorter than Diana.', 'Who is shorter?')",
#  "('Edward is older than Albert.', 'Who is older?')",
#  "('Alan is shorter than Johnny.', 'Who is shorter?')",
#  "('Ian is stranger than Peter.', 'Who is stranger?')",
#  "('Daniel is greater than Nick.', 'Who is greater?')",
#  "('Fred is cooler than Louis.', 'Who is cooler?')",
#  "('Heather is tougher than Ryan.', 'Who is tougher?')",
#  "('Emma is smaller than Dave.', 'Who is smaller?')",
#  "('Benjamin is older than Mark.', 'Who is older?')",
#  "('George is greater than Jay.', 'Who is greater?')",
#  "('Angela is stranger than Brian.', 'Who is stranger?')",
#  "('Patricia is stronger than Louis.', 'Who is stronger?')",
#  "('Susan is cooler than Evelyn.', 'Who is cooler?')",
#  "('Martha is cooler than Frances.', 'Who is cooler?')",
#  "('Jason is smaller than Carolyn.', 'Who is smaller?')",
#  "('Greg is wiser than Linda.', 'Who is wiser?')",
#  "('Janet is slower than Michael.', 'Who is slower?')",
#  "('Kenneth is cooler than Lauren.', 'Who is cooler?')",
#  "('Larry is cooler than Ralph.', 'Who is cooler?')",
#  "('Julie is cleaner than Matt.', 'Who is cleaner?')",
#  "('Frederick is cleaner than Helen.', 'Who is cleaner?')",
#  "('Ellen is older than Ann.', 'Who is older?')",
#  "('Robin is wiser than Virginia.', 'Who is wiser?')",
#  "('Louise is tougher than Judith.', 'Who is tougher?')",
#  "('Bobby is cleaner than Judy.', 'Who is cleaner?')",
#  "('Jason is older than Evelyn.', 'Who is older?')",
#  "('Jill is shorter than Alice.', 'Who is shorter?')",
#  "('Ed is nicer than Sue.', 'Who is nicer?')",
#  "('Leslie is wiser than Claire.', 'Who is wiser?')",
#  "('Robert is richer than Mike.', 'Who is richer?')",
#  "('Suzanne is tougher than Benjamin.', 'Who is tougher?')",
#  "('Thomas is stranger than Laura.', 'Who is stranger?')",
#  "('Matthew is stranger than Edith.', 'Who is stranger?')",
#  "('Anna is slower than Amanda.', 'Who is slower?')",
#  "('Janet is taller than Rebecca.', 'Who is taller?')",
#  "('Michael is cleaner than Nicole.', 'Who is cleaner?')",
#  "('Paul is richer than Roy.', 'Who is richer?')",
#  "('Adam is darker than Sara.', 'Who is darker?')",
#  "('Susan is cleaner than Janet.', 'Who is cleaner?')",
#  "('Andrew is weaker than Sam.', 'Who is weaker?')",
#  "('Edwin is cooler than Andrea.', 'Who is cooler?')",
#  "('Paul is higher than Donald.', 'Who is higher?')",
#  "('Angela is cleaner than Ryan.', 'Who is cleaner?')",
#  "('Ken is darker than Sharon.', 'Who is darker?')",
#  "('Daniel is cleaner than Gary.', 'Who is cleaner?')",
#  "('Jean is weaker than Amanda.', 'Who is weaker?')",
#  "('Andrew is tougher than Alfred.', 'Who is tougher?')",
#  "('Dorothy is darker than Albert.', 'Who is darker?')",
#  "('Joan is shorter than Daniel.', 'Who is shorter?')",
#  "('Steven is smarter than Alan.', 'Who is smarter?')",
#  "('Carol is weaker than Jack.', 'Who is weaker?')",
#  "('Mike is cleaner than Tony.', 'Who is cleaner?')",
#  "('Ron is taller than Tony.', 'Who is taller?')",
#  "('Roger is richer than Dave.', 'Who is richer?')",
#  "('Helen is tougher than Florence.', 'Who is less tough?')",
#  "('Judith is cleaner than Stephen.', 'Who is less clean?')",
#  "('Sue is tougher than Fred.', 'Who is less tough?')",
#  "('Samuel is richer than Diane.', 'Who is less rich?')",
#  "('Benjamin is higher than Katherine.', 'Who is less high?')",
#  "('Rebecca is taller than Jerry.', 'Who is less tall?')",
#  "('Melissa is weaker than Lucy.', 'Who is less weak?')",
#  "('Steven is taller than Simon.', 'Who is less tall?')",
#  "('Ron is cooler than Katherine.', 'Who is less cool?')",
#  "('Billy is smaller than Frederick.', 'Who is less small?')",
#  "('Elizabeth is slower than Karen.', 'Who is less slow?')",
#  "('George is stranger than Margaret.', 'Who is less strange?')",
#  "('Patricia is taller than Jessica.', 'Who is less tall?')",
#  "('Alexander is nicer than Melissa.', 'Who is less nice?')",
#  "('Ellen is older than Dorothy.', 'Who is less old?')",
#  "('Harold is cooler than Heather.', 'Who is less cool?')",
#  "('Ian is shorter than Emma.', 'Who is less short?')",
#  "('Lisa is faster than Julie.', 'Who is less fast?')",
#  "('Amy is nicer than Charles.', 'Who is less nice?')",
#  "('Lisa is smarter than Evelyn.', 'Who is less smart?')",
#  "('Laura is darker than Ken.', 'Who is less dark?')",
#  "('Nancy is taller than Susan.', 'Who is less tall?')",
#  "('Angela is faster than Albert.', 'Who is less fast?')",
#  "('Michelle is wiser than Daniel.', 'Who is less wise?')",
#  "('Charlotte is darker than Ralph.', 'Who is less dark?')",
#  "('Donna is faster than Anna.', 'Who is less fast?')",
#  "('Alice is taller than Karen.', 'Who is less tall?')",
#  "('Carol is stranger than Maria.', 'Who is less strange?')",
#  "('Ralph is nicer than Harry.', 'Who is less nice?')",
#  "('Suzanne is taller than Emma.', 'Who is less tall?')",
#  "('Ralph is weaker than Janet.', 'Who is less weak?')",
#  "('John is taller than Sara.', 'Who is less tall?')",
#  "('Tom is higher than Gary.', 'Who is less high?')",
#  "('Sarah is slower than Jim.', 'Who is less slow?')",
#  "('Anna is smarter than Louise.', 'Who is less smart?')",
#  "('Margaret is darker than Florence.', 'Who is less dark?')",
#  "('Anne is smarter than Caroline.', 'Who is less smart?')",
#  "('Edith is slower than Alexander.', 'Who is less slow?')",
#  "('Scott is older than Angela.', 'Who is less old?')",
#  "('Ashley is darker than Kathryn.', 'Who is less dark?')",
#  "('Judith is shorter than Scott.', 'Who is less short?')",
#  "('Greg is greater than Samuel.', 'Who is less great?')",
#  "('Alfred is darker than Samuel.', 'Who is less dark?')",
#  "('Roy is wiser than Ian.', 'Who is less wise?')",
#  "('Eric is higher than Billy.', 'Who is less high?')",
#  "('Ron is stronger than Frank.', 'Who is less strong?')",
#  "('Charlie is slower than Ian.', 'Who is less slow?')",
#  "('Janet is greater than Carol.', 'Who is less great?')",
#  "('Louis is nicer than Harriet.', 'Who is less nice?')",
#  "('Tony is cleaner than Robin.', 'Who is less clean?')",
#  "('Marilyn is older than Nancy.', 'Who is less old?')",
#  "('Jim is cooler than Hugh.', 'Who is less cool?')",
#  "('Ralph is older than Nancy.', 'Who is less old?')",
#  "('Evelyn is greater than Arthur.', 'Who is less great?')",
#  "('Victoria is higher than Alfred.', 'Who is less high?')",
#  "('Colin is shorter than Ian.', 'Who is less short?')",
#  "('Patricia is higher than Laura.', 'Who is less high?')",
#  "('Mary is stronger than Jonathan.', 'Who is less strong?')",
#  "('Keith is tougher than Howard.', 'Who is less tough?')",
#  "('Carolyn is cooler than Anne.', 'Who is less cool?')",
#  "('Thomas is nicer than Ruth.', 'Who is less nice?')",
#  "('Edwin is taller than Kate.', 'Who is less tall?')",
#  "('Anne is taller than Pamela.', 'Who is less tall?')",
#  "('Harold is stronger than Alan.', 'Who is less strong?')",
#  "('Lynn is richer than Mike.', 'Who is less rich?')",
#  "('Kathryn is taller than Florence.', 'Who is less tall?')",
#  "('Paul is younger than Andrew.', 'Who is less young?')",
#  "('Diana is older than Christine.', 'Who is less old?')",
#  "('Don is taller than Arthur.', 'Who is less tall?')",
#  "('Alison is tougher than Dave.', 'Who is less tough?')",
#  "('Diane is higher than Andrew.', 'Who is less high?')",
#  "('Alexander is shorter than Sue.', 'Who is less short?')",
#  "('Sam is slower than Ron.', 'Who is less slow?')",
#  "('Carl is tougher than Colin.', 'Who is less tough?')",
#  "('Alex is stranger than Fred.', 'Who is less strange?')",
#  "('Nicole is greater than Andrea.', 'Who is less great?')",
#  "('Colin is shorter than Scott.', 'Who is less short?')",
#  "('Adam is older than William.', 'Who is less old?')",
#  "('Sara is nicer than Alex.', 'Who is less nice?')",
#  "('Anna is smarter than Alan.', 'Who is less smart?')",
#  "('Katherine is slower than Julie.', 'Who is less slow?')",
#  "('Caroline is richer than Deborah.', 'Who is less rich?')",
#  "('Dick is younger than Donna.', 'Who is less young?')",
#  "('Lucy is nicer than Carolyn.', 'Who is less nice?')",
#  "('Marilyn is wiser than Patricia.', 'Who is less wise?')",
#  "('Robert is wiser than Judy.', 'Who is less wise?')",
#  "('Emily is richer than Linda.', 'Who is less rich?')",
#  "('Rose is nicer than Michael.', 'Who is less nice?')",
#  "('Betty is tougher than William.', 'Who is less tough?')",
#  "('Wendy is richer than Karen.', 'Who is less rich?')",
#  "('Christopher is greater than Dorothy.', 'Who is less great?')",
#  "('Eric is cooler than Victoria.', 'Who is less cool?')",
#  "('Lawrence is cooler than Jerry.', 'Who is less cool?')",
#  "('Anthony is taller than Mark.', 'Who is less tall?')",
#  "('Daniel is older than Mark.', 'Who is less old?')",
#  "('Ashley is nicer than Judy.', 'Who is less nice?')",
#  "('Steve is greater than Andrew.', 'Who is less great?')",
#  "('Kate is richer than Ken.', 'Who is less rich?')",
#  "('Karen is slower than Wendy.', 'Who is less slow?')",
#  "('Claire is nicer than Wendy.', 'Who is less nice?')",
#  "('Jennifer is smaller than Katherine.', 'Who is less small?')",
#  "('Jay is tougher than Steven.', 'Who is less tough?')",
#  "('John is taller than Carolyn.', 'Who is less tall?')",
#  "('Sandra is richer than Barbara.', 'Who is less rich?')",
#  "('Benjamin is greater than Angela.', 'Who is less great?')",
#  "('Christine is older than Jonathan.', 'Who is less old?')",
#  "('Jessica is smaller than Simon.', 'Who is less small?')",
#  "('Robert is stranger than Richard.', 'Who is less strange?')",
#  "('William is cleaner than Hugh.', 'Who is less clean?')",
#  "('Kenneth is smaller than Jill.', 'Who is less small?')",
#  "('Sara is stronger than Sally.', 'Who is less strong?')",
#  "('Ian is darker than Keith.', 'Who is less dark?')",
#  "('Nick is stranger than Henry.', 'Who is less strange?')",
#  "('Caroline is tougher than William.', 'Who is less tough?')",
#  "('Marilyn is stronger than Tom.', 'Who is less strong?')",
#  "('Mike is weaker than Greg.', 'Who is less weak?')",
#  "('Marie is cooler than Francis.', 'Who is less cool?')",
#  "('Keith is higher than Louise.', 'Who is less high?')",
#  "('Ron is greater than Carolyn.', 'Who is less great?')",
#  "('Andrew is shorter than Greg.', 'Who is less short?')",
#  "('Ray is younger than Bill.', 'Who is less young?')",
#  "('Tony is faster than Sam.', 'Who is less fast?')",
#  "('Angela is stranger than Anne.', 'Who is less strange?')",
#  "('Ron is greater than Sharon.', 'Who is less great?')",
#  "('Stephen is higher than Harriet.', 'Who is less high?')",
#  "('Janet is wiser than Julie.', 'Who is less wise?')",
#  "('Bobby is shorter than Arthur.', 'Who is less short?')",
#  "('Benjamin is cleaner than James.', 'Who is less clean?')",
#  "('Judy is wiser than Walter.', 'Who is less wise?')",
#  "('Al is smaller than Emily.', 'Who is less small?')",
#  "('Alexander is faster than Tim.', 'Who is less fast?')",
#  "('Stephanie is faster than Thomas.', 'Who is less fast?')",
#  "('Judy is weaker than Tim.', 'Who is less weak?')",
#  "('Kathryn is shorter than Jessica.', 'Who is less short?')",
#  "('Bobby is shorter than Patrick.', 'Who is less short?')",
#  "('Janet is higher than Lisa.', 'Who is less high?')",
#  "('Helen is slower than Jill.', 'Who is less slow?')",
#  "('Alice is stronger than Sandra.', 'Who is less strong?')",
#  "('Tom is richer than Robert.', 'Who is less rich?')",
#  "('Margaret is stranger than Ellen.', 'Who is less strange?')",
#  "('Wendy is stranger than Nick.', 'Who is less strange?')",
#  "('Gary is cooler than Christine.', 'Who is less cool?')",
#  "('Benjamin is slower than Harriet.', 'Who is less slow?')",
#  "('Linda is shorter than Eric.', 'Who is less short?')",
#  "('Julie is cleaner than Kelly.', 'Who is less clean?')",
#  "('Michael is faster than Judy.', 'Who is less fast?')",
#  "('Karen is weaker than Frank.', 'Who is less weak?')",
#  "('Maria is stronger than Kathryn.', 'Who is less strong?')",
#  "('Diana is higher than Alex.', 'Who is less high?')",
#  "('Alexandra is older than Pamela.', 'Who is less old?')",
#  "('Jay is smaller than Laura.', 'Who is less small?')",
#  "('Stephen is shorter than Frederick.', 'Who is less short?')",
#  "('Annie is cooler than Ann.', 'Who is less cool?')",
#  "('Anne is greater than Sally.', 'Who is less great?')",
#  "('Lauren is smaller than Kelly.', 'Who is less small?')",
#  "('Alex is greater than Dave.', 'Who is less great?')",
#  "('Judith is shorter than Virginia.', 'Who is less short?')",
#  "('Martha is wiser than Larry.', 'Who is less wise?')",
#  "('Philip is weaker than Judith.', 'Who is less weak?')",
#  "('Louise is shorter than Alan.', 'Who is less short?')",
#  "('Lucy is wiser than Don.', 'Who is less wise?')",
#  "('Dan is weaker than Lauren.', 'Who is less weak?')",
#  "('Evelyn is nicer than Lucy.', 'Who is less nice?')",
#  "('Tom is cooler than Jerry.', 'Who is less cool?')",
#  "('Rachel is taller than Harriet.', 'Who is less tall?')",
#  "('Lawrence is greater than Rose.', 'Who is less great?')",
#  "('Larry is darker than Thomas.', 'Who is less dark?')",
#  "('Joan is taller than Rose.', 'Who is less tall?')",
#  "('Suzanne is stronger than Deborah.', 'Who is less strong?')",
#  "('Joseph is higher than Anthony.', 'Who is less high?')",
#  "('Peter is weaker than Marilyn.', 'Who is less weak?')",
#  "('Sally is shorter than Edwin.', 'Who is less short?')",
#  "('Alexandra is younger than Angela.', 'Who is less young?')",
#  "('Louis is older than Frederick.', 'Who is less old?')",
#  "('Greg is older than Lucy.', 'Who is less old?')",
#  "('Don is slower than Fiona.', 'Who is less slow?')",
#  "('Christine is greater than Michelle.', 'Who is less great?')",
#  "('Martha is younger than Alexander.', 'Who is less young?')",
#  "('Evelyn is slower than Jim.', 'Who is less slow?')",
#  "('Alison is younger than Ralph.', 'Who is less young?')",
#  "('Ashley is greater than Jonathan.', 'Who is less great?')",
#  "('Robert is stranger than James.', 'Who is less strange?')",
#  "('Judy is stronger than Jim.', 'Who is less strong?')",
#  "('Nick is greater than Hugh.', 'Who is less great?')",
#  "('Bob is stranger than Simon.', 'Who is less strange?')",
#  "('Diane is tougher than Louis.', 'Who is less tough?')",
#  "('Greg is smarter than Kathryn.', 'Who is less smart?')",
#  "('Kelly is older than Daniel.', 'Who is less old?')",
#  "('Judith is older than Fiona.', 'Who is less old?')",
#  "('Sally is wiser than John.', 'Who is less wise?')",
#  "('Linda is faster than Tom.', 'Who is less fast?')",
#  "('Bruce is darker than Carol.', 'Who is less dark?')",
#  "('Janet is shorter than Jay.', 'Who is less short?')",
#  "('Brian is stranger than Fiona.', 'Who is less strange?')",
#  "('Jean is shorter than Virginia.', 'Who is less short?')",
#  "('Alex is shorter than Rachel.', 'Who is less short?')",
#  "('Alison is greater than Amy.', 'Who is less great?')",
#  "('Al is taller than David.', 'Who is less tall?')",
#  "('Alexander is older than Roy.', 'Who is less old?')",
#  "('Rose is younger than Lisa.', 'Who is less young?')",
#  "('Sandra is taller than Charlotte.', 'Who is less tall?')",
#  "('Marie is cleaner than Annie.', 'Who is less clean?')",
#  "('Alan is richer than Steven.', 'Who is less rich?')",
#  "('Martha is greater than Nancy.', 'Who is less great?')",
#  "('Marie is richer than Martha.', 'Who is less rich?')",
#  "('Marie is higher than Joseph.', 'Who is less high?')",
#  "('Mark is older than Matt.', 'Who is less old?')",
#  "('Nick is faster than Bruce.', 'Who is less fast?')",
#  "('Frank is slower than Sophie.', 'Who is less slow?')",
#  "('Simon is nicer than Virginia.', 'Who is less nice?')",
#  "('Alex is tougher than Joe.', 'Who is less tough?')",
#  "('Donald is cleaner than Diane.', 'Who is less clean?')",
#  "('Stephanie is cooler than Arthur.', 'Who is less cool?')",
#  "('Martha is shorter than Ann.', 'Who is less short?')",
#  "('Don is nicer than Katherine.', 'Who is less nice?')",
#  "('Kelly is shorter than Frederick.', 'Who is less short?')",
#  "('Edwin is stranger than Caroline.', 'Who is less strange?')",
#  "('Bobby is higher than Jeff.', 'Who is less high?')",
#  "('Rebecca is older than Arthur.', 'Who is less old?')",
#  "('Thomas is nicer than Larry.', 'Who is less nice?')",
#  "('Don is shorter than Rachel.', 'Who is less short?')",
#  "('Alison is greater than Carolyn.', 'Who is less great?')",
#  "('Samuel is taller than Suzanne.', 'Who is less tall?')",
#  "('Kathy is higher than Gary.', 'Who is less high?')",
#  "('Kevin is tougher than Tony.', 'Who is less tough?')",
#  "('Louise is richer than Angela.', 'Who is less rich?')",
#  "('Edith is stranger than William.', 'Who is less strange?')",
#  "('Don is higher than Lucy.', 'Who is less high?')",
#  "('Bobby is taller than Benjamin.', 'Who is less tall?')",
#  "('Jack is older than Bobby.', 'Who is less old?')",
#  "('Linda is cooler than Billy.', 'Who is less cool?')",
#  "('Joseph is stronger than Paul.', 'Who is less strong?')",
#  "('Charlie is taller than Harry.', 'Who is less tall?')",
#  "('Eric is nicer than Charlotte.', 'Who is less nice?')",
#  "('Carolyn is darker than Kathryn.', 'Who is less dark?')",
#  "('James is younger than Kate.', 'Who is less young?')",
#  "('Lisa is smaller than Henry.', 'Who is less small?')",
#  "('Evelyn is cooler than Sharon.', 'Who is less cool?')",
#  "('Evelyn is cleaner than Sue.', 'Who is less clean?')",
#  "('Chris is nicer than Elizabeth.', 'Who is less nice?')",
#  "('Greg is cooler than Dick.', 'Who is less cool?')",
#  "('Karen is greater than Steven.', 'Who is less great?')",
#  "('John is shorter than Susan.', 'Who is less short?')",
#  "('Caroline is cleaner than Brian.', 'Who is less clean?')",
#  "('Nicole is higher than Diana.', 'Who is less high?')",
#  "('Colin is richer than Adam.', 'Who is less rich?')",
#  "('Susan is stranger than Steven.', 'Who is less strange?')",
#  "('Joseph is slower than David.', 'Who is less slow?')",
#  "('Emma is stronger than Adam.', 'Who is less strong?')",
#  "('Carol is younger than Ron.', 'Who is less young?')",
#  "('Ellen is nicer than Marilyn.', 'Who is less nice?')",
#  "('Victoria is cleaner than Roy.', 'Who is less clean?')",
#  "('Joan is shorter than Diane.', 'Who is less short?')",
#  "('Nick is tougher than Lucy.', 'Who is less tough?')",
#  "('Marie is smaller than Larry.', 'Who is less small?')",
#  "('Elaine is faster than Patrick.', 'Who is less fast?')",
#  "('Jack is wiser than Anne.', 'Who is less wise?')",
#  "('Charles is nicer than Frederick.', 'Who is less nice?')",
#  "('Ruth is taller than Richard.', 'Who is less tall?')",
#  "('Ron is cleaner than Jennifer.', 'Who is less clean?')",
#  "('Don is younger than Martha.', 'Who is less young?')",
#  "('Howard is taller than Virginia.', 'Who is less tall?')",
#  "('Alan is faster than Melissa.', 'Who is less fast?')",
#  "('Ken is tougher than James.', 'Who is less tough?')",
#  "('Patrick is darker than Maria.', 'Who is less dark?')",
#  "('Katie is richer than Louis.', 'Who is less rich?')",
#  "('Leslie is tougher than Kelly.', 'Who is less tough?')",
#  "('Sam is darker than Julia.', 'Who is less dark?')",
#  "('Betty is weaker than Stephen.', 'Who is less weak?')",
#  "('Kate is stronger than Marie.', 'Who is less strong?')",
#  "('Florence is stranger than Donna.', 'Who is less strange?')",
#  "('Kathryn is stronger than Tony.', 'Who is less strong?')",
#  "('Lynn is darker than Dave.', 'Who is less dark?')",
#  "('Kevin is darker than Barbara.', 'Who is less dark?')",
#  "('Jennifer is stronger than Don.', 'Who is less strong?')",
#  "('Frank is weaker than Harriet.', 'Who is less weak?')",
#  "('Ashley is smarter than Jennifer.', 'Who is less smart?')",
#  "('Chris is wiser than Marie.', 'Who is less wise?')",
#  "('Arthur is smarter than Patrick.', 'Who is less smart?')",
#  "('Richard is faster than Charles.', 'Who is less fast?')",
#  "('Leslie is tougher than Hugh.', 'Who is less tough?')",
#  "('Patrick is weaker than Edward.', 'Who is less weak?')",
#  "('Edith is cleaner than Victoria.', 'Who is less clean?')",
#  "('Ron is higher than Dorothy.', 'Who is less high?')",
#  "('Wendy is cooler than Roger.', 'Who is less cool?')",
#  "('Chris is greater than Ken.', 'Who is less great?')",
#  "('Jane is darker than Jason.', 'Who is less dark?')",
#  "('Emma is wiser than Anna.', 'Who is less wise?')",
#  "('Chris is nicer than Mike.', 'Who is less nice?')",
#  "('David is shorter than Harriet.', 'Who is less short?')",
#  "('Angela is taller than Alison.', 'Who is less tall?')",
#  "('Edwin is smarter than Bobby.', 'Who is less smart?')",
#  "('Evelyn is smaller than Cynthia.', 'Who is less small?')",
#  "('Ron is faster than Dorothy.', 'Who is less fast?')",
#  "('John is shorter than Joan.', 'Who is less short?')",
#  "('Wendy is older than Henry.', 'Who is less old?')",
#  "('Martha is taller than Louise.', 'Who is less tall?')",
#  "('Rose is nicer than Christine.', 'Who is less nice?')",
#  "('Simon is stronger than Frederick.', 'Who is less strong?')",
#  "('Kenneth is richer than Edwin.', 'Who is less rich?')",
#  "('Wendy is older than Stephen.', 'Who is less old?')",
#  "('Bill is younger than Steve.', 'Who is less young?')",
#  "('Chris is stronger than Rachel.', 'Who is less strong?')",
#  "('Sara is darker than Ed.', 'Who is less dark?')",
#  "('Claire is wiser than Johnny.', 'Who is less wise?')",
#  "('Wendy is higher than Harriet.', 'Who is less high?')",
#  "('Alfred is greater than Sophie.', 'Who is less great?')",
#  "('Ralph is taller than Mike.', 'Who is less tall?')",
#  "('Sara is slower than Elaine.', 'Who is less slow?')",
#  "('Fred is weaker than Mark.', 'Who is less weak?')",
#  "('Frances is older than Karen.', 'Who is less old?')",
#  "('Richard is older than Kenneth.', 'Who is less old?')",
#  "('Christine is smarter than Ellen.', 'Who is less smart?')",
#  "('Julia is younger than Ellen.', 'Who is less young?')",
#  "('Francis is weaker than Dave.', 'Who is less weak?')",
#  "('Anna is slower than Marie.', 'Who is less slow?')",
#  "('Tim is nicer than Charles.', 'Who is less nice?')",
#  "('Laura is cleaner than Judy.', 'Who is less clean?')",
#  "('Martin is wiser than Wendy.', 'Who is less wise?')",
#  "('Patricia is slower than Frances.', 'Who is less slow?')",
#  "('Anthony is smarter than Kevin.', 'Who is less smart?')",
#  "('Simon is tougher than Jonathan.', 'Who is less tough?')",
#  "('Maria is slower than William.', 'Who is less slow?')",
#  "('Deborah is slower than Mike.', 'Who is less slow?')",
#  "('Sophie is weaker than Scott.', 'Who is less weak?')",
#  "('Harold is faster than Walter.', 'Who is less fast?')",
#  "('Louise is stranger than Maria.', 'Who is less strange?')",
#  "('Charles is higher than Michael.', 'Who is less high?')",
#  "('Ben is taller than Carl.', 'Who is less tall?')",
#  "('Alfred is stranger than Matthew.', 'Who is less strange?')",
#  "('Joe is faster than Kathryn.', 'Who is less fast?')",
#  "('Charlie is tougher than Daniel.', 'Who is less tough?')",
#  "('Jeff is smaller than Alison.', 'Who is less small?')",
#  "('Jane is smarter than Samuel.', 'Who is less smart?')",
#  "('Rebecca is richer than Steve.', 'Who is less rich?')",
#  "('Dorothy is nicer than Alex.', 'Who is less nice?')",
#  "('Daniel is taller than Eleanor.', 'Who is less tall?')",
#  "('Carolyn is stranger than Jill.', 'Who is less strange?')",
#  "('Frank is cleaner than Charlotte.', 'Who is less clean?')",
#  "('Ralph is shorter than Cynthia.', 'Who is less short?')",
#  "('Frank is stranger than Karen.', 'Who is less strange?')",
#  "('Donald is stranger than Keith.', 'Who is less strange?')",
#  "('Paul is cleaner than Kathryn.', 'Who is less clean?')",
#  "('Jason is stronger than Sharon.', 'Who is less strong?')",
#  "('Jonathan is smarter than Catherine.', 'Who is less smart?')",
#  "('Angela is wiser than Arthur.', 'Who is less wise?')",
#  "('Angela is shorter than Fred.', 'Who is less short?')",
#  "('Frederick is smarter than Katherine.', 'Who is less smart?')",
#  "('Dorothy is slower than Anthony.', 'Who is less slow?')",
#  "('Ed is wiser than Marilyn.', 'Who is less wise?')",
#  "('Julie is nicer than Kevin.', 'Who is less nice?')",
#  "('Simon is older than Evelyn.', 'Who is less old?')",
#  "('Kathy is higher than Mike.', 'Who is less high?')",
#  "('Hugh is wiser than Joseph.', 'Who is less wise?')",
#  "('Maria is faster than Rebecca.', 'Who is less fast?')",
#  "('Marilyn is higher than Ian.', 'Who is less high?')",
#  "('Rachel is cleaner than Dan.', 'Who is less clean?')",
#  "('Rebecca is tougher than Eric.', 'Who is less tough?')",
#  "('Samuel is darker than Lawrence.', 'Who is less dark?')",
#  "('Karen is nicer than Amy.', 'Who is less nice?')",
#  "('John is cleaner than Anne.', 'Who is less clean?')",
#  "('Michelle is greater than Nancy.', 'Who is less great?')",
#  "('Heather is shorter than Ashley.', 'Who is less short?')",
#  "('Anna is richer than Florence.', 'Who is less rich?')",
#  "('Sharon is darker than Kim.', 'Who is less dark?')",
#  "('Linda is shorter than Donald.', 'Who is less short?')",
#  "('Christopher is taller than Samuel.', 'Who is less tall?')",
#  "('Stephanie is smarter than Kathleen.', 'Who is less smart?')",
#  "('Stephen is faster than Maria.', 'Who is less fast?')",
#  "('Billy is shorter than Julie.', 'Who is less short?')",
#  "('Charlie is cooler than Donald.', 'Who is less cool?')",
#  "('Alex is smaller than Johnny.', 'Who is less small?')",
#  "('Jean is cleaner than Benjamin.', 'Who is less clean?')",
#  "('Emily is nicer than Ray.', 'Who is less nice?')",
#  "('Katherine is richer than Fiona.', 'Who is less rich?')",
#  "('Jessica is older than Stephanie.', 'Who is less old?')",
#  "('Walter is greater than Nicole.', 'Who is less great?')",
#  "('Tony is richer than Kelly.', 'Who is less rich?')",
#  "('Jerry is greater than Don.', 'Who is less great?')",
#  "('Peter is stronger than Joan.', 'Who is less strong?')",
#  "('Kelly is younger than Jeff.', 'Who is less young?')",
#  "('Sue is wiser than Julie.', 'Who is less wise?')",
#  "('Eleanor is taller than Julia.', 'Who is less tall?')",
#  "('Sally is faster than Frances.', 'Who is less fast?')",
#  "('Anne is faster than Alan.', 'Who is less fast?')",
#  "('Joe is weaker than Linda.', 'Who is less weak?')",
#  "('Simon is shorter than Victoria.', 'Who is less short?')",
#  "('Angela is cooler than Michael.', 'Who is less cool?')",
#  "('Kathleen is slower than Peter.', 'Who is less slow?')",
#  "('Brian is stranger than Carl.', 'Who is less strange?')",
#  "('Ruth is tougher than Florence.', 'Who is less tough?')",
#  "('Diane is weaker than Anne.', 'Who is less weak?')",
#  "('Ralph is stronger than Marie.', 'Who is less strong?')",
#  "('Virginia is higher than Jeff.', 'Who is less high?')",
#  "('Lisa is stranger than Carl.', 'Who is less strange?')",
#  "('Claire is faster than Donna.', 'Who is less fast?')",
#  "('Rachel is stronger than Fred.', 'Who is less strong?')",
#  "('Fred is cooler than Roy.', 'Who is less cool?')",
#  "('Alan is nicer than Angela.', 'Who is less nice?')",
#  "('Eleanor is richer than Cynthia.', 'Who is less rich?')",
#  "('Florence is faster than Philip.', 'Who is less fast?')",
#  "('Martin is smaller than Stephen.', 'Who is less small?')",
#  "('Jessica is stronger than Jean.', 'Who is less strong?')",
#  "('Mike is darker than Margaret.', 'Who is less dark?')",
#  "('Sara is smarter than Wendy.', 'Who is less smart?')",
#  "('Keith is stranger than Joe.', 'Who is less strange?')",
#  "('Scott is greater than Alan.', 'Who is less great?')",
#  "('Gary is greater than George.', 'Who is less great?')",
#  "('Andrea is greater than Mary.', 'Who is less great?')",
#  "('Stephanie is cooler than Harry.', 'Who is less cool?')",
#  "('Don is younger than Alex.', 'Who is less young?')",
#  "('Jill is richer than Ellen.', 'Who is less rich?')",
#  "('Tom is faster than Harry.', 'Who is less fast?')",
#  "('Jane is tougher than Heather.', 'Who is less tough?')",
#  "('Eleanor is slower than Anna.', 'Who is less slow?')",
#  "('Andrew is greater than Kelly.', 'Who is less great?')",
#  "('Victoria is wiser than Frederick.', 'Who is less wise?')",
#  "('Colin is slower than Michael.', 'Who is less slow?')",
#  "('Susan is richer than Nick.', 'Who is less rich?')",
#  "('Simon is wiser than Donna.', 'Who is less wise?')",
#  "('Alice is richer than Alison.', 'Who is less rich?')",
#  "('Frances is slower than Francis.', 'Who is less slow?')",
#  "('Emma is shorter than Greg.', 'Who is less short?')",
#  "('Sophie is smaller than Katherine.', 'Who is less small?')",
#  "('Louise is richer than Jean.', 'Who is less rich?')",
#  "('Florence is slower than Kathy.', 'Who is less slow?')",
#  "('Kathleen is older than Charlotte.', 'Who is less old?')",
#  "('Lucy is greater than Lawrence.', 'Who is less great?')",
#  "('Diane is richer than Dick.', 'Who is less rich?')",
#  "('Patrick is stranger than Andrew.', 'Who is less strange?')",
#  "('Dick is cooler than Kenneth.', 'Who is less cool?')",
#  "('Dan is darker than Daniel.', 'Who is less dark?')",
#  "('Fiona is cooler than Rose.', 'Who is less cool?')",
#  "('Alex is tougher than Joan.', 'Who is less tough?')",
#  "('Diana is smaller than Charles.', 'Who is less small?')",
#  "('Dick is stronger than Edward.', 'Who is less strong?')",
#  "('Howard is higher than Deborah.', 'Who is less high?')",
#  "('George is cooler than Alison.', 'Who is less cool?')",
#  "('Florence is greater than Rachel.', 'Who is less great?')",
#  "('Jonathan is younger than Sam.', 'Who is less young?')",
#  "('Carolyn is nicer than Martin.', 'Who is less nice?')",
#  "('Sophie is stronger than Peter.', 'Who is less strong?')",
#  "('Harriet is cooler than Christopher.', 'Who is less cool?')",
#  "('Ralph is older than Hugh.', 'Who is less old?')",
#  "('Bruce is wiser than Simon.', 'Who is less wise?')",
#  "('Jack is smarter than Francis.', 'Who is less smart?')",
#  "('Cynthia is cooler than Melissa.', 'Who is less cool?')",
#  "('Eric is taller than Annie.', 'Who is less tall?')",
#  "('Christine is stronger than Jeff.', 'Who is less strong?')",
#  "('Benjamin is older than Jerry.', 'Who is less old?')",
#  "('Donna is younger than Ian.', 'Who is less young?')",
#  "('Fiona is younger than Charlie.', 'Who is less young?')",
#  "('Alex is slower than Leslie.', 'Who is less slow?')",
#  "('Fred is slower than Angela.', 'Who is less slow?')",
#  "('Sara is darker than Jonathan.', 'Who is less dark?')",
#  "('Steven is cooler than William.', 'Who is less cool?')",
#  "('Joseph is cleaner than Robert.', 'Who is less clean?')",
#  "('Paul is younger than Kathy.', 'Who is less young?')",
#  "('Robin is weaker than Lisa.', 'Who is less weak?')",
#  "('Susan is cooler than Bruce.', 'Who is less cool?')",
#  "('Melissa is weaker than Eric.', 'Who is less weak?')",
#  "('Anna is faster than Ashley.', 'Who is less fast?')",
#  "('Lawrence is stranger than Helen.', 'Who is less strange?')",
#  "('Christine is nicer than Dorothy.', 'Who is less nice?')",
#  "('Keith is greater than Rebecca.', 'Who is less great?')",
#  "('Lauren is smarter than Kim.', 'Who is less smart?')",
#  "('Tony is richer than Pamela.', 'Who is less rich?')",
#  "('Christine is slower than Chris.', 'Who is less slow?')",
#  "('Maria is younger than Ed.', 'Who is less young?')",
#  "('Sam is older than Janet.', 'Who is less old?')",
#  "('Francis is faster than Jason.', 'Who is less fast?')",
#  "('Matthew is greater than Tom.', 'Who is less great?')",
#  "('Don is higher than Thomas.', 'Who is less high?')",
#  "('Victoria is weaker than Maria.', 'Who is less weak?')",
#  "('Andrew is cleaner than Suzanne.', 'Who is less clean?')",
#  "('Mike is stronger than Anne.', 'Who is less strong?')",
#  "('Edwin is wiser than Alexander.', 'Who is less wise?')",
#  "('Frances is richer than Steve.', 'Who is less rich?')",
#  "('Alfred is wiser than Ryan.', 'Who is less wise?')",
#  "('Jason is stranger than Ian.', 'Who is less strange?')",
#  "('Kevin is younger than Louise.', 'Who is less young?')",
#  "('Billy is richer than Elizabeth.', 'Who is less rich?')",
#  "('Larry is older than Louis.', 'Who is less old?')",
#  "('Patrick is greater than Lynn.', 'Who is less great?')",
#  "('Jimmy is smaller than Cynthia.', 'Who is less small?')",
#  "('Don is cooler than Carl.', 'Who is less cool?')",
#  "('Ray is darker than Sam.', 'Who is less dark?')",
#  "('Robert is cleaner than Mary.', 'Who is less clean?')",
#  "('Sandra is nicer than David.', 'Who is less nice?')",
#  "('Elaine is younger than Thomas.', 'Who is less young?')",
#  "('Kim is cooler than Mike.', 'Who is less cool?')",
#  "('Virginia is faster than Patricia.', 'Who is less fast?')",
#  "('Barbara is taller than Scott.', 'Who is less tall?')",
#  "('Victoria is taller than Philip.', 'Who is less tall?')",
#  "('Louise is cooler than Lynn.', 'Who is less cool?')",
#  "('Patrick is cleaner than Emma.', 'Who is less clean?')",
#  "('Karen is greater than Bill.', 'Who is less great?')",
#  "('Alan is really enthusiastic about the project. Roy is enthusiastic about the project.', 'Who is most enthusiastic about the project?')",
#  "('Alan is really enthusiastic about the project. Roy is enthusiastic about the project.', 'Who is least enthusiastic about the project?')",
#  "('Roy is enthusiastic about the project. Alan is really enthusiastic about the project.', 'Who is most enthusiastic about the project?')",
#  "('Roy is enthusiastic about the project. Alan is really enthusiastic about the project.', 'Who is least enthusiastic about the project?')",
#  ...]
