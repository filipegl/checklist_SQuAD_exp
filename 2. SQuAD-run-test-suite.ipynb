# %% [markdown]
# # Running checklist test suite for SQuAD
# Source: code from https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/tutorials/5.%20Testing%20transformer%20pipelines.ipynb with some changes

# %%
from checklist.test_suite import TestSuite
import numpy as np
from transformers import pipeline

# %%
model = pipeline('question-answering', model="distilbert-base-cased-distilled-squad")
model({
    'context': 'A new strain of flu that has the potential to become a pandemic has been identified by scientists.',
    'question': 'What has been discovered by scientists?'
})
# Out:
# {'score': 0.38112872838974,
#  'start': 0,
#  'end': 19,
#  'answer': 'A new strain of flu'}

# %%
suite_path = './squad_suite2.pkl'
suite = TestSuite.from_file(suite_path)

# %%
def predconfs(context_question_pairs):
    preds = []
    confs = []
    for c, q in context_question_pairs:
        try:
            p = model(question=q, context=c, truncation=True, )
        except:
            print('Failed', q)
            preds.append(' ')
            confs.append(1)
        preds.append(p['answer'])
        confs.append(p['score'])
    return preds, np.array(confs)

def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

# %%
# %%time
suite.run(predconfs, n=100, overwrite=True)
# Out:
# Running A is COMP than B. Who is more COMP?
# Predicting 100 examples
# Running A is COMP than B. Who is less COMP?
# Predicting 100 examples
# Running Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Predicting 1200 examples
# Running size, shape, age, color
# Predicting 400 examples
# Running Profession vs nationality
# Predicting 1000 examples
# Running Animal vs Vehicle
# Predicting 400 examples
# Running Animal vs Vehicle v2
# Predicting 400 examples
# Running Synonyms
# Predicting 400 examples
# Running A is COMP than B. Who is antonym(COMP)? B
# Predicting 400 examples
# Running A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Predicting 1600 examples
# Running Question typo
# Predicting 200 examples
# Running Question contractions
# Predicting 200 examples
# Running Add random sentence to context
# Predicting 300 examples
# Running Change name everywhere
# Predicting 1100 examples
# Running Change location everywhere
# Predicting 1100 examples
# Running There was a change in profession
# Predicting 200 examples
# Running Understanding before / after -> first / last.
# Predicting 400 examples
# Running Negation in context, may or may not be in question
# Predicting 400 examples
# Running Negation in question only.
# Predicting 800 examples
# Running M/F failure rates should be similar for different professions
# Predicting 100 examples
# Running Basic coref, he / she
# Predicting 800 examples
# Running Basic coref, his / her
# Predicting 200 examples
# Running Former / Latter
# Predicting 400 examples
# Running Agent / object distinction
# Predicting 400 examples
# Running Agent / object distinction with 3 agents
# Predicting 1600 examples
# CPU times: total: 2min 52s
# Wall time: 7min 19s

# %%
suite.summary(n=0)
# Out:
# Vocabulary
#
# A is COMP than B. Who is more COMP?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    3 (3.0%)
#
#
# A is COMP than B. Who is less COMP?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
# Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
#
#
# Taxonomy
#
# size, shape, age, color
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
# Profession vs nationality
# Test cases:      500
# Test cases run:  100
# Fails (rate):    18 (18.0%)
#
#
# Animal vs Vehicle
# Test cases:      500
# Test cases run:  100
# Fails (rate):    60 (60.0%)
#
#
# Animal vs Vehicle v2
# Test cases:      498
# Test cases run:  100
# Fails (rate):    63 (63.0%)
#
#
# Synonyms
# Test cases:      449
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
#
# A is COMP than B. Who is antonym(COMP)? B
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
# A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
#
#
# Robustness
#
# Question typo
# Test cases:      500
# Test cases run:  100
# Fails (rate):    15 (15.0%)
#
#
# Question contractions
# Test cases:      500
# Test cases run:  100
# Fails (rate):    11 (11.0%)
#
#
# Add random sentence to context
# Test cases:      500
# Test cases run:  100
# Fails (rate):    9 (9.0%)
#
#
#
#
# NER
#
# Change name everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    4 (4.0%)
#
#
# Change location everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    4 (4.0%)
#
#
#
#
# Fairness
#
# M/F failure rates should be similar for different professions
# Test cases:      2000
# Test cases run:  100
# Fails (rate):    84 (84.0%)
#
#
#
#
# Temporal
#
# There was a change in profession
# Test cases:      488
# Test cases run:  100
# Fails (rate):    1 (1.0%)
#
#
# Understanding before / after -> first / last.
# Test cases:      499
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
#
#
# Negation
#
# Negation in context, may or may not be in question
# Test cases:      495
# Test cases run:  100
# Fails (rate):    95 (95.0%)
#
#
# Negation in question only.
# Test cases:      486
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
#
#
# Coref
#
# Basic coref, he / she
# Test cases:      486
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
# Basic coref, his / her
# Test cases:      500
# Test cases run:  100
# Fails (rate):    98 (98.0%)
#
#
# Former / Latter
# Test cases:      485
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
#
#
#
# SRL
#
# Agent / object distinction
# Test cases:      499
# Test cases run:  100
# Fails (rate):    62 (62.0%)
#
#
# Agent / object distinction with 3 agents
# Test cases:      492
# Test cases run:  100
# Fails (rate):    100 (100.0%)

# %%
suite.summary(format_example_fn=format_squad_with_context)
# Out:
# Vocabulary
#
# A is COMP than B. Who is more COMP?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    3 (3.0%)
#
# Example fails:
# C: Sarah is hotter than Rose.
# Q: Who is hotter?
# A: Sarah
# P: Sarah is hotter than Rose
#
# ----
# C: Janet is cooler than Harriet.
# Q: Who is cooler?
# A: Janet
# P: Harriet
#
# ----
# C: Claire is thinner than Anna.
# Q: Who is thinner?
# A: Claire
# P: Anna
#
# ----
#
#
# A is COMP than B. Who is less COMP?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Eric is weaker than Leslie.
# Q: Who is less weaker?
# A: Leslie
# P: Eric
#
# ----
# C: Catherine is older than William.
# Q: Who is less older?
# A: William
# P: Catherine
#
# ----
# C: Jean is smarter than Ian.
# Q: Who is less smarter?
# A: Ian
# P: Jean
#
# ----
#
#
# Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Charlie is enthusiastic about the project. Dave is particularly enthusiastic about the project.
# Q: Who is least enthusiastic about the project?
# A: Charlie
# P: Dave
#
# C: Dave is enthusiastic about the project. Charlie is somewhat enthusiastic about the project.
# Q: Who is most enthusiastic about the project?
# A: Dave
# P: Charlie
#
# C: Charlie is somewhat enthusiastic about the project. Dave is particularly enthusiastic about the project.
# Q: Who is least enthusiastic about the project?
# A: Charlie
# P: Dave
#
#
# ----
# C: Amanda is hopeful about the project. Billy is mildly hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Billy
# P: Amanda
#
# C: Amanda is quite hopeful about the project. Billy is mildly hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Billy
# P: Amanda
#
# C: Amanda is quite hopeful about the project. Billy is hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Billy
# P: Amanda
#
#
# ----
# C: Ellen is somewhat hopeful about the project. Emma is hopeful about the project.
# Q: Who is most hopeful about the project?
# A: Emma
# P: Ellen
#
# C: Emma is hopeful about the project. Ellen is somewhat hopeful about the project.
# Q: Who is most hopeful about the project?
# A: Emma
# P: Ellen
#
# C: Emma is hopeful about the project. Ellen is somewhat hopeful about the project.
# Q: Who is least hopeful about the project?
# A: Ellen
# P: Emma
#
#
# ----
#
#
#
#
# Taxonomy
#
# size, shape, age, color
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: There is a big oval thing in the room.
# Q: What size is the thing?
# A: big
# P: oval
#
# C: There is a thing in the room. The thing is big and oval.
# Q: What size is the thing?
# A: big
# P: big and oval
#
# C: There is a thing in the room. The thing is big and oval.
# Q: What shape is the thing?
# A: oval
# P: big and oval
#
#
# ----
# C: There is a table in the room. The table is enormous and orange.
# Q: What size is the table?
# A: enormous
# P: enormous and orange
#
# C: There is an enormous orange table in the room.
# Q: What size is the table?
# A: enormous
# P: orange
#
#
# ----
# C: There is a table in the room. The table is small and grey.
# Q: What size is the table?
# A: small
# P: small and grey
#
# C: There is a small grey table in the room.
# Q: What size is the table?
# A: small
# P: grey
#
#
# ----
#
#
# Profession vs nationality
# Test cases:      500
# Test cases run:  100
# Fails (rate):    18 (18.0%)
#
# Example fails:
# C: Kathy is a Pakistani agent.
# Q: What is Kathy's job?
# A: agent
# P: Pakistani agent
#
#
# ----
# C: Donna is a Japanese intern.
# Q: What is Donna's job?
# A: intern
# P: Japanese intern
#
# C: Donna is an intern and Japanese.
# Q: What is Donna's job?
# A: intern
# P: an intern and Japanese
#
#
# ----
# C: Martin is a Pakistani executive.
# Q: What is Martin's job?
# A: executive
# P: Pakistani executive
#
#
# ----
#
#
# Animal vs Vehicle
# Test cases:      500
# Test cases run:  100
# Fails (rate):    60 (60.0%)
#
# Example fails:
# C: Joseph has a firetruck and a serpent.
# Q: What animal does Joseph have?
# A: serpent
# P: firetruck and a serpent
#
# C: Joseph has a firetruck and a serpent.
# Q: What vehicle does Joseph have?
# A: firetruck
# P: firetruck and a serpent
#
#
# ----
# C: Lynn has a bull and a minivan.
# Q: What vehicle does Lynn have?
# A: minivan
# P: a bull and a minivan
#
#
# ----
# C: Ryan has a rabbit and a minivan.
# Q: What vehicle does Ryan have?
# A: minivan
# P: a rabbit and a minivan
#
#
# ----
#
#
# Animal vs Vehicle v2
# Test cases:      498
# Test cases run:  100
# Fails (rate):    63 (63.0%)
#
# Example fails:
# C: Alice bought a cow. Harold bought a train.
# Q: Who bought a vehicle?
# A: Harold
# P: Alice
#
#
# ----
# C: Alexandra bought a bull. Lucy bought a bike.
# Q: Who bought an animal?
# A: Alexandra
# P: Lucy
#
# C: Lucy bought a bike. Alexandra bought a bull.
# Q: Who bought an animal?
# A: Alexandra
# P: Lucy
#
#
# ----
# C: Ann bought a hamster. Joe bought a minivan.
# Q: Who bought an animal?
# A: Ann
# P: Ann bought a hamster. Joe
#
# C: Joe bought a minivan. Ann bought a hamster.
# Q: Who bought an animal?
# A: Ann
# P: Joe
#
#
# ----
#
#
# Synonyms
# Test cases:      449
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
# Example fails:
# C: Jane is very outspoken. Brian is very brave.
# Q: Who is vocal?
# A: Jane
# P: Brian
#
#
# ----
# C: Ken is very happy. Jason is very spiritual.
# Q: Who is joyful?
# A: Ken
# P: Jason
#
#
# ----
# C: Ian is very outspoken. Sara is very brave.
# Q: Who is vocal?
# A: Ian
# P: Sara
#
#
# ----
#
#
# A is COMP than B. Who is antonym(COMP)? B
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Charlotte is worse than Frances.
# Q: Who is better?
# A: Frances
# P: Charlotte
#
# C: Frances is better than Charlotte.
# Q: Who is worse?
# A: Charlotte
# P: Frances
#
#
# ----
# C: Gary is warmer than Nick.
# Q: Who is colder?
# A: Nick
# P: Gary
#
# C: Nick is colder than Gary.
# Q: Who is warmer?
# A: Gary
# P: Nick
#
#
# ----
# C: Alexandra is louder than Anna.
# Q: Who is quieter?
# A: Anna
# P: Alexandra
#
# C: Anna is quieter than Alexandra.
# Q: Who is louder?
# A: Alexandra
# P: Anna
#
#
# ----
#
#
# A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Test cases:      496
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Deborah is more secular than Simon.
# Q: Who is less secular?
# A: Simon
# P: Deborah
#
# C: Deborah is less religious than Simon.
# Q: Who is less secular?
# A: Simon
# P: Deborah
#
# C: Deborah is more secular than Simon.
# Q: Who is more religious?
# A: Simon
# P: Deborah
#
#
# ----
# C: Leslie is more rude than Stephanie.
# Q: Who is less rude?
# A: Stephanie
# P: Leslie
#
# C: Leslie is more rude than Stephanie.
# Q: Who is more polite?
# A: Stephanie
# P: Leslie
#
# C: Leslie is less polite than Stephanie.
# Q: Who is more polite?
# A: Stephanie
# P: Leslie
#
#
# ----
# C: Alice is more happy than Jim.
# Q: Who is more unhappy?
# A: Jim
# P: Alice
#
# C: Alice is more happy than Jim.
# Q: Who is less happy?
# A: Jim
# P: Alice
#
# C: Jim is more unhappy than Alice.
# Q: Who is less unhappy?
# A: Alice
# P: Jim
#
#
# ----
#
#
#
#
# Robustness
#
# Question typo
# Test cases:      500
# Test cases run:  100
# Fails (rate):    15 (15.0%)
#
# Example fails:
# C: Domestic dogs have been selectively bred for millennia for various behaviors, sensory capabilities, and physical attributes. Modern dog breeds show more variation in size, appearance, and behavior than any other domestic animal. Dogs are predators and scavengers, and like many other predatory mammals, the dog has powerful muscles, fused wrist bones, a cardiovascular system that supports both sprinting and endurance, and teeth for catching and tearing.
# Q: What are a dog's teeth mainly used for?
# P: catching and tearing
#
# C: Domestic dogs have been selectively bred for millennia for various behaviors, sensory capabilities, and physical attributes. Modern dog breeds show more variation in size, appearance, and behavior than any other domestic animal. Dogs are predators and scavengers, and like many other predatory mammals, the dog has powerful muscles, fused wrist bones, a cardiovascular system that supports both sprinting and endurance, and teeth for catching and tearing.
# Q: What are a dog's teteh mainly used for?
# P: predators and scavengers
#
#
# ----
# C: In the 18th century, the Moroccan Sultan Moulay Ismail "the Bloodthirsty" (1672–1727) raised a corps of 150,000 black slaves, called his Black Guard, who coerced the country into submission.
# Q: When did the Black Guard exist?
# P: 18th century
#
# C: In the 18th century, the Moroccan Sultan Moulay Ismail "the Bloodthirsty" (1672–1727) raised a corps of 150,000 black slaves, called his Black Guard, who coerced the country into submission.
# Q: When did the Black uGard exist?
# P: 1727
#
#
# ----
# C: Although exotic on Earth, one of the most common ions in the universe is the H+
# 3 ion, known as protonated molecular hydrogen or the trihydrogen cation.
# Q: What kind of cation is the H+3 knowns as?
# P: trihydrogen
#
# C: Although exotic on Earth, one of the most common ions in the universe is the H+
# 3 ion, known as protonated molecular hydrogen or the trihydrogen cation.
# Q: What kind of ctaion is the H+3 knowns as?
# P: protonated molecular hydrogen
#
#
# ----
#
#
# Question contractions
# Test cases:      500
# Test cases run:  100
# Fails (rate):    11 (11.0%)
#
# Example fails:
# C: Chopin has figured extensively in Polish literature, both in serious critical studies of his life and music and in fictional treatments. The earliest manifestation was probably an 1830 sonnet on Chopin by Leon Ulrich. French writers on Chopin (apart from Sand) have included Marcel Proust and André Gide; and he has also featured in works of Gottfried Benn and Boris Pasternak. There are numerous biographies of Chopin in English (see bibliography for some of these).
# Q: What is the earliest sighting of Chopin in Polish Literature?
# P: an 1830 sonnet on Chopin by Leon Ulrich
#
# C: Chopin has figured extensively in Polish literature, both in serious critical studies of his life and music and in fictional treatments. The earliest manifestation was probably an 1830 sonnet on Chopin by Leon Ulrich. French writers on Chopin (apart from Sand) have included Marcel Proust and André Gide; and he has also featured in works of Gottfried Benn and Boris Pasternak. There are numerous biographies of Chopin in English (see bibliography for some of these).
# Q: What's the earliest sighting of Chopin in Polish Literature?
# P: 1830 sonnet on Chopin by Leon Ulrich
#
#
# ----
# C: The essential usefulness of a transistor comes from its ability to use a small signal applied between one pair of its terminals to control a much larger signal at another pair of terminals. This property is called gain. It can produce a stronger output signal, a voltage or current, which is proportional to a weaker input signal; that is, it can act as an amplifier. Alternatively, the transistor can be used to turn current on or off in a circuit as an electrically controlled switch, where the amount of current is determined by other circuit elements.
# Q: What is an additional use of the transistor?
# P: turn current on or off in a circuit as an electrically controlled switch
#
# C: The essential usefulness of a transistor comes from its ability to use a small signal applied between one pair of its terminals to control a much larger signal at another pair of terminals. This property is called gain. It can produce a stronger output signal, a voltage or current, which is proportional to a weaker input signal; that is, it can act as an amplifier. Alternatively, the transistor can be used to turn current on or off in a circuit as an electrically controlled switch, where the amount of current is determined by other circuit elements.
# Q: What's an additional use of the transistor?
# P: to turn current on or off in a circuit as an electrically controlled switch
#
#
# ----
# C: Plants depend on certain edaphic (soil) and climatic factors in their environment but can modify these factors too. For example, they can change their environment's albedo, increase runoff interception, stabilize mineral soils and develop their organic content, and affect local temperature. Plants compete with other organisms in their ecosystem for resources. They interact with their neighbours at a variety of spatial scales in groups, populations and communities that collectively constitute vegetation. Regions with characteristic vegetation types and dominant plants as well as similar abiotic and biotic factors, climate, and geography make up biomes like tundra or tropical rainforest.
# Q: What are groupings of similar plants?
# P: biomes
#
# C: Plants depend on certain edaphic (soil) and climatic factors in their environment but can modify these factors too. For example, they can change their environment's albedo, increase runoff interception, stabilize mineral soils and develop their organic content, and affect local temperature. Plants compete with other organisms in their ecosystem for resources. They interact with their neighbours at a variety of spatial scales in groups, populations and communities that collectively constitute vegetation. Regions with characteristic vegetation types and dominant plants as well as similar abiotic and biotic factors, climate, and geography make up biomes like tundra or tropical rainforest.
# Q: What're groupings of similar plants?
# P: biomes like tundra or tropical rainforest
#
#
# ----
#
#
# Add random sentence to context
# Test cases:      500
# Test cases run:  100
# Fails (rate):    9 (9.0%)
#
# Example fails:
# C: On April 26, 1988, about 500 people participated in a march organized by the Ukrainian Cultural Club on Kiev's Khreschatyk Street to mark the second anniversary of the Chernobyl nuclear disaster, carrying placards with slogans like "Openness and Democracy to the End." Between May and June 1988, Ukrainian Catholics in western Ukraine celebrated the Millennium of Christianity in Kievan Rus' in secret by holding services in the forests of Buniv, Kalush, Hoshiv, and Zarvanytsia. On June 5, 1988, as the official celebrations of the Millennium were held in Moscow, the Ukrainian Cultural Club hosted its own observances in Kiev at the monument to St. Volodymyr the Great, the grand prince of Kievan Rus'.
# Q: What did the marchers wish to commemorate?
# P: the second anniversary of the Chernobyl nuclear disaster
#
# C: Besides major infrastructural projects, the colonial authorities invested significantly in the agricultural sector. On April 26, 1988, about 500 people participated in a march organized by the Ukrainian Cultural Club on Kiev's Khreschatyk Street to mark the second anniversary of the Chernobyl nuclear disaster, carrying placards with slogans like "Openness and Democracy to the End." Between May and June 1988, Ukrainian Catholics in western Ukraine celebrated the Millennium of Christianity in Kievan Rus' in secret by holding services in the forests of Buniv, Kalush, Hoshiv, and Zarvanytsia. On June 5, 1988, as the official celebrations of the Millennium were held in Moscow, the Ukrainian Cultural Club hosted its own observances in Kiev at the monument to St. Volodymyr the Great, the grand prince of Kievan Rus'.
# Q: What did the marchers wish to commemorate?
# P: Chernobyl nuclear disaster
#
#
# ----
# C: The cantons have a permanent constitutional status and, in comparison with the situation in other countries, a high degree of independence. Under the Federal Constitution, all 26 cantons are equal in status. Each canton has its own constitution, and its own parliament, government and courts. However, there are considerable differences between the individual cantons, most particularly in terms of population and geographical area. Their populations vary between 15,000 (Appenzell Innerrhoden) and 1,253,500 (Zürich), and their area between 37 km2 (14 sq mi) (Basel-Stadt) and 7,105 km2 (2,743 sq mi) (Graubünden). The Cantons comprise a total of 2,485 municipalities. Within Switzerland there are two enclaves: Büsingen belongs to Germany, Campione d'Italia belongs to Italy.
# Q: How large is the smallest canton?
# P: 37 km2 (14 sq mi)
#
# C: The cantons have a permanent constitutional status and, in comparison with the situation in other countries, a high degree of independence. Under the Federal Constitution, all 26 cantons are equal in status. Each canton has its own constitution, and its own parliament, government and courts. However, there are considerable differences between the individual cantons, most particularly in terms of population and geographical area. Their populations vary between 15,000 (Appenzell Innerrhoden) and 1,253,500 (Zürich), and their area between 37 km2 (14 sq mi) (Basel-Stadt) and 7,105 km2 (2,743 sq mi) (Graubünden). The Cantons comprise a total of 2,485 municipalities. Within Switzerland there are two enclaves: Büsingen belongs to Germany, Campione d'Italia belongs to Italy.At the 57th Annual Grammy Awards in February 2015, Beyoncé was nominated for six awards, ultimately winning three: Best R&B Performance and Best R&B Song for "Drunk in Love", and Best Surround Sound Album for Beyoncé.
# Q: How large is the smallest canton?
# P: 7,105 km2 (2,743 sq mi)
#
#
# ----
# C: In theism, God is the creator and sustainer of the universe, while in deism, God is the creator, but not the sustainer, of the universe. Monotheism is the belief in the existence of one God or in the oneness of God. In pantheism, God is the universe itself. In atheism, God is not believed to exist, while God is deemed unknown or unknowable within the context of agnosticism. God has also been conceived as being incorporeal (immaterial), a personal being, the source of all moral obligation, and the "greatest conceivable existent". Many notable philosophers have developed arguments for and against the existence of God.
# Q: In what belief is God the creator and sustainer of the universe?
# P: theism
#
# C: The "Low" in Old Low Franconian refers to the Frankish spoken in the Low Countries where it was not influenced by the High German consonant shift, as opposed to Central and high Franconian in Germany. In theism, God is the creator and sustainer of the universe, while in deism, God is the creator, but not the sustainer, of the universe. Monotheism is the belief in the existence of one God or in the oneness of God. In pantheism, God is the universe itself. In atheism, God is not believed to exist, while God is deemed unknown or unknowable within the context of agnosticism. God has also been conceived as being incorporeal (immaterial), a personal being, the source of all moral obligation, and the "greatest conceivable existent". Many notable philosophers have developed arguments for and against the existence of God.
# Q: In what belief is God the creator and sustainer of the universe?
# P: deism
#
#
# ----
#
#
#
#
# NER
#
# Change name everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    4 (4.0%)
#
# Example fails:
# C: Burke's last publications were the Letters on a Regicide Peace (October 1796), called forth by negotiations for peace with France by the Pitt government. Burke regarded this as appeasement, injurious to national dignity and honour. In his Second Letter, Burke wrote of the French Revolutionary Government: "Individuality is left out of their scheme of government. The State is all in all. Everything is referred to the production of force; afterwards, everything is trusted to the use of it. It is military in its principle, in its maxims, in its spirit, and in all its movements. The State has dominion and conquest for its sole objects—dominion over minds by proselytism, over bodies by arms".
# Q: What did Burke think were the French Revolutionary Government's only goals?
# P: conquest
#
# C: Adam's last publications were the Letters on a Regicide Peace (October 1796), called forth by negotiations for peace with France by the Pitt government. Adam regarded this as appeasement, injurious to national dignity and honour. In his Second Letter, Adam wrote of the French Revolutionary Government: "Individuality is left out of their scheme of government. The State is all in all. Everything is referred to the production of force; afterwards, everything is trusted to the use of it. It is military in its principle, in its maxims, in its spirit, and in all its movements. The State has dominion and conquest for its sole objects—dominion over minds by proselytism, over bodies by arms".
# Q: What did Adam think were the French Revolutionary Government's only goals?
# P: The State has dominion and conquest
#
# C: James's last publications were the Letters on a Regicide Peace (October 1796), called forth by negotiations for peace with France by the Pitt government. James regarded this as appeasement, injurious to national dignity and honour. In his Second Letter, James wrote of the French Revolutionary Government: "Individuality is left out of their scheme of government. The State is all in all. Everything is referred to the production of force; afterwards, everything is trusted to the use of it. It is military in its principle, in its maxims, in its spirit, and in all its movements. The State has dominion and conquest for its sole objects—dominion over minds by proselytism, over bodies by arms".
# Q: What did James think were the French Revolutionary Government's only goals?
# P: The State has dominion and conquest
#
#
# ----
# C: Unlike in Westminster style legislatures or as with the Senate Majority Leader, the House Majority Leader's duties and prominence vary depending upon the style and power of the Speaker of the House. Typically, the Speaker does not participate in debate and rarely votes on the floor. In some cases, Majority Leaders have been more influential than the Speaker; notably Tom DeLay who was more prominent than Speaker Dennis Hastert. In addition, Speaker Newt Gingrich delegated to Dick Armey an unprecedented level of authority over scheduling legislation on the House floor.
# Q: Who was speaker of the house When Tom Delay was Majority leader?
# P: Dennis Hastert
#
# C: Unlike in Westminster style legislatures or as with the Senate Majority Leader, the House Majority Leader's duties and prominence vary depending upon the style and power of the Speaker of the House. Typically, the Speaker does not participate in debate and rarely votes on the floor. In some cases, Majority Leaders have been more influential than the Speaker; notably Michael Martinez who was more prominent than Speaker Dennis Hastert. In addition, Speaker Newt Gingrich delegated to Dick Armey an unprecedented level of authority over scheduling legislation on the House floor.
# Q: Who was speaker of the house When Tom Delay was Majority leader?
# P: Michael Martinez
#
# C: Unlike in Westminster style legislatures or as with the Senate Majority Leader, the House Majority Leader's duties and prominence vary depending upon the style and power of the Speaker of the House. Typically, the Speaker does not participate in debate and rarely votes on the floor. In some cases, Majority Leaders have been more influential than the Speaker; notably Christopher James who was more prominent than Speaker Dennis Hastert. In addition, Speaker Newt Gingrich delegated to Dick Armey an unprecedented level of authority over scheduling legislation on the House floor.
# Q: Who was speaker of the house When Tom Delay was Majority leader?
# P: Christopher James
#
#
# ----
# C: The Angel, Islington was formerly a coaching inn, the first on the route northwards out of London, where Thomas Paine is believed to have written much of The Rights of Man. It was mentioned by Charles Dickens, became a Lyons Corner House, and is now a Co-operative Bank.
# Q: At what pub did Thomas Paine write The Rights of Man?
# P: The Angel
#
# C: The Jose, Islington was formerly a coaching inn, the first on the route northwards out of London, where Thomas Paine is believed to have written much of The Rights of Man. It was mentioned by Charles Dickens, became a Lyons Corner House, and is now a Co-operative Bank.
# Q: At what pub did Thomas Paine write The Rights of Man?
# P: The Jose, Islington
#
#
# ----
#
#
# Change location everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    4 (4.0%)
#
# Example fails:
# C: A dispute during the Lausanne Congress of Supreme Councils of 1875 prompted the Grand Orient de France to commission a report by a Protestant pastor which concluded that, as Freemasonry was not a religion, it should not require a religious belief. The new constitutions read, "Its principles are absolute liberty of conscience and human solidarity", the existence of God and the immortality of the soul being struck out. It is possible that the immediate objections of the United Grand Lodge of England were at least partly motivated by the political tension between France and Britain at the time. The result was the withdrawal of recognition of the Grand Orient of France by the United Grand Lodge of England, a situation that continues today.
# Q: How was the belief of the existance of God and the immortal soul replaced in the constitution?
# P: absolute liberty of conscience and human solidarity
#
# C: A dispute during the Lausanne Congress of Supreme Councils of 1875 prompted the Grand Orient de United States to commission a report by a Protestant pastor which concluded that, as Freemasonry was not a religion, it should not require a religious belief. The new constitutions read, "Its principles are absolute liberty of conscience and human solidarity", the existence of God and the immortality of the soul being struck out. It is possible that the immediate objections of the United Grand Lodge of England were at least partly motivated by the political tension between United States and Britain at the time. The result was the withdrawal of recognition of the Grand Orient of United States by the United Grand Lodge of England, a situation that continues today.
# Q: How was the belief of the existance of God and the immortal soul replaced in the constitution?
# P: Its principles are absolute liberty of conscience and human solidarity
#
#
# ----
# C: The United Kingdom has traditionally been governed as a unitary state by the Westminster Parliament in London. Instead of adopting a federal model, the UK has relied on gradual devolution to decentralise political power. Devolution in the UK began with the Government of Ireland Act 1914 which granted home rule to Ireland as a constituent country of the former United Kingdom of Great Britain and Ireland. Following the partition of Ireland in 1921 which saw the creation of the sovereign Irish Free State (which eventually evolved into the modern day Republic of Ireland), Northern Ireland retained its devolved government through the Parliament of Northern Ireland, the only part of the UK to have such a body at this time. This body was suspended in 1972 and Northern Ireland was governed by direct rule during the period of conflict known as The Troubles.
# Q: What is Irish Free State?
# P: Republic of Ireland
#
# C: The United Kingdom has traditionally been governed as a unitary state by the Westminster Parliament in London. Instead of adopting a federal model, the UK has relied on gradual devolution to decentralise political power. Devolution in the UK began with the Government of Pakistan Act 1914 which granted home rule to Pakistan as a constituent country of the former United Kingdom of Great Britain and Pakistan. Following the partition of Pakistan in 1921 which saw the creation of the sovereign Irish Free State (which eventually evolved into the modern day Republic of Pakistan), Northern Pakistan retained its devolved government through the Parliament of Northern Pakistan, the only part of the UK to have such a body at this time. This body was suspended in 1972 and Northern Pakistan was governed by direct rule during the period of conflict known as The Troubles.
# Q: What is Irish Free State?
# P: which eventually evolved into the modern day Republic of Pakistan
#
#
# ----
# C: Portugal’s national energy transmission company, Redes Energéticas Nacionais (REN), uses sophisticated modeling to predict weather, especially wind patterns, and computer programs to calculate energy from the various renewable-energy plants. Before the solar/wind revolution, Portugal had generated electricity from hydropower plants on its rivers for decades. New programs combine wind and water: wind-driven turbines pump water uphill at night, the most blustery period; then the water flows downhill by day, generating electricity, when consumer demand is highest. Portugal’s distribution system is also now a two-way street. Instead of just delivering electricity, it draws electricity from even the smallest generators, like rooftop solar panels. The government aggressively encouraged such contributions by setting a premium price for those who buy rooftop-generated solar electricity.
# Q: What is the name of Portugal's national energy transmission company?
# P: Redes Energéticas Nacionais
#
# C: Uzbekistan’s national energy transmission company, Redes Energéticas Nacionais (REN), uses sophisticated modeling to predict weather, especially wind patterns, and computer programs to calculate energy from the various renewable-energy plants. Before the solar/wind revolution, Uzbekistan had generated electricity from hydropower plants on its rivers for decades. New programs combine wind and water: wind-driven turbines pump water uphill at night, the most blustery period; then the water flows downhill by day, generating electricity, when consumer demand is highest. Uzbekistan’s distribution system is also now a two-way street. Instead of just delivering electricity, it draws electricity from even the smallest generators, like rooftop solar panels. The government aggressively encouraged such contributions by setting a premium price for those who buy rooftop-generated solar electricity.
# Q: What is the name of Uzbekistan's national energy transmission company?
# P: Redes Energéticas Nacionais (REN)
#
#
# ----
#
#
#
#
# Fairness
#
# M/F failure rates should be similar for different professions
# Test cases:      2000
# Test cases run:  100
# Fails (rate):    84 (84.0%)
#
# Example fails:
# C: Leslie is not a nurse, Colin is.
# Q: Who is a nurse?
# A: Colin
# P: Leslie
#
# ----
# C: Ashley is not a doctor, Edwin is.
# Q: Who is a doctor?
# A: Edwin
# P: Ashley
#
# ----
# C: Steve is not a secretary, Sue is.
# Q: Who is a secretary?
# A: Sue
# P: Steve
#
# ----
#
#
#
#
# Temporal
#
# There was a change in profession
# Test cases:      488
# Test cases run:  100
# Fails (rate):    1 (1.0%)
#
# Example fails:
# C: Both John and Philip were actresss, but there was a change in Philip, who is now a model.
# Q: Who is a model?
# A: Philip
# P: John and Philip
#
#
# ----
#
#
# Understanding before / after -> first / last.
# Test cases:      499
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Daniel became a administrator before Mark did.
# Q: Who became a administrator last?
# A: Mark
# P: Daniel
#
# C: Mark became a administrator after Daniel did.
# Q: Who became a administrator first?
# A: Daniel
# P: Mark
#
#
# ----
# C: Helen became a intern before Katie did.
# Q: Who became a intern last?
# A: Katie
# P: Helen
#
# C: Katie became a intern after Helen did.
# Q: Who became a intern first?
# A: Helen
# P: Katie
#
#
# ----
# C: Sally became a editor before Marie did.
# Q: Who became a editor last?
# A: Marie
# P: Sally
#
# C: Marie became a editor after Sally did.
# Q: Who became a editor first?
# A: Sally
# P: Marie
#
#
# ----
#
#
#
#
# Negation
#
# Negation in context, may or may not be in question
# Test cases:      495
# Test cases run:  100
# Fails (rate):    95 (95.0%)
#
# Example fails:
# C: Lynn is not an intern. Michael is.
# Q: Who is an intern?
# A: Michael
# P: Lynn
#
#
# ----
# C: Sally is not an investor. Patrick is.
# Q: Who is an investor?
# A: Patrick
# P: Sally
#
#
# ----
# C: Ray is not an investigator. Colin is.
# Q: Who is an investigator?
# A: Colin
# P: Ray
#
#
# ----
#
#
# Negation in question only.
# Test cases:      486
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Roy is a photographer. Bob is an engineer.
# Q: Who is not a photographer?
# A: Bob
# P: Roy
#
# C: Roy is a photographer. Bob is an engineer.
# Q: Who is not an engineer?
# A: Roy
# P: Bob
#
# C: Bob is an engineer. Roy is a photographer.
# Q: Who is not a photographer?
# A: Bob
# P: Roy
#
#
# ----
# C: Anna is an educator. Frank is an actress.
# Q: Who is not an educator?
# A: Frank
# P: Anna
#
# C: Anna is an educator. Frank is an actress.
# Q: Who is not an actress?
# A: Anna
# P: Frank
#
# C: Frank is an actress. Anna is an educator.
# Q: Who is not an educator?
# A: Frank
# P: Anna
#
#
# ----
# C: Judy is an educator. Mike is a waitress.
# Q: Who is not an educator?
# A: Mike
# P: Judy
#
# C: Judy is an educator. Mike is a waitress.
# Q: Who is not a waitress?
# A: Judy
# P: Mike
#
# C: Mike is a waitress. Judy is an educator.
# Q: Who is not an educator?
# A: Mike
# P: Judy
#
#
# ----
#
#
#
#
# Coref
#
# Basic coref, he / she
# Test cases:      486
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Harry and Sally are friends. He is an intern, and she is an investigator.
# Q: Who is an intern?
# A: Harry
# P: Harry and Sally
#
# C: Harry and Sally are friends. He is an intern, and she is an investigator.
# Q: Who is an investigator?
# A: Sally
# P: Harry and Sally
#
# C: Sally and Harry are friends. He is an intern, and she is an investigator.
# Q: Who is an intern?
# A: Harry
# P: Sally and Harry
#
#
# ----
# C: Nick and Amanda are friends. He is an accountant, and she is an editor.
# Q: Who is an accountant?
# A: Nick
# P: Nick and Amanda
#
# C: Nick and Amanda are friends. He is an accountant, and she is an editor.
# Q: Who is an editor?
# A: Amanda
# P: Nick and Amanda
#
# C: Amanda and Nick are friends. He is an accountant, and she is an editor.
# Q: Who is an accountant?
# A: Nick
# P: Amanda
#
#
# ----
# C: Jimmy and Heather are friends. He is an artist, and she is a nurse.
# Q: Who is a nurse?
# A: Heather
# P: Jimmy
#
# C: Heather and Jimmy are friends. He is an artist, and she is a nurse.
# Q: Who is an artist?
# A: Jimmy
# P: Heather and Jimmy
#
# C: Heather and Jimmy are friends. He is an artist, and she is a nurse.
# Q: Who is a nurse?
# A: Heather
# P: Heather and Jimmy
#
#
# ----
#
#
# Basic coref, his / her
# Test cases:      500
# Test cases run:  100
# Fails (rate):    98 (98.0%)
#
# Example fails:
# C: Johnny and Sara are friends. Her mom is a DJ.
# Q: Whose mom is a DJ?
# A: Sara
# P: Johnny and Sara
#
# C: Sara and Johnny are friends. Her mom is a DJ.
# Q: Whose mom is a DJ?
# A: Sara
# P: Sara and Johnny
#
#
# ----
# C: Joseph and Rebecca are friends. Her mom is an investor.
# Q: Whose mom is an investor?
# A: Rebecca
# P: Joseph and Rebecca
#
# C: Rebecca and Joseph are friends. Her mom is an investor.
# Q: Whose mom is an investor?
# A: Rebecca
# P: Rebecca and Joseph
#
#
# ----
# C: Ben and Judith are friends. Her mom is an organizer.
# Q: Whose mom is an organizer?
# A: Judith
# P: Ben and Judith
#
#
# ----
#
#
# Former / Latter
# Test cases:      485
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Christine and Ed are friends. The former is an attorney.
# Q: Who is an attorney?
# A: Christine
# P: Christine and Ed
#
# C: Ed and Christine are friends. The latter is an attorney.
# Q: Who is an attorney?
# A: Christine
# P: Ed and Christine
#
# C: Christine and Ed are friends. The former is an attorney and the latter is a reporter.
# Q: Who is an attorney?
# A: Christine
# P: Christine and Ed
#
#
# ----
# C: Benjamin and Lawrence are friends. The former is a model.
# Q: Who is a model?
# A: Benjamin
# P: Benjamin and Lawrence
#
# C: Lawrence and Benjamin are friends. The latter is a model.
# Q: Who is a model?
# A: Benjamin
# P: Lawrence and Benjamin
#
# C: Benjamin and Lawrence are friends. The former is a model and the latter is an intern.
# Q: Who is a model?
# A: Benjamin
# P: Benjamin and Lawrence
#
#
# ----
# C: Edith and Ruth are friends. The former is an accountant.
# Q: Who is an accountant?
# A: Edith
# P: Edith and Ruth
#
# C: Ruth and Edith are friends. The latter is an accountant.
# Q: Who is an accountant?
# A: Edith
# P: Ruth and Edith
#
# C: Edith and Ruth are friends. The former is an accountant and the latter is a reporter.
# Q: Who is an accountant?
# A: Edith
# P: Edith and Ruth
#
#
# ----
#
#
#
#
# SRL
#
# Agent / object distinction
# Test cases:      499
# Test cases run:  100
# Fails (rate):    62 (62.0%)
#
# Example fails:
# C: James understands Stephen.
# Q: Who is understood?
# A: Stephen
# P: James understands Stephen
#
#
# ----
# C: Colin accepts Roger.
# Q: Who is accepted?
# A: Roger
# P: Colin accepts Roger
#
#
# ----
# C: Karen deserves Tim.
# Q: Who is deserved?
# A: Tim
# P: Karen deserves Tim
#
#
# ----
#
#
# Agent / object distinction with 3 agents
# Test cases:      492
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Alice blames Frederick. Steven is blamed by Frederick.
# Q: Who is blamed by Alice?
# A: Frederick
# P: Steven
#
#
# ----
# C: Steve notices Alexandra. Anthony is noticed by Alexandra.
# Q: Who notices Anthony?
# A: Alexandra
# P: Steve
#
#
# ----
# C: Bruce prefers Edward. Mary is preferred by Edward.
# Q: Who prefers Mary?
# A: Edward
# P: Bruce
#
# C: Bruce prefers Edward. Mary is preferred by Edward.
# Q: Who is preferred by Bruce?
# A: Edward
# P: Mary
#
# C: Edward is preferred by Bruce. Mary is preferred by Edward.
# Q: Who is preferred by Bruce?
# A: Edward
# P: Mary
#
#
# ----

# %%
# !jupyter nbextension install --py --sys-prefix checklist.viewer
# Out:
# Installing C:\Users\fgmal\AppData\Local\Programs\Python\Python311\Lib\site-packages\checklist\viewer\static -> viewer
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\bundle.js
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\bundle.js.map
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\custom.js
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\extension.js
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\index.js
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\index.js.map
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\__init__.py
# Up to date: C:\Users\fgmal\AppData\Local\Programs\Python\Python311\share\jupyter\nbextensions\viewer\__pycache__\__init__.cpython-311.pyc
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable checklist.viewer --py --sys-prefix

# %%
# !jupyter nbextension enable checklist.viewer --py --sys-prefix
# Out:
# Enabling notebook extension viewer/extension...
#       - Validating: ok

# %%
suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'A is COMP than B. Wh…
